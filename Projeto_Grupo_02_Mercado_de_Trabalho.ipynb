# %% [markdown]
# <a href="https://colab.research.google.com/github/ejascma/Data-Science/blob/main/Projeto_Grupo_02_Mercado_de_Trabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color ="cyan">1. DESCRIÇÃO GERAL DO PROJETO</font>

# %% [markdown]
# → Todas as equipes deverão entregar as mesmas especificações, de acordo com o seu respectivo tema.
#
# → Vocês deverão aplicar os conceitos vistos durante o curso para tratar, organizar e modelar pelo menos 1 (dataset) escolhido por vocês seguindo o tema de sua equipe.
#
# → Obrigatoriamente Python, Pandas, Looker Studio, Google Drive.
# Desejável conter as tecnologias Google Cloud Platform (Google Cloud SQL, SQL com BigQuery ou SQL com Python)

# %% [markdown]
# #<font color ="cyan">2. APRESENTAÇÃO</font>

# %% [markdown]
# A apresentação do trabalho se dará da seguinte maneira:
#
# → Cada grupo deverá ser totalmente responsável pela forma pela qual vai interpretar o dataset, apresentando suposições e conclusões dos dados.
#
# → Todas essas situações devem ser explicadas.
#
# → Deverá iniciar pela apresentação do dataset, informando de qual local foi obtido o dataset e quais as principais informações sobre o mesmo.
#
# → Deverá apresentar as funções e ferramentas utilizadas no código. Explicar o porquê do dataset escolhido.
#
# → Todos os componentes (integrantes) deverão se apresentar.
#
# → Deverá ser usado termos técnicos, evitando o uso de gírias ou expressões coloquiais e/ou culturais.
#
# → Cada grupo terá até 60 minutos para se apresentar.
#
# → A ordem da apresentação será comunicada pelos professores próximo à data de apresentação.

# %% [markdown]
# #<font color ="cyan">3. PRINCIPAIS HABILIDADES A SEREM AVALIADAS</font>

# %% [markdown]
# → Oralidade e comunicação em público.
#
# → Storytelling na apresentação dos dados: a apresentação dos dados pode ser feita de forma mais eficaz e envolvente através da técnica de storytelling.
#
# → Ao contar uma história, os dados são apresentados de maneira mais clara e compreensível, e a audiência é mais facilmente motivada e engajada.
#
# → Principais métricas e KPI’s observadas: definição completa de quais métricas e/ou KPI’s serão aplicadas ao projeto, suas razões e definições estratégicas.
#
# → Estabeleça algumas sugestões de ações: construa algumas sugestões de ações frente às informações coletadas no projeto.
#
# → Ações destinadas a campanhas, objetivos e segmentações, por exemplo.
#
# → Capacidade de argumentação
#
# → Habilidade de codificação em Python e utilização de suas bibliotecas
#
# → Habilidade de interpretação e análise de dados.
#
# → Capacidade de implementação de códigos utilizando a biblioteca Pandas.
#
# → Capacidade de implementação de consultas utilizando a linguagem SQL.
#
# → Capacidade Analítica e Interpretativa.
#
# → Capacidade de organização e grupo

# %% [markdown]
# #<font color ="red">4. ⚠️ REQUISITOS OBRIGATÓRIOS!!! ⚠️ </font>

# %% [markdown]
# → Em caso de mais de um dataset escolhido, obrigatoriamente os datasets devem ter formatos diferentes (CSV / Json / Sql / NoSql/ Excel, outros) e 1 deles obrigatoriamente tem que ser em CSV. ✅
#
# → Operações com Pandas (limpezas , transformações e normalizações) ✅
#
# → Utilizar pelo menos 2 gráficos distintos (bibliotecas matplotlib, seaborn, plotly ou outros) para representar os dados. ✅
#
# → Os datasets utilizados podem ser em língua estrangeira , mas devem ao final terem seus dados/colunas exibidos na língua PT-BR (Utilizar a diretrizes abordadas em aula) ✅
#
# → Os datasets devem ser salvos e operados em armazenamento cloud obrigatoriamente no Google Drive. ✅
#
# → Deve ser criado no Looker Studio um dashboard para exibição gráfica dos dados tratados trazendo insights importantes. ✅
#
# → E deve ser demonstrado em um workflow simples (gráfico) as etapas de ETL com suas respectivas ferramentas. ✅
#
# → Fazer a documentação do projeto; ✅
#
# → Liberem a pasta do projeto do drive dando acesso ao e-mail: professor.dados@soulcode.com ✅

# %% [markdown]
# #<font color ="cyan">5. INTEGRANTES DO GRUPO</font>

# %% [markdown]
# ###Nomes dos integrantes do Grupo 4

# %% [markdown]
# #<font color ="cyan">6. LINKS IMPORTANTES </font>

# %% [markdown]
# ##Links do Kaggle:
# ####[Dataset 2021](https://www.kaggle.com/datasets/datahackers/state-of-data-2021/data)
#
# ####[Dataset 2022](https://www.kaggle.com/datasets/datahackers/state-of-data-2022)
#
# ##Workflow e Apresentação:
# ####[Apresentação](https://docs.google.com/presentation/d/1gRjyOHDOaoQcMue3nvDzqhijbq-NCeDpIqDbzqj8cww/edit?usp=sharing)
#
# ##Looker Studio:
# ####[Looker Studio](https://lookerstudio.google.com/reporting/db4c9526-b76a-4842-ac03-9dadb78fbe14)
#
# ##Pasta dos Arquivos na Nuvem:
# ####[Google Drive](https://drive.google.com/drive/folders/18zUF-MSLciVzxIp7alvRV4zHmewANRq0?usp=drive_link)

# %% [markdown]
# #<font color ="cyan">HIPÓTESES</font>

# %% [markdown]
# ###→ HIPÓTESE 1 - Experiência e Satisfação no Trabalho:
# Pessoas com mais experiência na área de dados tendem a ter uma maior satisfação com a empresa atual.
#
# ###→ HIPÓTESE 2 - Localização Geográfica e Mudança de Estado:
# Pessoas que mudaram de estado recentemente têm uma tendência a ter um nível mais alto de satisfação com a empresa atual, devido à mudança e a uma possível busca por melhores oportunidades.
#
# ###→ HIPÓTESE 3 - Faixa Salarial e Satisfação no Trabalho:
# Existe uma relação entre a faixa salarial e a satisfação com a empresa atual? Pessoas com salários mais altos tendem a estar mais satisfeitas?
#
# ###→ HIPÓTESE 4 - Gênero e Nível de Ensino:
# Existe alguma disparidade de gênero em relação ao nível de ensino? Por exemplo, há mais homens ou mulheres com mestrado ou doutorado?
#
# ###→ HIPÓTESE 5 - Maturidade em Tecnologia e Dados e Forma de Trabalho Ideal:
# Pessoas com maior maturidade em tecnologia e dados têm uma preferência diferente em relação à forma de trabalho ideal? Por exemplo, eles preferem mais o trabalho remoto do que aqueles com menor maturidade?
#
# ###→ HIPÓTESE 6 - Existe uma correlação entre a idade dos profissionais e sua área de formação?
#
# Pessoas mais jovens tendem a ter uma área de formação mais voltada para tecnologia e ciência da computação, enquanto pessoas mais velhas podem ter uma formação mais diversificada em áreas como engenharia, administração ou outras.

# %% [markdown]
# #<font color ="cyan">IMPORTANDO O PANDAS, MATPLOTLIB, SEABORN, NUMPY, PLOTLY E PANDERA </font>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# !pip install pandera
import plotly.express as px
import pandera as pa
# Out:
# Collecting pandera
#   Downloading pandera-0.18.0-py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 3.5 MB/s eta 0:00:00
# Collecting multimethod (from pandera)
#   Downloading multimethod-1.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (23.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from pandera) (1.5.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from pandera) (2.6.1)
# Collecting typeguard>=3.0.2 (from pandera)
#   Downloading typeguard-4.1.5-py3-none-any.whl (34 kB)
# Collecting typing-inspect>=0.6.0 (from pandera)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from pandera) (1.14.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->pandera) (2023.4)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from typeguard>=3.0.2->pandera) (4.9.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.6.0->pandera)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->pandera) (2.16.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pandera) (1.16.0)
# Installing collected packages: typeguard, mypy-extensions, multimethod, typing-inspect, pandera
# Successfully installed multimethod-1.11 mypy-extensions-1.0.0 pandera-0.18.0 typeguard-4.1.5 typing-inspect-0.9.0

# %% [markdown]
# #<font color ="cyan">CARREGAMENTO DOS DATASETS</font>
#
# Recomendamos realizar o upload dos arquivos para executar os comandos da base de dados.

# %%
import pandas as pd

# Carregar o dataset de 2021
df_2021 = pd.read_csv('/content/State of Data 2021 - Dataset - Pgina1.csv')
# Out:
# <ipython-input-2-d87a1eacddcf>:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2021 = pd.read_csv('/content/drive/MyDrive/Projeto - SoulCode - AD3 - Grupo 02 - Mercado de Trabalho/Base de Dados/State of Data 2021 - Dataset - Pgina1.csv')

# %%
# Carregar o dataset de 2022
df_2022 = pd.read_excel('/content/State_of_data_2022.xlsx')

# %%
# configurando da quantidade de colunas para aparecer em um dataframe e tirando conotação científca
pd.set_option('display.max_columns', 357, 'display.float_format', lambda x: '%.2f' % x)

# %% [markdown]
# #<font color ="cyan">DATAFRAME 2021 (CSV)</font>

# %% [markdown]
# ##MOSTRANDO AS INFORMAÇÕES DO DATAFRAME DE 2021 - BRUTO
#
# → [URL da fonte de dados de 2021](https://www.kaggle.com/datasets/datahackers/state-of-data-2021/data)

# %%
df_2021
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     qkx4q0ei90wcjxnqkx4q0j3xgf0zn13s               38.00
# 1     zdl2n19yhgpnoaco6kkczdl2nwv9zwrt               39.00
# 2     vsamqp2un3q7us84mgvsams5fulsmcoh               30.00
# 3     v31ab41botodnsv31zgg4k34zzojy81l               38.00
# 4     ubhu8ntvm4xc0sfkdubhu80e973eek0k               36.00
# ...                                ...                 ...
# 2640  07nvo8cdy377a46gon207nvjebwe65zg               40.00
# 2641  01mqnby32u01pg3nuj6vipp4mc06s8pg               27.00
# 2642  01fncs8qbhl9zx01fncs8rqib2zl3d18               24.00
# 2643  075h3v2z19if04yn7o075h3vhifl38rw               38.00
# 2644  037usz1h2yip96dgil4mhj037uszw1gk               27.00
#
#      ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         35-39           Masculino
# 2                         30-34           Masculino
# 3                         35-39            Feminino
# 4                         35-39           Masculino
# ...                         ...                 ...
# 2640                      40-44           Masculino
# 2641                      25-29           Masculino
# 2642                      22-24           Masculino
# 2643                      35-39           Masculino
# 2644                      25-29            Feminino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                       Ceará (CE)                          CE
# 1                       Bahia (BA)                          BA
# 2              Santa Catarina (SC)                          SC
# 3                   São Paulo (SP)                          SP
# 4              Santa Catarina (SC)                          SC
# ...                            ...                         ...
# 2640                São Paulo (SP)                          SP
# 2641           Santa Catarina (SC)                          SC
# 2642           Santa Catarina (SC)                          SC
# 2643           Rio de Janeiro (RJ)                          RJ
# 2644             Minas Gerais (MG)                          MG
#
#      ('P1_e_b ', 'Regiao onde mora') ('P1_g_b ', 'Regiao de origem')  \
# 0                           Nordeste                             NaN
# 1                           Nordeste                         Sudeste
# 2                                Sul                             NaN
# 3                            Sudeste                             NaN
# 4                                Sul                             NaN
# ...                              ...                             ...
# 2640                         Sudeste                         Sudeste
# 2641                             Sul                             Sul
# 2642                             Sul                             NaN
# 2643                         Sudeste                             NaN
# 2644                         Sudeste                             NaN
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 0                                   0                Pós-graduação
# 1                                   1                Pós-graduação
# 2                                   0                Pós-graduação
# 3                                   0                Pós-graduação
# 4                                   0                Pós-graduação
# ...                               ...                          ...
# 2640                                1   Não tenho graduação formal
# 2641                                1        Graduação/Bacharelado
# 2642                                0        Graduação/Bacharelado
# 2643                                0        Graduação/Bacharelado
# 2644                                0                Pós-graduação
#
#                           ('P1_i ', 'Área de Formação')  \
# 0                                      Química / Física
# 1     Economia/ Administração / Contabilidade / Fina...
# 2     Computação / Engenharia de Software / Sistemas...
# 3                                                Outras
# 4                                    Outras Engenharias
# ...                                                 ...
# 2640                                                NaN
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?')  \
# 0                                      Empregado (CLT)
# 1                     Empreendedor ou Empregado (CNPJ)
# 2                                      Empregado (CLT)
# 3                     Empreendedor ou Empregado (CNPJ)
# 4                     Empreendedor ou Empregado (CNPJ)
# ...                                                ...
# 2640            Trabalho na área Acadêmica/Pesquisador
# 2641                                   Empregado (CLT)
# 2642                                   Empregado (CLT)
# 2643                Desempregado, buscando recolocação
# 2644                Desempregado, buscando recolocação
#
#                   ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 0                          Marketing                        de 101 a 500
# 1                        Consultoria                            de 1 a 5
# 2                          Indústria                      de 1001 a 3000
# 3                           Serviços                      de 1001 a 3000
# 4                             Varejo                           de 6 a 10
# ...                              ...                                 ...
# 2640                             NaN                                 NaN
# 2641  Tecnologia/Fábrica de Software                       de 501 a 1000
# 2642  Tecnologia/Fábrica de Software                       Acima de 3000
# 2643                             NaN                                 NaN
# 2644                             NaN                                 NaN
#
#       ('P2_d ', 'Gestor?')             ('P2_e ', 'Cargo como Gestor')  \
# 0                     1.00                     Supervisor/Coordenador
# 1                     1.00  Sócio ou C-level (CEO, CDO, CIO, CTO etc)
# 2                     1.00                     Supervisor/Coordenador
# 3                     1.00                    Gerente/Head/Diretor/VP
# 4                     1.00                    Gerente/Head/Diretor/VP
# ...                    ...                                        ...
# 2640                   NaN                                        NaN
# 2641                  0.00                                        NaN
# 2642                  0.00                                        NaN
# 2643                   NaN                                        NaN
# 2644                   NaN                                        NaN
#
#                ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                   NaN                NaN
# ...                                 ...                ...
# 2640                                NaN                NaN
# 2641  Cientista de Dados/Data Scientist              Pleno
# 2642  Engenheiro de Dados/Data Engineer              Pleno
# 2643                                NaN                NaN
# 2644                                NaN                NaN
#
#            ('P2_h ', 'Faixa salarial')  \
# 0       de R$ 4.001/mês a R$ 6.000/mês
# 1       de R$ 6.001/mês a R$ 8.000/mês
# 2      de R$ 8.001/mês a R$ 12.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4      de R$ 8.001/mês a R$ 12.000/mês
# ...                                ...
# 2640                               NaN
# 2641    de R$ 6.001/mês a R$ 8.000/mês
# 2642    de R$ 6.001/mês a R$ 8.000/mês
# 2643                               NaN
# 2644                               NaN
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 0                                       Mais de 10 anos
# 1                                         de 2 a 3 anos
# 2                                         de 1 a 2 anos
# 3                                       Mais de 10 anos
# 4                                         de 1 a 2 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                      de 4 a 5 anos
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 0     Não tive experiência na área de TI/Engenharia ...
# 1     Não tive experiência na área de TI/Engenharia ...
# 2                                         de 2 a 3 anos
# 3                                        Menos de 1 ano
# 4                                         de 4 a 5 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 0                                                  1.00
# 1                                                  1.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               1.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                O clima de trabalho/ambiente não é bom
# 3              Falta de maturidade analítica na empresa
# 4     Gostaria de trabalhar em em outra área de atua...
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642  Salário atual não corresponde ao mercado, Gost...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_b ', 'Salário atual não corresponde ao mercado')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               1.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_e ', 'Gostaria de receber mais benefícios')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               1.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_f ', 'O clima de trabalho/ambiente não é bom')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  1.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_l_g ', 'Falta de maturidade analítica na empresa')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  1.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')  \
# 0                  Sim, fui aprovado e mudei de emprego
# 1     Não participei de entrevistas de empregos/proc...
# 2     Sim, fui aprovado mas decidi não mudar de emprego
# 3     Não participei de entrevistas de empregos/proc...
# 4     Não participei de entrevistas de empregos/proc...
# ...                                                 ...
# 2640                                                NaN
# 2641               Sim, fui aprovado e mudei de emprego
# 2642               Sim, fui aprovado e mudei de emprego
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')  \
# 0     Estou em busca de oportunidades dentro ou fora...
# 1     Não estou buscando, mas me considero aberto a ...
# 2     Estou em busca de oportunidades dentro ou fora...
# 3     Estou em busca de oportunidades dentro ou fora...
# 4     Não estou buscando, mas me considero aberto a ...
# ...                                                 ...
# 2640                                                NaN
# 2641  Não estou buscando e não pretendo mudar de emp...
# 2642  Estou em busca de oportunidades dentro ou fora...
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 0                                            Benefícios
# 1                      Flexibilidade de trabalho remoto
# 2     Oportunidade de aprendizado e trabalhar com re...
# 3     Propósito do trabalho e da empresa, Flexibilid...
# 4     Maturidade da empresa em termos de tecnologia ...
# ...                                                 ...
# 2640                                                NaN
# 2641  Oportunidade de aprendizado e trabalhar com re...
# 2642  Remuneração/Salário, Benefícios, Propósito do ...
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_a ', 'Remuneração/Salário')  ('P2_o_b ', 'Benefícios')  \
# 0                                   0.00                       1.00
# 1                                   0.00                       0.00
# 2                                   0.00                       0.00
# 3                                   1.00                       0.00
# 4                                   1.00                       0.00
# ...                                  ...                        ...
# 2640                                 NaN                        NaN
# 2641                                0.00                       0.00
# 2642                                1.00                       1.00
# 2643                                 NaN                        NaN
# 2644                                 NaN                        NaN
#
#       ('P2_o_c ', 'Propósito do trabalho e da empresa')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  1.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                               1.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_d ', 'Flexibilidade de trabalho remoto')  \
# 0                                                0.00
# 1                                                1.00
# 2                                                0.00
# 3                                                1.00
# 4                                                0.00
# ...                                               ...
# 2640                                              NaN
# 2641                                             0.00
# 2642                                             0.00
# 2643                                              NaN
# 2644                                              NaN
#
#       ('P2_o_e ', 'Ambiente e clima de trabalho')  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
# 3                                            0.00
# 4                                            0.00
# ...                                           ...
# 2640                                          NaN
# 2641                                         0.00
# 2642                                         0.00
# 2643                                          NaN
# 2644                                          NaN
#
#       ('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  1.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               1.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               1.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_i ', 'Qualidade dos gestores e líderes')  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 2640                                              NaN
# 2641                                             1.00
# 2642                                             0.00
# 2643                                              NaN
# 2644                                              NaN
#
#       ('P2_o_j ', 'Reputação que a empresa tem no mercado')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_q ', 'Atualmente qual a sua forma de trabalho?')  \
# 0                                Modelo 100% presencial
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2                                Modelo 100% presencial
# 3                                Modelo 100% presencial
# 4                                Modelo 100% presencial
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_r ', 'Qual a forma de trabalho ideal para você?')  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1                                    Modelo 100% remoto
# 2                                    Modelo 100% remoto
# 3     Modelo híbrido com dias fixos de trabalho pres...
# 4                                    Modelo 100% remoto
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')  \
# 0     Vou aceitar e retornar ao modelo 100% presencial.
# 1     Vou procurar outra oportunidade no modelo 100%...
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4     Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 2640                                                NaN
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')  \
# 0                                                4 - 10
# 1                                                 1 - 3
# 2     Ainda não temos pessoas atuando com dados na e...
# 3                                                 1 - 3
# 4     Ainda não temos pessoas atuando com dados na e...
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')  \
# 0                  Analista de Business Intelligence/BI
# 1                  Analista de Business Intelligence/BI
# 2                  Analista de Business Intelligence/BI
# 3                  Analista de Business Intelligence/BI
# 4                  Analista de Business Intelligence/BI
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_b_a ', 'Analytics Engineer')  \
# 0                                  0.00
# 1                                  0.00
# 2                                  0.00
# 3                                  0.00
# 4                                  0.00
# ...                                 ...
# 2640                                NaN
# 2641                                NaN
# 2642                                NaN
# 2643                                NaN
# 2644                                NaN
#
#       ('P3_b_b ', 'Engenharia de Dados/Data Engineer')  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_c ', 'Analista de Dados/Data Analyst')  \
# 0                                              0.00
# 1                                              0.00
# 2                                              0.00
# 3                                              0.00
# 4                                              0.00
# ...                                             ...
# 2640                                            NaN
# 2641                                            NaN
# 2642                                            NaN
# 2643                                            NaN
# 2644                                            NaN
#
#       ('P3_b_d ', 'Cientista de Dados/Data Scientist')  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_e ', 'Database Administrator/DBA')  \
# 0                                          0.00
# 1                                          0.00
# 2                                          0.00
# 3                                          0.00
# 4                                          0.00
# ...                                         ...
# 2640                                        NaN
# 2641                                        NaN
# 2642                                        NaN
# 2643                                        NaN
# 2644                                        NaN
#
#       ('P3_b_f ', 'Analista de Business Intelligence/BI')  \
# 0                                                  1.00
# 1                                                  1.00
# 2                                                  1.00
# 3                                                  1.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_b_g ', 'Arquiteto de Dados/Data Architect')  \
# 0                                                 0.00
# 1                                                 0.00
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ...                                                ...
# 2640                                               NaN
# 2641                                               NaN
# 2642                                               NaN
# 2643                                               NaN
# 2644                                               NaN
#
#       ('P3_b_h ', 'Data Product Manager/DPM')  \
# 0                                        0.00
# 1                                        0.00
# 2                                        0.00
# 3                                        0.00
# 4                                        0.00
# ...                                       ...
# 2640                                      NaN
# 2641                                      NaN
# 2642                                      NaN
# 2643                                      NaN
# 2644                                      NaN
#
#       ('P3_b_i ', 'Business Analyst')  \
# 0                                0.00
# 1                                0.00
# 2                                0.00
# 3                                0.00
# 4                                0.00
# ...                               ...
# 2640                              NaN
# 2641                              NaN
# 2642                              NaN
# 2643                              NaN
# 2644                              NaN
#
#      ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')  \
# 0     Sou gestor da equipe responsável pela entrega ...
# 1     Apesar de ser gestor ainda atuo na parte técni...
# 2     Organização de treinamentos e iniciativas com ...
# 3     Organização de treinamentos e iniciativas com ...
# 4     Pensar na visão de longo prazo de dados da emp...
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  1.00
# 3                                                  1.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  1.00
# 3                                                  1.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                                NaN
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               1.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                                NaN
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')  \
# 0           Newsletter Semanal, Podcast do Data Hackers
# 1       Newsletter Semanal, Blog/Medium do Data Hackers
# 2     Blog/Medium do Data Hackers, Podcast do Data H...
# 3                     Ainda não conhecia o Data Hackers
# 4     Podcast do Data Hackers, Canal do Slack, Newsl...
# ...                                                 ...
# 2640                  Ainda não conhecia o Data Hackers
# 2641                        Blog/Medium do Data Hackers
# 2642  Blog/Medium do Data Hackers, Podcast do Data H...
# 2643                        Blog/Medium do Data Hackers
# 2644                  Ainda não conhecia o Data Hackers
#
#       ('P9_a_a ', 'Blog/Medium do Data Hackers')  \
# 0                                              0
# 1                                              1
# 2                                              1
# 3                                              0
# 4                                              0
# ...                                          ...
# 2640                                           0
# 2641                                           1
# 2642                                           1
# 2643                                           1
# 2644                                           0
#
#       ('P9_a_b ', 'Podcast do Data Hackers')  \
# 0                                          1
# 1                                          0
# 2                                          1
# 3                                          0
# 4                                          1
# ...                                      ...
# 2640                                       0
# 2641                                       0
# 2642                                       1
# 2643                                       0
# 2644                                       0
#
#       ('P9_a_d ', 'Newsletter Semanal')  ('P9_a_e ', 'Canal do Slack')  \
# 0                                     1                              0
# 1                                     1                              0
# 2                                     0                              0
# 3                                     0                              0
# 4                                     1                              1
# ...                                 ...                            ...
# 2640                                  0                              0
# 2641                                  0                              0
# 2642                                  1                              1
# 2643                                  0                              0
# 2644                                  0                              0
#
#       ('P9_a_f ', 'Canal do Youtube do Data Hackers')  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 2640                                                0
# 2641                                                0
# 2642                                                0
# 2643                                                0
# 2644                                                0
#
#       ('P9_a_g ', 'Ainda não conhecia o Data Hackers')
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    1
# 4                                                    0
# ...                                                ...
# 2640                                                 1
# 2641                                                 0
# 2642                                                 0
# 2643                                                 0
# 2644                                                 1
#
# [2645 rows x 356 columns]

# %% [markdown]
# ##LISTA COM O TOTAL DE COLUNAS DO DATAFRAME 2021

# %%
df_2021.columns.tolist()
# Out:
# ["('P0', 'id')",
#  "('P1_a ', 'Idade')",
#  "('P1_a_a ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_e ', 'Estado onde mora')",
#  "('P1_e_a ', 'uf onde mora')",
#  "('P1_e_b ', 'Regiao onde mora')",
#  "('P1_g_b ', 'Regiao de origem')",
#  "('P1_g_c ', 'Mudou de Estado?')",
#  "('P1_h ', 'Nivel de Ensino')",
#  "('P1_i ', 'Área de Formação')",
#  "('P2_a ', 'Qual sua situação atual de trabalho?')",
#  "('P2_b ', 'Setor')",
#  "('P2_c ', 'Numero de Funcionarios')",
#  "('P2_d ', 'Gestor?')",
#  "('P2_e ', 'Cargo como Gestor')",
#  "('P2_f ', 'Cargo Atual')",
#  "('P2_g ', 'Nivel')",
#  "('P2_h ', 'Faixa salarial')",
#  "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#  "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#  "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
#  "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
#  "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')",
#  "('P2_l_b ', 'Salário atual não corresponde ao mercado')",
#  "('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')",
#  "('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')",
#  "('P2_l_e ', 'Gostaria de receber mais benefícios')",
#  "('P2_l_f ', 'O clima de trabalho/ambiente não é bom')",
#  "('P2_l_g ', 'Falta de maturidade analítica na empresa')",
#  "('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
#  "('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')",
#  "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
#  "('P2_o_a ', 'Remuneração/Salário')",
#  "('P2_o_b ', 'Benefícios')",
#  "('P2_o_c ', 'Propósito do trabalho e da empresa')",
#  "('P2_o_d ', 'Flexibilidade de trabalho remoto')",
#  "('P2_o_e ', 'Ambiente e clima de trabalho')",
#  "('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
#  "('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')",
#  "('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')",
#  "('P2_o_i ', 'Qualidade dos gestores e líderes')",
#  "('P2_o_j ', 'Reputação que a empresa tem no mercado')",
#  "('P2_q ', 'Atualmente qual a sua forma de trabalho?')",
#  "('P2_r ', 'Qual a forma de trabalho ideal para você?')",
#  "('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')",
#  "('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')",
#  "('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')",
#  "('P3_b_a ', 'Analytics Engineer')",
#  "('P3_b_b ', 'Engenharia de Dados/Data Engineer')",
#  "('P3_b_c ', 'Analista de Dados/Data Analyst')",
#  "('P3_b_d ', 'Cientista de Dados/Data Scientist')",
#  "('P3_b_e ', 'Database Administrator/DBA')",
#  "('P3_b_f ', 'Analista de Business Intelligence/BI')",
#  "('P3_b_g ', 'Arquiteto de Dados/Data Architect')",
#  "('P3_b_h ', 'Data Product Manager/DPM')",
#  "('P3_b_i ', 'Business Analyst')",
#  "('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')",
#  "('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')",
#  "('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')",
#  "('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')",
#  "('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')",
#  "('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')",
#  "('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')",
#  "('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')",
#  "('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')",
#  "('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')",
#  "('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')",
#  "('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')",
#  "('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')",
#  "('P3_d_ ', 'a Contratar novos talentos.')",
#  "('P3_d_ ', 'b Reter talentos.')",
#  "('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')",
#  "('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')",
#  "('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')",
#  "('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')",
#  "('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')",
#  "('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')",
#  "('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')",
#  "('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')",
#  "('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')",
#  "('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')",
#  "('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')",
#  "('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')",
#  "('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')",
#  "('P4_a ', 'Atuacao')",
#  "('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')",
#  "('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')",
#  "('P4_b_b ', 'Dados armazenados em bancos NoSQL')",
#  "('P4_b_c ', 'Imagens')",
#  "('P4_b_d ', 'Textos/Documentos')",
#  "('P4_b_e ', 'Vídeos')",
#  "('P4_b_f ', 'Áudios')",
#  "('P4_b_g ', 'Planilhas')",
#  "('P4_b_h ', 'Dados georeferenciados')",
#  "('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')",
#  "('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')",
#  "('P4_c_b ', 'Dados armazenados em bancos NoSQL')",
#  "('P4_c_c ', 'Imagens')",
#  "('P4_c_d ', 'Textos/Documentos')",
#  "('P4_c_e ', 'Vídeos')",
#  "('P4_c_f ', 'Áudios')",
#  "('P4_c_g ', 'Planilhas')",
#  "('P4_c_h ', 'Dados georeferenciados')",
#  "('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')",
#  "('P4_d_a ', 'SQL')",
#  "('P4_d_b ', 'R ')",
#  "('P4_d_c ', 'Python')",
#  "('P4_d_d ', 'C/C++/C#')",
#  "('P4_d_e ', '.NET')",
#  "('P4_d_f ', 'Java')",
#  "('P4_d_g ', 'Julia')",
#  "('P4_d_h ', 'SAS/Stata')",
#  "('P4_d_i ', 'Visual Basic/VBA')",
#  "('P4_d_j ', 'Scala')",
#  "('P4_d_k ', 'Matlab')",
#  "('P4_d_l ', 'PHP')",
#  "('P4_d_m ', 'Javascript')",
#  "('P4_d_n ', 'Não utilizo nenhuma linguagem')",
#  "('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')",
#  "('P4_e_a ', 'SQL')",
#  "('P4_e_b ', 'R ')",
#  "('P4_e_c ', 'Python')",
#  "('P4_e_d ', 'C/C++/C#')",
#  "('P4_e_e ', '.NET')",
#  "('P4_e_f ', 'Java')",
#  "('P4_e_g ', 'Julia')",
#  "('P4_e_h ', 'SAS/Stata')",
#  "('P4_e_i ', 'Visual Basic/VBA')",
#  "('P4_e_j ', 'Scala')",
#  "('P4_e_k ', 'Matlab')",
#  "('P4_e_l ', 'PHP')",
#  "('P4_e_m ', 'Javascript')",
#  "('P4_e_n ', 'Não utilizo nenhuma linguagem')",
#  "('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')",
#  "('P4_f_a ', 'MySQL')",
#  "('P4_f_b ', 'Oracle')",
#  "('P4_f_c ', 'SQL SERVER')",
#  "('P4_f_d ', 'SAP')",
#  "('P4_f_e ', 'Amazon Aurora ou RDS')",
#  "('P4_f_f ', 'Amazon DynamoDB')",
#  "('P4_f_g ', 'CoachDB')",
#  "('P4_f_h ', 'Cassandra')",
#  "('P4_f_i ', 'MongoDB')",
#  "('P4_f_j ', 'MariaDB')",
#  "('P4_f_k ', 'Datomic')",
#  "('P4_f_l ', 'S3')",
#  "('P4_f_m ', 'PostgreSQL')",
#  "('P4_f_n ', 'ElasticSearch')",
#  "('P4_f_o ', 'DB2')",
#  "('P4_f_p ', 'Microsoft Access')",
#  "('P4_f_q ', 'SQLite')",
#  "('P4_f_r ', 'Sybase')",
#  "('P4_f_s ', 'Firebase')",
#  "('P4_f_t ', 'Vertica')",
#  "('P4_f_u ', 'Redis')",
#  "('P4_f_v ', 'Neo4J')",
#  "('P4_f_x ', 'Google BigQuery')",
#  "('P4_f_y ', 'Google Firestore')",
#  "('P4_f_z ', 'Amazon Redshift')",
#  "('P4_f_z1 ', 'Amazon Athena')",
#  "('P4_f_z2 ', 'Snowflake')",
#  "('P4_f_z3 ', 'Databricks')",
#  "('P4_f_z4 ', 'HBase')",
#  "('P4_f_z5 ', 'Presto')",
#  "('P4_f_z6 ', 'Splunk')",
#  "('P4_f_z7 ', 'SAP HANA')",
#  "('P4_f_z8 ', 'Hive')",
#  "('P4_f_z9 ', 'Firebird')",
#  "('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')",
#  "('P4_g_a ', 'Amazon Web Services (AWS)')",
#  "('P4_g_b ', 'Google Cloud (GCP)')",
#  "('P4_g_c ', 'Azure (Microsoft)')",
#  "('P4_g_d ', 'Oracle Cloud')",
#  "('P4_g_e ', 'IBM')",
#  "('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')",
#  "('P4_g_g ', 'Cloud Própria')",
#  "('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')",
#  "('P4_h_a ', 'Microsoft PowerBI')",
#  "('P4_h_b ', 'Qlik View/Qlik Sense')",
#  "('P4_h_c ', 'Tableau')",
#  "('P4_h_d ', 'Metabase')",
#  "('P4_h_e ', 'Superset')",
#  "('P4_h_f ', 'Redash')",
#  "('P4_h_g ', 'MicroStrategy')",
#  "('P4_h_h ', 'IBM Analytics/Cognos')",
#  "('P4_h_i ', 'SAP Business Objects')",
#  "('P4_h_j ', 'Oracle Business Intelligence')",
#  "('P4_h_k ', 'Amazon QuickSight')",
#  "('P4_h_l ', 'Salesforce/Einstein Analytics')",
#  "('P4_h_m ', 'Mode')",
#  "('P4_h_n ', 'Alteryx')",
#  "('P4_h_o ', 'Birst')",
#  "('P4_h_p ', 'Looker')",
#  "('P4_h_q ', 'Google Data Studio')",
#  "('P4_h_r ', 'SAS Visual Analytics')",
#  "('P4_h_s ', 'Grafana')",
#  "('P4_h_t ', 'TIBCO Spotfire')",
#  "('P4_h_u ', 'Pentaho')",
#  "('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')",
#  "('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')",
#  "('P5_b ', 'Qual oportunidade você está buscando?')",
#  "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
#  "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
#  "('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')",
#  "('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
#  "('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
#  "('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
#  "('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
#  "('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
#  "('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
#  "('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')",
#  "('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
#  "('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')",
#  "('P6_b_a ', 'Scripts Python')",
#  "('P6_b_b ', 'SQL & Stored Procedures')",
#  "('P6_b_c ', 'Apache Airflow')",
#  "('P6_b_d ', 'Luigi')",
#  "('P6_b_e ', 'AWS Glue')",
#  "('P6_b_f ', 'Talend')",
#  "('P6_b_g ', 'Stitch')",
#  "('P6_b_h ', 'Fivetran')",
#  "('P6_b_i ', 'Google Dataflow')",
#  "('P6_b_j ', 'Oracle Data Integrator')",
#  "('P6_b_k ', 'IBM DataStage')",
#  "('P6_b_l ', 'SAP BW ETL')",
#  "('P6_b_m ', 'SQL Server Integration Services (SSIS)')",
#  "('P6_b_n ', 'SAS Data Integration')",
#  "('P6_b_o ', 'Qlik Sense')",
#  "('P6_b_p ', 'Knime')",
#  "('P6_b_q ', 'Não utilizo ferramentas de ETL')",
#  "('P6_c ', 'Sua organização possui um Data Lake?')",
#  "('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')",
#  "('P6_e ', 'Sua organização possui um Data Warehouse?')",
#  "('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')",
#  "('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')",
#  "('P6_g_a ', 'great_expectations')",
#  "('P6_g_b ', 'dbt')",
#  "('P6_g_c ', 'AWS Deequ')",
#  "('P6_g_d ', 'Apache Griffin')",
#  "('P6_g_e ', 'Datafold')",
#  "('P6_g_f ', 'Amundsen')",
#  "('P6_g_g ', 'Monte Carlo')",
#  "('P6_g_h ', 'SODA')",
#  "('P6_g_i ', 'Big Eye')",
#  "('P6_g_j ', 'Data Band')",
#  "('P6_g_k ', 'Anomalo')",
#  "('P6_g_l ', 'Metaplane')",
#  "('P6_g_m ', 'Acceldata')",
#  "('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')",
#  "('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
#  "('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
#  "('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
#  "('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
#  "('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
#  "('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
#  "('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')",
#  "('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')",
#  "('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')",
#  "('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
#  "('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')",
#  "('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
#  "('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
#  "('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
#  "('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')",
#  "('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')",
#  "('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')",
#  "('P7_b_a ', 'Scripts Python')",
#  "('P7_b_b ', 'SQL & Stored Procedures')",
#  "('P7_b_c ', 'Apache Airflow')",
#  "('P7_b_d ', 'Luigi')",
#  "('P7_b_e ', 'AWS Glue')",
#  "('P7_b_f ', 'Talend')",
#  "('P7_b_g ', 'Stitch')",
#  "('P7_b_h ', 'Fivetran')",
#  "('P7_b_i ', 'Google Dataflow')",
#  "('P7_b_j ', 'Oracle Data Integrator')",
#  "('P7_b_k ', 'IBM DataStage')",
#  "('P7_b_l ', 'SAP BW ETL')",
#  "('P7_b_m ', 'SQL Server Integration Services (SSIS)')",
#  "('P7_b_n ', 'SAS Data Integration')",
#  "('P7_b_o ', 'Qlik Sense')",
#  "('P7_b_p ', 'Knime')",
#  "('P7_b_q ', 'Não utilizo ferramentas de ETL')",
#  "('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')",
#  "('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')",
#  '(\'P7_c_b \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')',
#  "('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')",
#  "('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')",
#  "('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')",
#  "('P7_c_f ', 'Não sei informar.')",
#  "('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')",
#  "('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')",
#  "('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
#  "('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')",
#  "('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
#  "('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
#  "('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
#  "('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')",
#  "('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
#  "('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')",
#  "('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
#  "('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')",
#  "('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
#  "('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
#  "('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')",
#  "('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
#  "('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')",
#  "('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
#  "('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
#  "('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')",
#  "('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')",
#  "('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')",
#  "('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')",
#  "('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')",
#  "('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')",
#  "('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')",
#  "('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')",
#  "('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')",
#  "('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')",
#  "('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')",
#  "('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')",
#  "('P8_b_l ', 'Utilizo métodos de Visão Computacional')",
#  "('P8_b_m ', 'Utilizo modelos de Detecção de Churn')",
#  "('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')",
#  "('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')",
#  "('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')",
#  "('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')",
#  "('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')",
#  "('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')",
#  "('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')",
#  "('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')",
#  "('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')",
#  "('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')",
#  "('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')",
#  "('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')",
#  "('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')",
#  "('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')",
#  "('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')",
#  "('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
#  "('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
#  "('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')",
#  "('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
#  "('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')",
#  "('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')",
#  "('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')",
#  "('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
#  "('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')",
#  "('P9_a_a ', 'Blog/Medium do Data Hackers')",
#  "('P9_a_b ', 'Podcast do Data Hackers')",
#  "('P9_a_d ', 'Newsletter Semanal')",
#  "('P9_a_e ', 'Canal do Slack')",
#  "('P9_a_f ', 'Canal do Youtube do Data Hackers')",
#  "('P9_a_g ', 'Ainda não conhecia o Data Hackers')"]

# %% [markdown]
# ##SEGREGANDO A TAREFA DE ANÁLISE DAS COLUNAS DO DATAFRAME 2021

# %%
# Original list of lines
lines = ["('P0', 'id')",
 "('P1_a ', 'Idade')",
 "('P1_a_a ', 'Faixa idade')",
 "('P1_b ', 'Genero')",
 "('P1_e ', 'Estado onde mora')",
 "('P1_e_a ', 'uf onde mora')",
 "('P1_e_b ', 'Regiao onde mora')",
 "('P1_g_b ', 'Regiao de origem')",
 "('P1_g_c ', 'Mudou de Estado?')",
 "('P1_h ', 'Nivel de Ensino')",
 "('P1_i ', 'Área de Formação')",
 "('P2_a ', 'Qual sua situação atual de trabalho?')",
 "('P2_b ', 'Setor')",
 "('P2_c ', 'Numero de Funcionarios')",
 "('P2_d ', 'Gestor?')",
 "('P2_e ', 'Cargo como Gestor')",
 "('P2_f ', 'Cargo Atual')",
 "('P2_g ', 'Nivel')",
 "('P2_h ', 'Faixa salarial')",
 "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
 "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
 "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
 "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
 "('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')",
 "('P2_l_b ', 'Salário atual não corresponde ao mercado')",
 "('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')",
 "('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')",
 "('P2_l_e ', 'Gostaria de receber mais benefícios')",
 "('P2_l_f ', 'O clima de trabalho/ambiente não é bom')",
 "('P2_l_g ', 'Falta de maturidade analítica na empresa')",
 "('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
 "('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')",
 "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
 "('P2_o_a ', 'Remuneração/Salário')",
 "('P2_o_b ', 'Benefícios')",
 "('P2_o_c ', 'Propósito do trabalho e da empresa')",
 "('P2_o_d ', 'Flexibilidade de trabalho remoto')",
 "('P2_o_e ', 'Ambiente e clima de trabalho')",
 "('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
 "('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')",
 "('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')",
 "('P2_o_i ', 'Qualidade dos gestores e líderes')",
 "('P2_o_j ', 'Reputação que a empresa tem no mercado')",
 "('P2_q ', 'Atualmente qual a sua forma de trabalho?')",
 "('P2_r ', 'Qual a forma de trabalho ideal para você?')",
 "('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')",
 "('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')",
 "('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')",
 "('P3_b_a ', 'Analytics Engineer')",
 "('P3_b_b ', 'Engenharia de Dados/Data Engineer')",
 "('P3_b_c ', 'Analista de Dados/Data Analyst')",
 "('P3_b_d ', 'Cientista de Dados/Data Scientist')",
 "('P3_b_e ', 'Database Administrator/DBA')",
 "('P3_b_f ', 'Analista de Business Intelligence/BI')",
 "('P3_b_g ', 'Arquiteto de Dados/Data Architect')",
 "('P3_b_h ', 'Data Product Manager/DPM')",
 "('P3_b_i ', 'Business Analyst')",
 "('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')",
 "('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')",
 "('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')",
 "('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')",
 "('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')",
 "('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')",
 "('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')",
 "('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')",
 "('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')",
 "('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')",
 "('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')",
 "('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')",
 "('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')",
 "('P3_d_ ', 'a Contratar novos talentos.')",
 "('P3_d_ ', 'b Reter talentos.')",
 "('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')",
 "('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')",
 "('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')",
 "('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')",
 "('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')",
 "('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')",
 "('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')",
 "('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')",
 "('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')",
 "('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')",
 "('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')",
 "('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')",
 "('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')",
 "('P4_a ', 'Atuacao')",
 "('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')",
 "('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')",
 "('P4_b_b ', 'Dados armazenados em bancos NoSQL')",
 "('P4_b_c ', 'Imagens')",
 "('P4_b_d ', 'Textos/Documentos')",
 "('P4_b_e ', 'Vídeos')",
 "('P4_b_f ', 'Áudios')",
 "('P4_b_g ', 'Planilhas')",
 "('P4_b_h ', 'Dados georeferenciados')",
 "('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')",
 "('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')",
 "('P4_c_b ', 'Dados armazenados em bancos NoSQL')",
 "('P4_c_c ', 'Imagens')",
 "('P4_c_d ', 'Textos/Documentos')",
 "('P4_c_e ', 'Vídeos')",
 "('P4_c_f ', 'Áudios')",
 "('P4_c_g ', 'Planilhas')",
 "('P4_c_h ', 'Dados georeferenciados')",
 "('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')",
 "('P4_d_a ', 'SQL')",
 "('P4_d_b ', 'R ')",
 "('P4_d_c ', 'Python')",
 "('P4_d_d ', 'C/C++/C#')",
 "('P4_d_e ', '.NET')",
 "('P4_d_f ', 'Java')",
 "('P4_d_g ', 'Julia')",
 "('P4_d_h ', 'SAS/Stata')",
 "('P4_d_i ', 'Visual Basic/VBA')",
 "('P4_d_j ', 'Scala')",
 "('P4_d_k ', 'Matlab')",
 "('P4_d_l ', 'PHP')",
 "('P4_d_m ', 'Javascript')",
 "('P4_d_n ', 'Não utilizo nenhuma linguagem')",
 "('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')",
 "('P4_e_a ', 'SQL')",
 "('P4_e_b ', 'R ')",
 "('P4_e_c ', 'Python')",
 "('P4_e_d ', 'C/C++/C#')",
 "('P4_e_e ', '.NET')",
 "('P4_e_f ', 'Java')",
 "('P4_e_g ', 'Julia')",
 "('P4_e_h ', 'SAS/Stata')",
 "('P4_e_i ', 'Visual Basic/VBA')",
 "('P4_e_j ', 'Scala')",
 "('P4_e_k ', 'Matlab')",
 "('P4_e_l ', 'PHP')",
 "('P4_e_m ', 'Javascript')",
 "('P4_e_n ', 'Não utilizo nenhuma linguagem')",
 "('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')",
 "('P4_f_a ', 'MySQL')",
 "('P4_f_b ', 'Oracle')",
 "('P4_f_c ', 'SQL SERVER')",
 "('P4_f_d ', 'SAP')",
 "('P4_f_e ', 'Amazon Aurora ou RDS')",
 "('P4_f_f ', 'Amazon DynamoDB')",
 "('P4_f_g ', 'CoachDB')",
 "('P4_f_h ', 'Cassandra')",
 "('P4_f_i ', 'MongoDB')",
 "('P4_f_j ', 'MariaDB')",
 "('P4_f_k ', 'Datomic')",
 "('P4_f_l ', 'S3')",
 "('P4_f_m ', 'PostgreSQL')",
 "('P4_f_n ', 'ElasticSearch')",
 "('P4_f_o ', 'DB2')",
 "('P4_f_p ', 'Microsoft Access')",
 "('P4_f_q ', 'SQLite')",
 "('P4_f_r ', 'Sybase')",
 "('P4_f_s ', 'Firebase')",
 "('P4_f_t ', 'Vertica')",
 "('P4_f_u ', 'Redis')",
 "('P4_f_v ', 'Neo4J')",
 "('P4_f_x ', 'Google BigQuery')",
 "('P4_f_y ', 'Google Firestore')",
 "('P4_f_z ', 'Amazon Redshift')",
 "('P4_f_z1 ', 'Amazon Athena')",
 "('P4_f_z2 ', 'Snowflake')",
 "('P4_f_z3 ', 'Databricks')",
 "('P4_f_z4 ', 'HBase')",
 "('P4_f_z5 ', 'Presto')",
 "('P4_f_z6 ', 'Splunk')",
 "('P4_f_z7 ', 'SAP HANA')",
 "('P4_f_z8 ', 'Hive')",
 "('P4_f_z9 ', 'Firebird')",
 "('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')",
 "('P4_g_a ', 'Amazon Web Services (AWS)')",
 "('P4_g_b ', 'Google Cloud (GCP)')",
 "('P4_g_c ', 'Azure (Microsoft)')",
 "('P4_g_d ', 'Oracle Cloud')",
 "('P4_g_e ', 'IBM')",
 "('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')",
 "('P4_g_g ', 'Cloud Própria')",
 "('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')",
 "('P4_h_a ', 'Microsoft PowerBI')",
 "('P4_h_b ', 'Qlik View/Qlik Sense')",
 "('P4_h_c ', 'Tableau')",
 "('P4_h_d ', 'Metabase')",
 "('P4_h_e ', 'Superset')",
 "('P4_h_f ', 'Redash')",
 "('P4_h_g ', 'MicroStrategy')",
 "('P4_h_h ', 'IBM Analytics/Cognos')",
 "('P4_h_i ', 'SAP Business Objects')",
 "('P4_h_j ', 'Oracle Business Intelligence')",
 "('P4_h_k ', 'Amazon QuickSight')",
 "('P4_h_l ', 'Salesforce/Einstein Analytics')",
 "('P4_h_m ', 'Mode')",
 "('P4_h_n ', 'Alteryx')",
 "('P4_h_o ', 'Birst')",
 "('P4_h_p ', 'Looker')",
 "('P4_h_q ', 'Google Data Studio')",
 "('P4_h_r ', 'SAS Visual Analytics')",
 "('P4_h_s ', 'Grafana')",
 "('P4_h_t ', 'TIBCO Spotfire')",
 "('P4_h_u ', 'Pentaho')",
 "('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')",
 "('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')",
 "('P5_b ', 'Qual oportunidade você está buscando?')",
 "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
 "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
 "('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')",
 "('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
 "('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
 "('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
 "('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
 "('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
 "('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
 "('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')",
 "('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
 "('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')",
 "('P6_b_a ', 'Scripts Python')",
 "('P6_b_b ', 'SQL & Stored Procedures')",
 "('P6_b_c ', 'Apache Airflow')",
 "('P6_b_d ', 'Luigi')",
 "('P6_b_e ', 'AWS Glue')",
 "('P6_b_f ', 'Talend')",
 "('P6_b_g ', 'Stitch')",
 "('P6_b_h ', 'Fivetran')",
 "('P6_b_i ', 'Google Dataflow')",
 "('P6_b_j ', 'Oracle Data Integrator')",
 "('P6_b_k ', 'IBM DataStage')",
 "('P6_b_l ', 'SAP BW ETL')",
 "('P6_b_m ', 'SQL Server Integration Services (SSIS)')",
 "('P6_b_n ', 'SAS Data Integration')",
 "('P6_b_o ', 'Qlik Sense')",
 "('P6_b_p ', 'Knime')",
 "('P6_b_q ', 'Não utilizo ferramentas de ETL')",
 "('P6_c ', 'Sua organização possui um Data Lake?')",
 "('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')",
 "('P6_e ', 'Sua organização possui um Data Warehouse?')",
 "('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')",
 "('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')",
 "('P6_g_a ', 'great_expectations')",
 "('P6_g_b ', 'dbt')",
 "('P6_g_c ', 'AWS Deequ')",
 "('P6_g_d ', 'Apache Griffin')",
 "('P6_g_e ', 'Datafold')",
 "('P6_g_f ', 'Amundsen')",
 "('P6_g_g ', 'Monte Carlo')",
 "('P6_g_h ', 'SODA')",
 "('P6_g_i ', 'Big Eye')",
 "('P6_g_j ', 'Data Band')",
 "('P6_g_k ', 'Anomalo')",
 "('P6_g_l ', 'Metaplane')",
 "('P6_g_m ', 'Acceldata')",
 "('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')",
 "('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
 "('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
 "('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
 "('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
 "('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
 "('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
 "('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')",
 "('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')",
 "('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')",
 "('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
 "('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')",
 "('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
 "('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
 "('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
 "('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')",
 "('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')",
 "('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')",
 "('P7_b_a ', 'Scripts Python')",
 "('P7_b_b ', 'SQL & Stored Procedures')",
 "('P7_b_c ', 'Apache Airflow')",
 "('P7_b_d ', 'Luigi')",
 "('P7_b_e ', 'AWS Glue')",
 "('P7_b_f ', 'Talend')",
 "('P7_b_g ', 'Stitch')",
 "('P7_b_h ', 'Fivetran')",
 "('P7_b_i ', 'Google Dataflow')",
 "('P7_b_j ', 'Oracle Data Integrator')",
 "('P7_b_k ', 'IBM DataStage')",
 "('P7_b_l ', 'SAP BW ETL')",
 "('P7_b_m ', 'SQL Server Integration Services (SSIS)')",
 "('P7_b_n ', 'SAS Data Integration')",
 "('P7_b_o ', 'Qlik Sense')",
 "('P7_b_p ', 'Knime')",
 "('P7_b_q ', 'Não utilizo ferramentas de ETL')",
 "('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')",
 "('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')",
 '(\'P7_c_b \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')',
 "('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')",
 "('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')",
 "('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')",
 "('P7_c_f ', 'Não sei informar.')",
 "('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')",
 "('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')",
 "('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
 "('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')",
 "('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
 "('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
 "('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
 "('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')",
 "('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
 "('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')",
 "('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
 "('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')",
 "('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
 "('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
 "('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')",
 "('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
 "('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')",
 "('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
 "('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
 "('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')",
 "('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')",
 "('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')",
 "('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')",
 "('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')",
 "('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')",
 "('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')",
 "('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')",
 "('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')",
 "('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')",
 "('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')",
 "('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')",
 "('P8_b_l ', 'Utilizo métodos de Visão Computacional')",
 "('P8_b_m ', 'Utilizo modelos de Detecção de Churn')",
 "('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')",
 "('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')",
 "('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')",
 "('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')",
 "('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')",
 "('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')",
 "('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')",
 "('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')",
 "('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')",
 "('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')",
 "('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')",
 "('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')",
 "('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')",
 "('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')",
 "('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')",
 "('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
 "('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
 "('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')",
 "('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
 "('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')",
 "('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')",
 "('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')",
 "('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
 "('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')",
 "('P9_a_a ', 'Blog/Medium do Data Hackers')",
 "('P9_a_b ', 'Podcast do Data Hackers')",
 "('P9_a_d ', 'Newsletter Semanal')",
 "('P9_a_e ', 'Canal do Slack')",
 "('P9_a_f ', 'Canal do Youtube do Data Hackers')",
 "('P9_a_g ', 'Ainda não conhecia o Data Hackers')"]

#Calcular o número de linhas por partes
total_lines = len(lines)
lines_per_part = total_lines // 8

#Segregar a lista em 8 partes
parts = [lines[i:i + lines_per_part] for i in range(0, total_lines, lines_per_part)]

#Printar cada parte
for i, part in enumerate(parts):
    print(f"Part {i + 1}:")
    for line in part:
        print(line)
    print()
# Out:
# Part 1:
# ('P0', 'id')
# ('P1_a ', 'Idade')
# ('P1_a_a ', 'Faixa idade')
# ('P1_b ', 'Genero')
# ('P1_e ', 'Estado onde mora')
# ('P1_e_a ', 'uf onde mora')
# ('P1_e_b ', 'Regiao onde mora')
# ('P1_g_b ', 'Regiao de origem')
# ('P1_g_c ', 'Mudou de Estado?')
# ('P1_h ', 'Nivel de Ensino')
# ('P1_i ', 'Área de Formação')
# ('P2_a ', 'Qual sua situação atual de trabalho?')
# ('P2_b ', 'Setor')
# ('P2_c ', 'Numero de Funcionarios')
# ('P2_d ', 'Gestor?')
# ('P2_e ', 'Cargo como Gestor')
# ('P2_f ', 'Cargo Atual')
# ('P2_g ', 'Nivel')
# ('P2_h ', 'Faixa salarial')
# ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')
# ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')
# ('P2_k ', 'Você está satisfeito na sua empresa atual?')
# ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')
# ('P2_l_a ', 'Falta de oportunidade de crescimento no emprego atual')
# ('P2_l_b ', 'Salário atual não corresponde ao mercado')
# ('P2_l_c ', 'Não tenho uma boa relação com meu líder/gestor')
# ('P2_l_d ', 'Gostaria de trabalhar em em outra área de atuação')
# ('P2_l_e ', 'Gostaria de receber mais benefícios')
# ('P2_l_f ', 'O clima de trabalho/ambiente não é bom')
# ('P2_l_g ', 'Falta de maturidade analítica na empresa')
# ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')
# ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')
# ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')
# ('P2_o_a ', 'Remuneração/Salário')
# ('P2_o_b ', 'Benefícios')
# ('P2_o_c ', 'Propósito do trabalho e da empresa')
# ('P2_o_d ', 'Flexibilidade de trabalho remoto')
# ('P2_o_e ', 'Ambiente e clima de trabalho')
# ('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')
# ('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')
# ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')
# ('P2_o_i ', 'Qualidade dos gestores e líderes')
# ('P2_o_j ', 'Reputação que a empresa tem no mercado')
# ('P2_q ', 'Atualmente qual a sua forma de trabalho?')
#
# Part 2:
# ('P2_r ', 'Qual a forma de trabalho ideal para você?')
# ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')
# ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')
# ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')
# ('P3_b_a ', 'Analytics Engineer')
# ('P3_b_b ', 'Engenharia de Dados/Data Engineer')
# ('P3_b_c ', 'Analista de Dados/Data Analyst')
# ('P3_b_d ', 'Cientista de Dados/Data Scientist')
# ('P3_b_e ', 'Database Administrator/DBA')
# ('P3_b_f ', 'Analista de Business Intelligence/BI')
# ('P3_b_g ', 'Arquiteto de Dados/Data Architect')
# ('P3_b_h ', 'Data Product Manager/DPM')
# ('P3_b_i ', 'Business Analyst')
# ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')
# ('P3_c_a ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')
# ('P3_c_b ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')
# ('P3_c_c ', 'Atração, seleção e contratação de talentos para o time de dados.')
# ('P3_c_d ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')
# ('P3_c_e ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')
# ('P3_c_f ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')
# ('P3_c_g ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')
# ('P3_c_h ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')
# ('P3_c_i ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')
# ('P3_c_j ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')
# ('P3_c_k ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')
# ('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')
# ('P3_d_ ', 'a Contratar novos talentos.')
# ('P3_d_ ', 'b Reter talentos.')
# ('P3_d_ ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')
# ('P3_d_ ', 'd Gestão de equipes no ambiente remoto.')
# ('P3_d_ ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')
# ('P3_d_ ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')
# ('P3_d_ ', 'g Conseguir processar e armazenar um alto volume de dados.')
# ('P3_d_ ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')
# ('P3_d_ ', 'i Desenvolver e manter modelos Machine Learning em produção.')
# ('P3_d_ ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')
# ('P3_d_ ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')
# ('P3_d_l ', 'Conseguir levar inovação para a empresa através dos dados.')
# ('P3_d_m ', 'Garantir retorno do investimento (ROI) em projetos de dados.')
# ('P3_d_n ', 'Dividir o tempo entre entregas técnicas e gestão.')
# ('P4_a_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')
# ('P4_a ', 'Atuacao')
# ('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')
# ('P4_b_a ', 'Dados relacionais (estruturados em bancos SQL)')
#
# Part 3:
# ('P4_b_b ', 'Dados armazenados em bancos NoSQL')
# ('P4_b_c ', 'Imagens')
# ('P4_b_d ', 'Textos/Documentos')
# ('P4_b_e ', 'Vídeos')
# ('P4_b_f ', 'Áudios')
# ('P4_b_g ', 'Planilhas')
# ('P4_b_h ', 'Dados georeferenciados')
# ('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')
# ('P4_c_a ', 'Dados relacionais (estruturados em bancos SQL)')
# ('P4_c_b ', 'Dados armazenados em bancos NoSQL')
# ('P4_c_c ', 'Imagens')
# ('P4_c_d ', 'Textos/Documentos')
# ('P4_c_e ', 'Vídeos')
# ('P4_c_f ', 'Áudios')
# ('P4_c_g ', 'Planilhas')
# ('P4_c_h ', 'Dados georeferenciados')
# ('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')
# ('P4_d_a ', 'SQL')
# ('P4_d_b ', 'R ')
# ('P4_d_c ', 'Python')
# ('P4_d_d ', 'C/C++/C#')
# ('P4_d_e ', '.NET')
# ('P4_d_f ', 'Java')
# ('P4_d_g ', 'Julia')
# ('P4_d_h ', 'SAS/Stata')
# ('P4_d_i ', 'Visual Basic/VBA')
# ('P4_d_j ', 'Scala')
# ('P4_d_k ', 'Matlab')
# ('P4_d_l ', 'PHP')
# ('P4_d_m ', 'Javascript')
# ('P4_d_n ', 'Não utilizo nenhuma linguagem')
# ('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')
# ('P4_e_a ', 'SQL')
# ('P4_e_b ', 'R ')
# ('P4_e_c ', 'Python')
# ('P4_e_d ', 'C/C++/C#')
# ('P4_e_e ', '.NET')
# ('P4_e_f ', 'Java')
# ('P4_e_g ', 'Julia')
# ('P4_e_h ', 'SAS/Stata')
# ('P4_e_i ', 'Visual Basic/VBA')
# ('P4_e_j ', 'Scala')
# ('P4_e_k ', 'Matlab')
# ('P4_e_l ', 'PHP')
#
# Part 4:
# ('P4_e_m ', 'Javascript')
# ('P4_e_n ', 'Não utilizo nenhuma linguagem')
# ('P4_f ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')
# ('P4_f_a ', 'MySQL')
# ('P4_f_b ', 'Oracle')
# ('P4_f_c ', 'SQL SERVER')
# ('P4_f_d ', 'SAP')
# ('P4_f_e ', 'Amazon Aurora ou RDS')
# ('P4_f_f ', 'Amazon DynamoDB')
# ('P4_f_g ', 'CoachDB')
# ('P4_f_h ', 'Cassandra')
# ('P4_f_i ', 'MongoDB')
# ('P4_f_j ', 'MariaDB')
# ('P4_f_k ', 'Datomic')
# ('P4_f_l ', 'S3')
# ('P4_f_m ', 'PostgreSQL')
# ('P4_f_n ', 'ElasticSearch')
# ('P4_f_o ', 'DB2')
# ('P4_f_p ', 'Microsoft Access')
# ('P4_f_q ', 'SQLite')
# ('P4_f_r ', 'Sybase')
# ('P4_f_s ', 'Firebase')
# ('P4_f_t ', 'Vertica')
# ('P4_f_u ', 'Redis')
# ('P4_f_v ', 'Neo4J')
# ('P4_f_x ', 'Google BigQuery')
# ('P4_f_y ', 'Google Firestore')
# ('P4_f_z ', 'Amazon Redshift')
# ('P4_f_z1 ', 'Amazon Athena')
# ('P4_f_z2 ', 'Snowflake')
# ('P4_f_z3 ', 'Databricks')
# ('P4_f_z4 ', 'HBase')
# ('P4_f_z5 ', 'Presto')
# ('P4_f_z6 ', 'Splunk')
# ('P4_f_z7 ', 'SAP HANA')
# ('P4_f_z8 ', 'Hive')
# ('P4_f_z9 ', 'Firebird')
# ('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')
# ('P4_g_a ', 'Amazon Web Services (AWS)')
# ('P4_g_b ', 'Google Cloud (GCP)')
# ('P4_g_c ', 'Azure (Microsoft)')
# ('P4_g_d ', 'Oracle Cloud')
# ('P4_g_e ', 'IBM')
# ('P4_g_f ', 'Servidores On Premise/Não utilizamos Cloud')
#
# Part 5:
# ('P4_g_g ', 'Cloud Própria')
# ('P4_h ', 'Quais as Ferramentas de Business Intelligence você utiliza no trabalho?')
# ('P4_h_a ', 'Microsoft PowerBI')
# ('P4_h_b ', 'Qlik View/Qlik Sense')
# ('P4_h_c ', 'Tableau')
# ('P4_h_d ', 'Metabase')
# ('P4_h_e ', 'Superset')
# ('P4_h_f ', 'Redash')
# ('P4_h_g ', 'MicroStrategy')
# ('P4_h_h ', 'IBM Analytics/Cognos')
# ('P4_h_i ', 'SAP Business Objects')
# ('P4_h_j ', 'Oracle Business Intelligence')
# ('P4_h_k ', 'Amazon QuickSight')
# ('P4_h_l ', 'Salesforce/Einstein Analytics')
# ('P4_h_m ', 'Mode')
# ('P4_h_n ', 'Alteryx')
# ('P4_h_o ', 'Birst')
# ('P4_h_p ', 'Looker')
# ('P4_h_q ', 'Google Data Studio')
# ('P4_h_r ', 'SAS Visual Analytics')
# ('P4_h_s ', 'Grafana')
# ('P4_h_t ', 'TIBCO Spotfire')
# ('P4_h_u ', 'Pentaho')
# ('P4_h_v ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')
# ('P4_h_x ', 'Não utilizo nenhuma ferramenta de BI no trabalho')
# ('P5_b ', 'Qual oportunidade você está buscando?')
# ('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')
# ('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')
# ('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')
# ('P6_a_a ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')
# ('P6_a_b ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')
# ('P6_a_c ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P6_a_d ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')
# ('P6_a_e ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')
# ('P6_a_f ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')
# ('P6_a_g ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')
# ('P6_a_h ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')
# ('P6_a_i ', 'Nenhuma das opções listadas refletem meu dia a dia.')
# ('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')
# ('P6_b_a ', 'Scripts Python')
# ('P6_b_b ', 'SQL & Stored Procedures')
# ('P6_b_c ', 'Apache Airflow')
# ('P6_b_d ', 'Luigi')
# ('P6_b_e ', 'AWS Glue')
#
# Part 6:
# ('P6_b_f ', 'Talend')
# ('P6_b_g ', 'Stitch')
# ('P6_b_h ', 'Fivetran')
# ('P6_b_i ', 'Google Dataflow')
# ('P6_b_j ', 'Oracle Data Integrator')
# ('P6_b_k ', 'IBM DataStage')
# ('P6_b_l ', 'SAP BW ETL')
# ('P6_b_m ', 'SQL Server Integration Services (SSIS)')
# ('P6_b_n ', 'SAS Data Integration')
# ('P6_b_o ', 'Qlik Sense')
# ('P6_b_p ', 'Knime')
# ('P6_b_q ', 'Não utilizo ferramentas de ETL')
# ('P6_c ', 'Sua organização possui um Data Lake?')
# ('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')
# ('P6_e ', 'Sua organização possui um Data Warehouse?')
# ('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')
# ('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')
# ('P6_g_a ', 'great_expectations')
# ('P6_g_b ', 'dbt')
# ('P6_g_c ', 'AWS Deequ')
# ('P6_g_d ', 'Apache Griffin')
# ('P6_g_e ', 'Datafold')
# ('P6_g_f ', 'Amundsen')
# ('P6_g_g ', 'Monte Carlo')
# ('P6_g_h ', 'SODA')
# ('P6_g_i ', 'Big Eye')
# ('P6_g_j ', 'Data Band')
# ('P6_g_k ', 'Anomalo')
# ('P6_g_l ', 'Metaplane')
# ('P6_g_m ', 'Acceldata')
# ('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')
# ('P6_h_a ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')
# ('P6_h_b ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')
# ('P6_h_c ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P6_h_d ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')
# ('P6_h_e ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')
# ('P6_h_f ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')
# ('P6_h_g ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')
# ('P6_h_h ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')
# ('P7_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')
# ('P7_a_a ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')
# ('P7_a_b ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')
# ('P7_a_c ', 'Utilizo API's para extrair dados e complementar minhas análises.')
# ('P7_a_d ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')
#
# Part 7:
# ('P7_a_e ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')
# ('P7_a_f ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')
# ('P7_a_g ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')
# ('P7_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS')
# ('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')
# ('P7_b_a ', 'Scripts Python')
# ('P7_b_b ', 'SQL & Stored Procedures')
# ('P7_b_c ', 'Apache Airflow')
# ('P7_b_d ', 'Luigi')
# ('P7_b_e ', 'AWS Glue')
# ('P7_b_f ', 'Talend')
# ('P7_b_g ', 'Stitch')
# ('P7_b_h ', 'Fivetran')
# ('P7_b_i ', 'Google Dataflow')
# ('P7_b_j ', 'Oracle Data Integrator')
# ('P7_b_k ', 'IBM DataStage')
# ('P7_b_l ', 'SAP BW ETL')
# ('P7_b_m ', 'SQL Server Integration Services (SSIS)')
# ('P7_b_n ', 'SAS Data Integration')
# ('P7_b_o ', 'Qlik Sense')
# ('P7_b_p ', 'Knime')
# ('P7_b_q ', 'Não utilizo ferramentas de ETL')
# ('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')
# ('P7_c_a ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')
# ('P7_c_b ', '""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.')
# ('P7_c_c ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')
# ('P7_c_d ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')
# ('P7_c_e ', 'Minha empresa não utiliza essas ferramentas.')
# ('P7_c_f ', 'Não sei informar.')
# ('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')
# ('P7_d_a ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')
# ('P7_d_b ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')
# ('P7_d_c ', 'Utilizando API's para extrair dados e complementar minhas análises.')
# ('P7_d_d ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')
# ('P7_d_e ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')
# ('P7_d_f ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')
# ('P7_d_g ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')
# ('P7_d_h ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')
# ('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')
# ('P8_a_a ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')
# ('P8_a_b ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')
# ('P8_a_c ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')
# ('P8_a_d ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')
# ('P8_a_e ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')
#
# Part 8:
# ('P8_a_f ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')
# ('P8_a_g ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')
# ('P8_a_h ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')
# ('P8_a_j ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')
# ('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')
# ('P8_b_a ', 'Utilizo modelos de regressão (linear, logística, GLM)')
# ('P8_b_b ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')
# ('P8_b_c ', 'Desenvolvo sistemas de recomendação (RecSys)')
# ('P8_b_d ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')
# ('P8_b_e ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')
# ('P8_b_f ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')
# ('P8_b_g ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')
# ('P8_b_h ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')
# ('P8_b_i ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')
# ('P8_b_j ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')
# ('P8_b_k ', 'Utilizo modelos de Machine Learning para detecção de fraude')
# ('P8_b_l ', 'Utilizo métodos de Visão Computacional')
# ('P8_b_m ', 'Utilizo modelos de Detecção de Churn')
# ('P8_c ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')
# ('P8_c_a ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')
# ('P8_c_b ', 'Planilhas (Excel, Google Sheets etc)')
# ('P8_c_c ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')
# ('P8_c_d ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')
# ('P8_c_e ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')
# ('P8_c_f ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')
# ('P8_c_g ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')
# ('P8_c_h ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')
# ('P8_c_i ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')
# ('P8_c_j ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')
# ('P8_c_k ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')
# ('P8_c_l ', 'Não utilizo nenhuma dessas ferramentas no meu dia a dia.')
# ('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')
# ('P8_d_a ', 'Coletando e limpando os dados que uso para análise e modelagem.')
# ('P8_d_b ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')
# ('P8_d_c ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')
# ('P8_d_d ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')
# ('P8_d_e ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')
# ('P8_d_f ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')
# ('P8_d_g ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')
# ('P8_d_h ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')
# ('P8_d_i ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')
# ('P9_a ', 'Quais das iniciativas do Data Hackers que você já acessou/acompanhou?')
# ('P9_a_a ', 'Blog/Medium do Data Hackers')
# ('P9_a_b ', 'Podcast do Data Hackers')
#
# Part 9:
# ('P9_a_d ', 'Newsletter Semanal')
# ('P9_a_e ', 'Canal do Slack')
# ('P9_a_f ', 'Canal do Youtube do Data Hackers')
# ('P9_a_g ', 'Ainda não conhecia o Data Hackers')

# %% [markdown]
# ##LIMPEZA DOS DADOS DATAFRAME 2021

# %% [markdown]
# ###REMOÇÃO DAS COLUNAS DESNECESSÁRIAS PARA O NOSSO PROJETO.

# %%
df_2021 = df_2021.drop(df_2021.columns[48:], axis=1)

# %%
df_2021 = df_2021.drop(df_2021.columns[0], axis=1)

# %%
df_2021 = df_2021.drop(df_2021.columns[-1], axis=1)

# %%
df_2021 = df_2021.drop(df_2021.columns[-1], axis=1)

# %%
df_2021 = df_2021.drop(df_2021.columns[5], axis=1)

# %%
# Removendo valores nulos com mais de 30%
df_2021 = df_2021.drop(df_2021.columns[5], axis=1)

# %%
# Removendo valores nulos com mais de 30%
df_2021 = df_2021.drop(df_2021.columns[12], axis=1)

# %%
# Removendo valores nulos com mais de 30%
df_2021 = df_2021.drop(df_2021.columns[18:26], axis=1)

# %%
df_2021 = df_2021.drop(df_2021.columns[18:20], axis=1)

# %%
# Colunas a serem removidas
colunas_eliminar1 = [
    "('P2_a ', 'Qual sua situação atual de trabalho?')",
    "('P2_d ', 'Gestor?')",
    "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
    "('P2_o_a ', 'Remuneração/Salário')",
    "('P2_o_b ', 'Benefícios')",
    "('P2_o_c ', 'Propósito do trabalho e da empresa')",
    "('P2_o_d ', 'Flexibilidade de trabalho remoto')",
    "('P2_o_e ', 'Ambiente e clima de trabalho')",
    "('P2_o_f ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
    "('P2_o_g ', 'Plano de carreira e oportunidades de crescimento profissional')"
]

# Remover as colunas especificadas
df_2021 = df_2021.drop(columns=colunas_eliminar1, axis=1)

# %% [markdown]
# ###RESULTADO DATAFRAME 2021 - DROP REALIZADO

# %%
df_2021
# Out:
#       ('P1_a ', 'Idade') ('P1_a_a ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                  38.00                      35-39           Masculino
# 1                  39.00                      35-39           Masculino
# 2                  30.00                      30-34           Masculino
# 3                  38.00                      35-39            Feminino
# 4                  36.00                      35-39           Masculino
# ...                  ...                        ...                 ...
# 2640               40.00                      40-44           Masculino
# 2641               27.00                      25-29           Masculino
# 2642               24.00                      22-24           Masculino
# 2643               38.00                      35-39           Masculino
# 2644               27.00                      25-29            Feminino
#
#      ('P1_e ', 'Estado onde mora') ('P1_e_a ', 'uf onde mora')  \
# 0                       Ceará (CE)                          CE
# 1                       Bahia (BA)                          BA
# 2              Santa Catarina (SC)                          SC
# 3                   São Paulo (SP)                          SP
# 4              Santa Catarina (SC)                          SC
# ...                            ...                         ...
# 2640                São Paulo (SP)                          SP
# 2641           Santa Catarina (SC)                          SC
# 2642           Santa Catarina (SC)                          SC
# 2643           Rio de Janeiro (RJ)                          RJ
# 2644             Minas Gerais (MG)                          MG
#
#       ('P1_g_c ', 'Mudou de Estado?') ('P1_h ', 'Nivel de Ensino')  \
# 0                                   0                Pós-graduação
# 1                                   1                Pós-graduação
# 2                                   0                Pós-graduação
# 3                                   0                Pós-graduação
# 4                                   0                Pós-graduação
# ...                               ...                          ...
# 2640                                1   Não tenho graduação formal
# 2641                                1        Graduação/Bacharelado
# 2642                                0        Graduação/Bacharelado
# 2643                                0        Graduação/Bacharelado
# 2644                                0                Pós-graduação
#
#                           ('P1_i ', 'Área de Formação')  \
# 0                                      Química / Física
# 1     Economia/ Administração / Contabilidade / Fina...
# 2     Computação / Engenharia de Software / Sistemas...
# 3                                                Outras
# 4                                    Outras Engenharias
# ...                                                 ...
# 2640                                                NaN
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras
#
#                   ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 0                          Marketing                        de 101 a 500
# 1                        Consultoria                            de 1 a 5
# 2                          Indústria                      de 1001 a 3000
# 3                           Serviços                      de 1001 a 3000
# 4                             Varejo                           de 6 a 10
# ...                              ...                                 ...
# 2640                             NaN                                 NaN
# 2641  Tecnologia/Fábrica de Software                       de 501 a 1000
# 2642  Tecnologia/Fábrica de Software                       Acima de 3000
# 2643                             NaN                                 NaN
# 2644                             NaN                                 NaN
#
#                ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 0                                   NaN                NaN
# 1                                   NaN                NaN
# 2                                   NaN                NaN
# 3                                   NaN                NaN
# 4                                   NaN                NaN
# ...                                 ...                ...
# 2640                                NaN                NaN
# 2641  Cientista de Dados/Data Scientist              Pleno
# 2642  Engenheiro de Dados/Data Engineer              Pleno
# 2643                                NaN                NaN
# 2644                                NaN                NaN
#
#            ('P2_h ', 'Faixa salarial')  \
# 0       de R$ 4.001/mês a R$ 6.000/mês
# 1       de R$ 6.001/mês a R$ 8.000/mês
# 2      de R$ 8.001/mês a R$ 12.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4      de R$ 8.001/mês a R$ 12.000/mês
# ...                                ...
# 2640                               NaN
# 2641    de R$ 6.001/mês a R$ 8.000/mês
# 2642    de R$ 6.001/mês a R$ 8.000/mês
# 2643                               NaN
# 2644                               NaN
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 0                                       Mais de 10 anos
# 1                                         de 2 a 3 anos
# 2                                         de 1 a 2 anos
# 3                                       Mais de 10 anos
# 4                                         de 1 a 2 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                      de 4 a 5 anos
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 0     Não tive experiência na área de TI/Engenharia ...
# 1     Não tive experiência na área de TI/Engenharia ...
# 2                                         de 2 a 3 anos
# 3                                        Menos de 1 ano
# 4                                         de 4 a 5 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 0                                                  1.00
# 1                                                  1.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               1.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#       ('P2_o_i ', 'Qualidade dos gestores e líderes')  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 2640                                              NaN
# 2641                                             1.00
# 2642                                             0.00
# 2643                                              NaN
# 2644                                              NaN
#
#       ('P2_o_j ', 'Reputação que a empresa tem no mercado')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 2640                                                NaN
# 2641                                               0.00
# 2642                                               0.00
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_q ', 'Atualmente qual a sua forma de trabalho?')  \
# 0                                Modelo 100% presencial
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2                                Modelo 100% presencial
# 3                                Modelo 100% presencial
# 4                                Modelo 100% presencial
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_r ', 'Qual a forma de trabalho ideal para você?')  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1                                    Modelo 100% remoto
# 2                                    Modelo 100% remoto
# 3     Modelo híbrido com dias fixos de trabalho pres...
# 4                                    Modelo 100% remoto
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#      ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')
# 0     Vou aceitar e retornar ao modelo 100% presencial.
# 1     Vou procurar outra oportunidade no modelo 100%...
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4     Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 2640                                                NaN
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
# 2643                                                NaN
# 2644                                                NaN
#
# [2645 rows x 22 columns]

# %% [markdown]
# ###RESULTADO DATAFRAME 2021 EM LISTA - DROP REALIZADO

# %%
df_2021.columns.tolist()
# Out:
# ["('P1_a ', 'Idade')",
#  "('P1_a_a ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_e ', 'Estado onde mora')",
#  "('P1_e_a ', 'uf onde mora')",
#  "('P1_g_c ', 'Mudou de Estado?')",
#  "('P1_h ', 'Nivel de Ensino')",
#  "('P1_i ', 'Área de Formação')",
#  "('P2_b ', 'Setor')",
#  "('P2_c ', 'Numero de Funcionarios')",
#  "('P2_f ', 'Cargo Atual')",
#  "('P2_g ', 'Nivel')",
#  "('P2_h ', 'Faixa salarial')",
#  "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#  "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#  "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
#  "('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')",
#  "('P2_o_i ', 'Qualidade dos gestores e líderes')",
#  "('P2_o_j ', 'Reputação que a empresa tem no mercado')",
#  "('P2_q ', 'Atualmente qual a sua forma de trabalho?')",
#  "('P2_r ', 'Qual a forma de trabalho ideal para você?')",
#  "('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')"]

# %% [markdown]
# ###CÁLCULO

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df_2021.isnull().sum() / len(df_2021)) * 100

# %%
# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# ('P1_a ', 'Idade')                                                                                                                        1.10
# ('P1_a_a ', 'Faixa idade')                                                                                                                0.00
# ('P1_b ', 'Genero')                                                                                                                       0.00
# ('P1_e ', 'Estado onde mora')                                                                                                             1.40
# ('P1_e_a ', 'uf onde mora')                                                                                                               1.40
# ('P1_g_c ', 'Mudou de Estado?')                                                                                                           0.00
# ('P1_h ', 'Nivel de Ensino')                                                                                                              0.00
# ('P1_i ', 'Área de Formação')                                                                                                             2.40
# ('P2_b ', 'Setor')                                                                                                                       10.60
# ('P2_c ', 'Numero de Funcionarios')                                                                                                      10.60
# ('P2_f ', 'Cargo Atual')                                                                                                                 29.80
# ('P2_g ', 'Nivel')                                                                                                                       29.80
# ('P2_h ', 'Faixa salarial')                                                                                                              10.60
# ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')                                                                      10.60
# ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')   10.60
# ('P2_k ', 'Você está satisfeito na sua empresa atual?')                                                                                  10.70
# ('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')                                                                     10.80
# ('P2_o_i ', 'Qualidade dos gestores e líderes')                                                                                          10.80
# ('P2_o_j ', 'Reputação que a empresa tem no mercado')                                                                                    10.80
# ('P2_q ', 'Atualmente qual a sua forma de trabalho?')                                                                                    10.60
# ('P2_r ', 'Qual a forma de trabalho ideal para você?')                                                                                   10.60
# ('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')                                                  10.60
# dtype: float64

# %% [markdown]
# ##RENOMEANDO AS COLUNAS DO DATAFRAME 2021

# %%
# Define o mapeamento das colunas
column_mapping2021 = {
    "('P1_a ', 'Idade')": "Idade",
    "('P1_a_a ', 'Faixa idade')": "Faixa idade",
    "('P1_b ', 'Genero')": "Genero",
    "('P1_e ', 'Estado onde mora')": "Estado onde mora",
    "('P1_e_a ', 'uf onde mora')": "UF onde mora",
    "('P1_g_c ', 'Mudou de Estado?')": "Mudou de Estado?",
    "('P1_h ', 'Nivel de Ensino')": "Nivel de Ensino",
    "('P1_i ', 'Área de Formação')": "Área de Formação",
    "('P2_b ', 'Setor')": "Setor",
    "('P2_c ', 'Numero de Funcionarios')": "Número de Funcionários",
    "('P2_f ', 'Cargo Atual')": "Cargo Atual",
    "('P2_g ', 'Nivel')": "Nível",
    "('P2_h ', 'Faixa salarial')": "Faixa salarial",
    "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')": "Experiência na área de dados",
    "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')": "Experiência prévia em TI/Engenharia de Software",
    "('P2_k ', 'Você está satisfeito na sua empresa atual?')": "Satisfação com a empresa atual",
    "('P2_o_h ', 'Maturidade da empresa em termos de tecnologia e dados')": "Maturidade em tecnologia e dados",
    "('P2_o_i ', 'Qualidade dos gestores e líderes')": "Qualidade dos gestores e líderes",
    "('P2_o_j ', 'Reputação que a empresa tem no mercado')": "Reputação da empresa no mercado",
    "('P2_q ', 'Atualmente qual a sua forma de trabalho?')": "Forma de trabalho atual",
    "('P2_r ', 'Qual a forma de trabalho ideal para você?')": "Forma de trabalho ideal",
    "('P2_s ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')": "Atitude em caso de modelo 100% presencial"
}

# Renomeia as colunas
df_2021.rename(columns=column_mapping2021, inplace=True)

# Imprime o DataFrame para verificar as alterações
print(df_2021)
# Out:
#       Idade Faixa idade     Genero     Estado onde mora UF onde mora  \
# 0     38.00       35-39  Masculino           Ceará (CE)           CE
# 1     39.00       35-39  Masculino           Bahia (BA)           BA
# 2     30.00       30-34  Masculino  Santa Catarina (SC)           SC
# 3     38.00       35-39   Feminino       São Paulo (SP)           SP
# 4     36.00       35-39  Masculino  Santa Catarina (SC)           SC
# ...     ...         ...        ...                  ...          ...
# 2640  40.00       40-44  Masculino       São Paulo (SP)           SP
# 2641  27.00       25-29  Masculino  Santa Catarina (SC)           SC
# 2642  24.00       22-24  Masculino  Santa Catarina (SC)           SC
# 2643  38.00       35-39  Masculino  Rio de Janeiro (RJ)           RJ
# 2644  27.00       25-29   Feminino    Minas Gerais (MG)           MG
#
#       Mudou de Estado?             Nivel de Ensino  \
# 0                    0               Pós-graduação
# 1                    1               Pós-graduação
# 2                    0               Pós-graduação
# 3                    0               Pós-graduação
# 4                    0               Pós-graduação
# ...                ...                         ...
# 2640                 1  Não tenho graduação formal
# 2641                 1       Graduação/Bacharelado
# 2642                 0       Graduação/Bacharelado
# 2643                 0       Graduação/Bacharelado
# 2644                 0               Pós-graduação
#
#                                        Área de Formação  \
# 0                                      Química / Física
# 1     Economia/ Administração / Contabilidade / Fina...
# 2     Computação / Engenharia de Software / Sistemas...
# 3                                                Outras
# 4                                    Outras Engenharias
# ...                                                 ...
# 2640                                                NaN
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras
#
#                                Setor Número de Funcionários  \
# 0                          Marketing           de 101 a 500
# 1                        Consultoria               de 1 a 5
# 2                          Indústria         de 1001 a 3000
# 3                           Serviços         de 1001 a 3000
# 4                             Varejo              de 6 a 10
# ...                              ...                    ...
# 2640                             NaN                    NaN
# 2641  Tecnologia/Fábrica de Software          de 501 a 1000
# 2642  Tecnologia/Fábrica de Software          Acima de 3000
# 2643                             NaN                    NaN
# 2644                             NaN                    NaN
#
#                             Cargo Atual  Nível  \
# 0                                   NaN    NaN
# 1                                   NaN    NaN
# 2                                   NaN    NaN
# 3                                   NaN    NaN
# 4                                   NaN    NaN
# ...                                 ...    ...
# 2640                                NaN    NaN
# 2641  Cientista de Dados/Data Scientist  Pleno
# 2642  Engenheiro de Dados/Data Engineer  Pleno
# 2643                                NaN    NaN
# 2644                                NaN    NaN
#
#                         Faixa salarial Experiência na área de dados  \
# 0       de R$ 4.001/mês a R$ 6.000/mês              Mais de 10 anos
# 1       de R$ 6.001/mês a R$ 8.000/mês                de 2 a 3 anos
# 2      de R$ 8.001/mês a R$ 12.000/mês                de 1 a 2 anos
# 3     de R$ 12.001/mês a R$ 16.000/mês              Mais de 10 anos
# 4      de R$ 8.001/mês a R$ 12.000/mês                de 1 a 2 anos
# ...                                ...                          ...
# 2640                               NaN                          NaN
# 2641    de R$ 6.001/mês a R$ 8.000/mês                de 4 a 5 anos
# 2642    de R$ 6.001/mês a R$ 8.000/mês                de 2 a 3 anos
# 2643                               NaN                          NaN
# 2644                               NaN                          NaN
#
#         Experiência prévia em TI/Engenharia de Software  \
# 0     Não tive experiência na área de TI/Engenharia ...
# 1     Não tive experiência na área de TI/Engenharia ...
# 2                                         de 2 a 3 anos
# 3                                        Menos de 1 ano
# 4                                         de 4 a 5 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#       Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 0                               1.00                              0.00
# 1                               1.00                              0.00
# 2                               0.00                              0.00
# 3                               0.00                              0.00
# 4                               0.00                              1.00
# ...                              ...                               ...
# 2640                             NaN                               NaN
# 2641                            1.00                              0.00
# 2642                            0.00                              0.00
# 2643                             NaN                               NaN
# 2644                             NaN                               NaN
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 0                                 0.00                             0.00
# 1                                 0.00                             0.00
# 2                                 0.00                             0.00
# 3                                 0.00                             0.00
# 4                                 0.00                             0.00
# ...                                ...                              ...
# 2640                               NaN                              NaN
# 2641                              1.00                             0.00
# 2642                              0.00                             0.00
# 2643                               NaN                              NaN
# 2644                               NaN                              NaN
#
#                                 Forma de trabalho atual  \
# 0                                Modelo 100% presencial
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2                                Modelo 100% presencial
# 3                                Modelo 100% presencial
# 4                                Modelo 100% presencial
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#                                 Forma de trabalho ideal  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1                                    Modelo 100% remoto
# 2                                    Modelo 100% remoto
# 3     Modelo híbrido com dias fixos de trabalho pres...
# 4                                    Modelo 100% remoto
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#               Atitude em caso de modelo 100% presencial
# 0     Vou aceitar e retornar ao modelo 100% presencial.
# 1     Vou procurar outra oportunidade no modelo 100%...
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4     Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 2640                                                NaN
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
# 2643                                                NaN
# 2644                                                NaN
#
# [2645 rows x 22 columns]

# %%
df_2021
# Out:
#       Idade Faixa idade     Genero     Estado onde mora UF onde mora  \
# 0     38.00       35-39  Masculino           Ceará (CE)           CE
# 1     39.00       35-39  Masculino           Bahia (BA)           BA
# 2     30.00       30-34  Masculino  Santa Catarina (SC)           SC
# 3     38.00       35-39   Feminino       São Paulo (SP)           SP
# 4     36.00       35-39  Masculino  Santa Catarina (SC)           SC
# ...     ...         ...        ...                  ...          ...
# 2640  40.00       40-44  Masculino       São Paulo (SP)           SP
# 2641  27.00       25-29  Masculino  Santa Catarina (SC)           SC
# 2642  24.00       22-24  Masculino  Santa Catarina (SC)           SC
# 2643  38.00       35-39  Masculino  Rio de Janeiro (RJ)           RJ
# 2644  27.00       25-29   Feminino    Minas Gerais (MG)           MG
#
#       Mudou de Estado?             Nivel de Ensino  \
# 0                    0               Pós-graduação
# 1                    1               Pós-graduação
# 2                    0               Pós-graduação
# 3                    0               Pós-graduação
# 4                    0               Pós-graduação
# ...                ...                         ...
# 2640                 1  Não tenho graduação formal
# 2641                 1       Graduação/Bacharelado
# 2642                 0       Graduação/Bacharelado
# 2643                 0       Graduação/Bacharelado
# 2644                 0               Pós-graduação
#
#                                        Área de Formação  \
# 0                                      Química / Física
# 1     Economia/ Administração / Contabilidade / Fina...
# 2     Computação / Engenharia de Software / Sistemas...
# 3                                                Outras
# 4                                    Outras Engenharias
# ...                                                 ...
# 2640                                                NaN
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
# 2643  Computação / Engenharia de Software / Sistemas...
# 2644                                             Outras
#
#                                Setor Número de Funcionários  \
# 0                          Marketing           de 101 a 500
# 1                        Consultoria               de 1 a 5
# 2                          Indústria         de 1001 a 3000
# 3                           Serviços         de 1001 a 3000
# 4                             Varejo              de 6 a 10
# ...                              ...                    ...
# 2640                             NaN                    NaN
# 2641  Tecnologia/Fábrica de Software          de 501 a 1000
# 2642  Tecnologia/Fábrica de Software          Acima de 3000
# 2643                             NaN                    NaN
# 2644                             NaN                    NaN
#
#                             Cargo Atual  Nível  \
# 0                                   NaN    NaN
# 1                                   NaN    NaN
# 2                                   NaN    NaN
# 3                                   NaN    NaN
# 4                                   NaN    NaN
# ...                                 ...    ...
# 2640                                NaN    NaN
# 2641  Cientista de Dados/Data Scientist  Pleno
# 2642  Engenheiro de Dados/Data Engineer  Pleno
# 2643                                NaN    NaN
# 2644                                NaN    NaN
#
#                         Faixa salarial Experiência na área de dados  \
# 0       de R$ 4.001/mês a R$ 6.000/mês              Mais de 10 anos
# 1       de R$ 6.001/mês a R$ 8.000/mês                de 2 a 3 anos
# 2      de R$ 8.001/mês a R$ 12.000/mês                de 1 a 2 anos
# 3     de R$ 12.001/mês a R$ 16.000/mês              Mais de 10 anos
# 4      de R$ 8.001/mês a R$ 12.000/mês                de 1 a 2 anos
# ...                                ...                          ...
# 2640                               NaN                          NaN
# 2641    de R$ 6.001/mês a R$ 8.000/mês                de 4 a 5 anos
# 2642    de R$ 6.001/mês a R$ 8.000/mês                de 2 a 3 anos
# 2643                               NaN                          NaN
# 2644                               NaN                          NaN
#
#         Experiência prévia em TI/Engenharia de Software  \
# 0     Não tive experiência na área de TI/Engenharia ...
# 1     Não tive experiência na área de TI/Engenharia ...
# 2                                         de 2 a 3 anos
# 3                                        Menos de 1 ano
# 4                                         de 4 a 5 anos
# ...                                                 ...
# 2640                                                NaN
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
# 2643                                                NaN
# 2644                                                NaN
#
#       Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 0                               1.00                              0.00
# 1                               1.00                              0.00
# 2                               0.00                              0.00
# 3                               0.00                              0.00
# 4                               0.00                              1.00
# ...                              ...                               ...
# 2640                             NaN                               NaN
# 2641                            1.00                              0.00
# 2642                            0.00                              0.00
# 2643                             NaN                               NaN
# 2644                             NaN                               NaN
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 0                                 0.00                             0.00
# 1                                 0.00                             0.00
# 2                                 0.00                             0.00
# 3                                 0.00                             0.00
# 4                                 0.00                             0.00
# ...                                ...                              ...
# 2640                               NaN                              NaN
# 2641                              1.00                             0.00
# 2642                              0.00                             0.00
# 2643                               NaN                              NaN
# 2644                               NaN                              NaN
#
#                                 Forma de trabalho atual  \
# 0                                Modelo 100% presencial
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2                                Modelo 100% presencial
# 3                                Modelo 100% presencial
# 4                                Modelo 100% presencial
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#                                 Forma de trabalho ideal  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1                                    Modelo 100% remoto
# 2                                    Modelo 100% remoto
# 3     Modelo híbrido com dias fixos de trabalho pres...
# 4                                    Modelo 100% remoto
# ...                                                 ...
# 2640                                                NaN
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
# 2643                                                NaN
# 2644                                                NaN
#
#               Atitude em caso de modelo 100% presencial
# 0     Vou aceitar e retornar ao modelo 100% presencial.
# 1     Vou procurar outra oportunidade no modelo 100%...
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4     Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 2640                                                NaN
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
# 2643                                                NaN
# 2644                                                NaN
#
# [2645 rows x 22 columns]

# %% [markdown]
# ##CHECAGEM DO TIPO DOS DADOS DO DATAFRAME 2021

# %%
# Comando usado neste momento para verificar o balanceamento do dataframe
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2645 entries, 0 to 2644
# Data columns (total 22 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Idade                                            2617 non-null   float64
#  1   Faixa idade                                      2645 non-null   object
#  2   Genero                                           2645 non-null   object
#  3   Estado onde mora                                 2609 non-null   object
#  4   UF onde mora                                     2609 non-null   object
#  5   Mudou de Estado?                                 2645 non-null   int64
#  6   Nivel de Ensino                                  2645 non-null   object
#  7   Área de Formação                                 2581 non-null   object
#  8   Setor                                            2365 non-null   object
#  9   Número de Funcionários                           2365 non-null   object
#  10  Cargo Atual                                      1857 non-null   object
#  11  Nível                                            1857 non-null   object
#  12  Faixa salarial                                   2365 non-null   object
#  13  Experiência na área de dados                     2365 non-null   object
#  14  Experiência prévia em TI/Engenharia de Software  2365 non-null   object
#  15  Satisfação com a empresa atual                   2362 non-null   float64
#  16  Maturidade em tecnologia e dados                 2360 non-null   float64
#  17  Qualidade dos gestores e líderes                 2360 non-null   float64
#  18  Reputação da empresa no mercado                  2360 non-null   float64
#  19  Forma de trabalho atual                          2365 non-null   object
#  20  Forma de trabalho ideal                          2365 non-null   object
#  21  Atitude em caso de modelo 100% presencial        2365 non-null   object
# dtypes: float64(5), int64(1), object(16)
# memory usage: 454.7+ KB

# %%
# Remover linhas com valores não finitos na coluna "Idade"
df_2021 = df_2021.dropna(subset=["Idade"])

# Converter a coluna para o tipo inteiro
df_2021["Idade"] = df_2021["Idade"].astype(int)

# Verificar os tipos de dados após a conversão
print(df_2021.dtypes)
# Out:
# Idade                                                int64
# Faixa idade                                         object
# Genero                                              object
# Estado onde mora                                    object
# UF onde mora                                        object
# Mudou de Estado?                                     int64
# Nivel de Ensino                                     object
# Área de Formação                                    object
# Setor                                               object
# Número de Funcionários                              object
# Cargo Atual                                         object
# Nível                                               object
# Faixa salarial                                      object
# Experiência na área de dados                        object
# Experiência prévia em TI/Engenharia de Software     object
# Satisfação com a empresa atual                     float64
# Maturidade em tecnologia e dados                   float64
# Qualidade dos gestores e líderes                   float64
# Reputação da empresa no mercado                    float64
# Forma de trabalho atual                             object
# Forma de trabalho ideal                             object
# Atitude em caso de modelo 100% presencial           object
# dtype: object
# <ipython-input-25-cab64d177495>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Idade"] = df_2021["Idade"].astype(int)

# %%
import numpy as np

# Substituir valores não finitos por um valor padrão (por exemplo, 0)
df_2021["Maturidade em tecnologia e dados"].fillna(0, inplace=True)

# Agora, converta para int64
df_2021["Maturidade em tecnologia e dados"] = df_2021["Maturidade em tecnologia e dados"].astype("int64")
# Out:
# <ipython-input-26-0ff214752d41>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Maturidade em tecnologia e dados"].fillna(0, inplace=True)
# <ipython-input-26-0ff214752d41>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Maturidade em tecnologia e dados"] = df_2021["Maturidade em tecnologia e dados"].astype("int64")

# %%
# Converter a série para o tipo Object
df_2021["Estado onde mora"] = df_2021["Estado onde mora"].astype(object)
# Out:
# <ipython-input-27-5a8b5548d414>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Estado onde mora"] = df_2021["Estado onde mora"].astype(object)

# %%
# Converter a série para o tipo bool
df_2021["Mudou de Estado?"] = df_2021["Mudou de Estado?"].astype(bool)
# Out:
# <ipython-input-28-d0ae8a8a13a2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Mudou de Estado?"] = df_2021["Mudou de Estado?"].astype(bool)

# %% [markdown]
# ##DROPANDO AS LINHAS VAZIAS DATAFRAME 2021

# %%
df_2021.dropna(inplace=True)
# Out:
# <ipython-input-29-196d8634182a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021.dropna(inplace=True)

# %%
# Verificar se há valores nulos na coluna "Satisfação com a empresa atual"
print(df_2021["Satisfação com a empresa atual"].isnull().sum())

# Se houver valores nulos, preencha-os com um valor padrão
df_2021["Satisfação com a empresa atual"].fillna(False, inplace=True)

# Converter a coluna para o tipo bool
df_2021["Satisfação com a empresa atual"] = df_2021["Satisfação com a empresa atual"].astype(bool)
# Out:
# 0
# <ipython-input-30-c7c78edba8f1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Satisfação com a empresa atual"].fillna(False, inplace=True)
# <ipython-input-30-c7c78edba8f1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021["Satisfação com a empresa atual"] = df_2021["Satisfação com a empresa atual"].astype(bool)

# %%
df_2021.isna().sum()
# Out:
# Idade                                              0
# Faixa idade                                        0
# Genero                                             0
# Estado onde mora                                   0
# UF onde mora                                       0
# Mudou de Estado?                                   0
# Nivel de Ensino                                    0
# Área de Formação                                   0
# Setor                                              0
# Número de Funcionários                             0
# Cargo Atual                                        0
# Nível                                              0
# Faixa salarial                                     0
# Experiência na área de dados                       0
# Experiência prévia em TI/Engenharia de Software    0
# Satisfação com a empresa atual                     0
# Maturidade em tecnologia e dados                   0
# Qualidade dos gestores e líderes                   0
# Reputação da empresa no mercado                    0
# Forma de trabalho atual                            0
# Forma de trabalho ideal                            0
# Atitude em caso de modelo 100% presencial          0
# dtype: int64

# %%
# Definição do DataFrame df_2021

# Definição do esquema de validação
schema = pa.DataFrameSchema({
    'Idade': pa.Column(pa.Int64),
    'Faixa idade': pa.Column(pa.String),
    'Genero': pa.Column(pa.String),
    'Estado onde mora': pa.Column(pa.String),
    'UF onde mora': pa.Column(pa.String),
    'Mudou de Estado?': pa.Column(pa.Bool),
    'Nível': pa.Column(pa.String),  # Atualizei o nome da coluna para 'Nível'
    'Área de Formação': pa.Column(pa.String),
    'Setor': pa.Column(pa.String),
    'Número de Funcionários': pa.Column(pa.String),
    'Cargo Atual': pa.Column(pa.String),
    'Faixa salarial': pa.Column(pa.String),
    'Experiência na área de dados': pa.Column(pa.String),
    'Experiência prévia em TI/Engenharia de Software': pa.Column(pa.String),
    'Satisfação com a empresa atual': pa.Column(pa.Bool),
    'Maturidade em tecnologia e dados': pa.Column(pa.Int64),
    'Qualidade dos gestores e líderes': pa.Column(pa.Float64),
    'Reputação da empresa no mercado': pa.Column(pa.Float64),
    'Forma de trabalho atual': pa.Column(pa.String),
    'Forma de trabalho ideal': pa.Column(pa.String),
    'Atitude em caso de modelo 100% presencial': pa.Column(pa.String)
})

# Validar o DataFrame
schema.validate(df_2021)
# Out:
#       Idade Faixa idade     Genero        Estado onde mora UF onde mora  \
# 482      32       30-34  Masculino             Paraná (PR)           PR
# 483      28       25-29   Feminino  Rio Grande do Sul (RS)           RS
# 484      46       45-49   Feminino             Paraná (PR)           PR
# 485      35       35-39   Feminino       Minas Gerais (MG)           MG
# 486      27       25-29  Masculino  Rio Grande do Sul (RS)           RS
# ...     ...         ...        ...                     ...          ...
# 2635     27       25-29   Feminino     Rio de Janeiro (RJ)           RJ
# 2637     34       30-34  Masculino     Rio de Janeiro (RJ)           RJ
# 2639     34       30-34  Masculino     Santa Catarina (SC)           SC
# 2641     27       25-29  Masculino     Santa Catarina (SC)           SC
# 2642     24       22-24  Masculino     Santa Catarina (SC)           SC
#
#       Mudou de Estado?         Nivel de Ensino  \
# 482              False   Graduação/Bacharelado
# 483               True           Pós-graduação
# 484               True                Mestrado
# 485              False           Pós-graduação
# 486              False   Graduação/Bacharelado
# ...                ...                     ...
# 2635              True  Estudante de Graduação
# 2637             False                Mestrado
# 2639              True           Pós-graduação
# 2641              True   Graduação/Bacharelado
# 2642             False   Graduação/Bacharelado
#
#                                        Área de Formação  \
# 482   Computação / Engenharia de Software / Sistemas...
# 483   Computação / Engenharia de Software / Sistemas...
# 484   Computação / Engenharia de Software / Sistemas...
# 485   Computação / Engenharia de Software / Sistemas...
# 486                                  Outras Engenharias
# ...                                                 ...
# 2635                                 Outras Engenharias
# 2637                                 Outras Engenharias
# 2639                                   Ciências Sociais
# 2641  Estatística/ Matemática / Matemática Computaci...
# 2642  Computação / Engenharia de Software / Sistemas...
#
#                                Setor Número de Funcionários  \
# 482   Tecnologia/Fábrica de Software           de 101 a 500
# 483               Finanças ou Bancos           de 101 a 500
# 484                    Setor Público          Acima de 3000
# 485                         Educação         de 1001 a 3000
# 486                        Marketing             de 11 a 50
# ...                              ...                    ...
# 2635                       Indústria           de 101 a 500
# 2637                         Energia          Acima de 3000
# 2639                   Área da Saúde           de 101 a 500
# 2641  Tecnologia/Fábrica de Software          de 501 a 1000
# 2642  Tecnologia/Fábrica de Software          Acima de 3000
#
#                                        Cargo Atual   Nível  \
# 482              Engenheiro de Dados/Data Engineer  Sênior
# 483              Cientista de Dados/Data Scientist   Pleno
# 484                                        Técnico  Júnior
# 485   Analista de BI/BI Analyst/Analytics Engineer   Pleno
# 486              Engenheiro de Dados/Data Engineer   Pleno
# ...                                            ...     ...
# 2635  Analista de BI/BI Analyst/Analytics Engineer  Júnior
# 2637           Outras Engenharias (não inclui dev)   Pleno
# 2639  Analista de BI/BI Analyst/Analytics Engineer  Júnior
# 2641             Cientista de Dados/Data Scientist   Pleno
# 2642             Engenheiro de Dados/Data Engineer   Pleno
#
#                         Faixa salarial Experiência na área de dados  \
# 482     de R$ 6.001/mês a R$ 8.000/mês               Menos de 1 ano
# 483     de R$ 6.001/mês a R$ 8.000/mês               de 6 a 10 anos
# 484     de R$ 4.001/mês a R$ 6.000/mês               Menos de 1 ano
# 485     de R$ 4.001/mês a R$ 6.000/mês                de 1 a 2 anos
# 486     de R$ 6.001/mês a R$ 8.000/mês                de 4 a 5 anos
# ...                                ...                          ...
# 2635    de R$ 1.001/mês a R$ 2.000/mês                de 1 a 2 anos
# 2637  de R$ 25.001/mês a R$ 30.000/mês               Menos de 1 ano
# 2639    de R$ 4.001/mês a R$ 6.000/mês                de 1 a 2 anos
# 2641    de R$ 6.001/mês a R$ 8.000/mês                de 4 a 5 anos
# 2642    de R$ 6.001/mês a R$ 8.000/mês                de 2 a 3 anos
#
#         Experiência prévia em TI/Engenharia de Software  \
# 482                                     Mais de 10 anos
# 483                                       de 4 a 5 anos
# 484   Não tive experiência na área de TI/Engenharia ...
# 485                                      de 6 a 10 anos
# 486   Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 2635                                     Menos de 1 ano
# 2637  Não tive experiência na área de TI/Engenharia ...
# 2639  Não tive experiência na área de TI/Engenharia ...
# 2641                                     Menos de 1 ano
# 2642                                      de 2 a 3 anos
#
#       Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 482                             True                                 0
# 483                             True                                 0
# 484                            False                                 1
# 485                             True                                 0
# 486                             True                                 0
# ...                              ...                               ...
# 2635                            True                                 1
# 2637                           False                                 0
# 2639                            True                                 0
# 2641                            True                                 0
# 2642                           False                                 0
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 482                               0.00                             0.00
# 483                               0.00                             0.00
# 484                               0.00                             0.00
# 485                               0.00                             0.00
# 486                               1.00                             0.00
# ...                                ...                              ...
# 2635                              0.00                             0.00
# 2637                              0.00                             0.00
# 2639                              0.00                             1.00
# 2641                              1.00                             0.00
# 2642                              0.00                             0.00
#
#                                 Forma de trabalho atual  \
# 482                                  Modelo 100% remoto
# 483                                  Modelo 100% remoto
# 484                                  Modelo 100% remoto
# 485   Modelo híbrido flexível (o funcionário tem lib...
# 486                                  Modelo 100% remoto
# ...                                                 ...
# 2635  Modelo híbrido flexível (o funcionário tem lib...
# 2637                                 Modelo 100% remoto
# 2639                             Modelo 100% presencial
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
#
#                                 Forma de trabalho ideal  \
# 482   Modelo híbrido flexível (o funcionário tem lib...
# 483   Modelo híbrido flexível (o funcionário tem lib...
# 484                                  Modelo 100% remoto
# 485   Modelo híbrido flexível (o funcionário tem lib...
# 486                                  Modelo 100% remoto
# ...                                                 ...
# 2635  Modelo híbrido flexível (o funcionário tem lib...
# 2637                                 Modelo 100% remoto
# 2639  Modelo híbrido flexível (o funcionário tem lib...
# 2641                             Modelo 100% presencial
# 2642                                 Modelo 100% remoto
#
#               Atitude em caso de modelo 100% presencial
# 482   Vou procurar outra oportunidade no modelo híbr...
# 483   Vou procurar outra oportunidade no modelo híbr...
# 484   Vou procurar outra oportunidade no modelo 100%...
# 485   Vou aceitar e retornar ao modelo 100% presencial.
# 486   Vou procurar outra oportunidade no modelo 100%...
# ...                                                 ...
# 2635  Vou procurar outra oportunidade no modelo híbr...
# 2637  Vou procurar outra oportunidade no modelo 100%...
# 2639  Vou aceitar e retornar ao modelo 100% presencial.
# 2641  Vou aceitar e retornar ao modelo 100% presencial.
# 2642  Vou procurar outra oportunidade no modelo 100%...
#
# [1785 rows x 22 columns]

# %% [markdown]
# #<font color ="cyan">EXPORTANDO DATAFRAME 2021 - TRATADO (CSV)</font>

# %%
# Exportação para google drive.
df_2021.to_csv('DF_2021_tratado.csv')

# %% [markdown]
# #<font color ="cyan">ANÁLISE EXPLORATÓRIA DO DATAFRAME 2021 (CSV)</font>

# %%
# Qual é a média de salário por gênero?
df_2021.groupby('Genero')['Idade'].sum().sort_values(ascending=False).head(10).plot(kind='barh', color='skyblue')
plt.xlabel('Salário')
plt.ylabel('Genero')
plt.title('Média Salarial por Genero')
plt.show()

# %%
#Qual é a distribuição de salários por faixa etária?
df_2021.groupby('Faixa salarial')['Faixa idade'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Salário / Idade')
plt.ylabel('Quantidade')
plt.title('Salário por Faixa Etária')
plt.show()

# %%
#Qual é a média de anos de experiência profissional por setor?
df_2021.groupby('Experiência na área de dados')['Setor'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Experiência na área de dados  Setor
# de 2 a 3 anos                 Tecnologia/Fábrica de Software    121
# Menos de 1 ano                Tecnologia/Fábrica de Software    100
# de 1 a 2 anos                 Tecnologia/Fábrica de Software     94
# de 2 a 3 anos                 Finanças ou Bancos                 78
# de 1 a 2 anos                 Finanças ou Bancos                 74
# de 4 a 5 anos                 Tecnologia/Fábrica de Software     66
# Menos de 1 ano                Finanças ou Bancos                 61
# de 4 a 5 anos                 Finanças ou Bancos                 51
# de 6 a 10 anos                Tecnologia/Fábrica de Software     44
# Mais de 10 anos               Tecnologia/Fábrica de Software     34
# Name: Setor, dtype: int64

# %%
#Como a média de salário varia entre diferentes níveis de educação?
df_2021.groupby('Faixa salarial')['Nivel de Ensino'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar', color='gray')
plt.xlabel('Salário x Educação')
plt.ylabel('Quantidade')
plt.title('Níveis de Educação')
plt.show()

# %% [markdown]
# #<font color ="cyan">GRÁFICOS USANDO MATPLOTLIB DATAFRAME 2021</font>

# %%
# Histograma de Idade
plt.hist(df_2021['Idade'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Distribuição da Idade dos Trabalhadores')
plt.show()

# %%
# Medidas de Tendência Central
media_idade = df_2021['Idade'].mean()
mediana_idade = df_2021['Idade'].median()
moda_idade = df_2021['Idade'].mode().values[0]

# %%
# Boxplot
plt.boxplot(df_2021['Idade'])
plt.ylabel('Idade')
plt.title('Distribuição da Idade dos Trabalhadores')
plt.show()

# %%
# Descrição Estatística
descricao_idade = df_2021['Idade'].describe()
print(descricao_idade)
# Out:
# count   1785.00
# mean      30.44
# std        6.78
# min       18.00
# 25%       25.00
# 50%       29.00
# 75%       34.00
# max       54.00
# Name: Idade, dtype: float64

# %%
print("Média de Idade:", media_idade)
print("Mediana de Idade:", mediana_idade)
print("Moda de Idade:", moda_idade)
# Out:
# Média de Idade: 30.435294117647057
# Mediana de Idade: 29.0
# Moda de Idade: 27

# %%
# Boxplot por Faixa Etária
plt.figure(figsize=(10, 6))
sns.boxplot(x='Faixa idade', y='Idade', data=df_2021, palette='viridis')
plt.xlabel('Faixa Etária')
plt.ylabel('Idade')
plt.title('Distribuição da Idade por Faixa Etária')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-43-401a5d2e77c6>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Faixa idade', y='Idade', data=df_2021, palette='viridis')

# %%
# Análise Estatística Descritiva por Faixa Etária
descricao_por_faixa_etaria = df_2021.groupby('Faixa idade')['Idade'].describe()
print(descricao_por_faixa_etaria)
# Out:
#              count  mean  std   min   25%   50%   75%   max
# Faixa idade
# 17-21        68.00 20.43 0.76 18.00 20.00 21.00 21.00 21.00
# 22-24       258.00 23.24 0.78 22.00 23.00 23.00 24.00 24.00
# 25-29       613.00 26.90 1.37 25.00 26.00 27.00 28.00 29.00
# 30-34       434.00 31.78 1.43 30.00 30.00 32.00 33.00 34.00
# 35-39       215.00 36.70 1.39 35.00 35.50 36.00 38.00 39.00
# 40-44       118.00 41.60 1.37 40.00 40.00 41.50 43.00 44.00
# 45-49        47.00 46.79 1.47 45.00 46.00 46.00 48.00 49.00
# 50-54        32.00 51.84 1.42 50.00 51.00 51.00 53.00 54.00

# %%
# Teste de ANOVA (Análise de Variância)
from scipy.stats import f_oneway

# %%
faixas_etarias = df_2021['Faixa idade'].unique()
grupos_por_faixa_etaria = [df_2021[df_2021['Faixa idade'] == faixa]['Idade'] for faixa in faixas_etarias]

# %%
resultado_anova = f_oneway(*grupos_por_faixa_etaria)
print("\nResultado do Teste de ANOVA:")
print("Valor-p:", resultado_anova.pvalue)
# Out:
# Resultado do Teste de ANOVA:
# Valor-p: 0.0

# %%
#Qual é a forma de trabalho ideal para os trabalhadores?

plt.figure(figsize=(6, 6))
plt.scatter(df_2021['Idade'], df_2021['Forma de trabalho ideal'])
plt.xlabel('Idade')
plt.ylabel('Forma de trabalho ideal')
plt.title('Relação entre Idade e Forma de trabalho ideal')
plt.show()

# %% [markdown]
# #<font color ="cyan">GRÁFICOS USANDO SEABORN DATAFRAME 2021</font>

# %%
# Calcula a matriz de correlação
correlation_matrix = df_2021.corr()

# Plota o gráfico de correlação usando seaborn
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", vmin=-1, vmax=1)
plt.title('Gráfico de Correlação')
plt.show()
# Out:
# <ipython-input-49-45e3b80b626d>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_2021.corr()

# %%
# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df_2021['Idade'], kde=True, color='blue', bins=10)
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Histograma de Idade')
plt.grid(True)
plt.show()

# %%
# Definir a lista de colunas numéricas
colunas_numericas = ['Idade', 'Maturidade em tecnologia e dados', 'Qualidade dos gestores e líderes', 'Reputação da empresa no mercado']

# Iterar sobre as colunas numéricas e imprimir os tipos de dados
for coluna in colunas_numericas:
    print(f"{coluna}: {df_2021[coluna].dtype}")
# Out:
# Idade: int64
# Maturidade em tecnologia e dados: int64
# Qualidade dos gestores e líderes: float64
# Reputação da empresa no mercado: float64

# %%
df_2021.columns.tolist()
# Out:
# ['Idade',
#  'Faixa idade',
#  'Genero',
#  'Estado onde mora',
#  'UF onde mora',
#  'Mudou de Estado?',
#  'Nivel de Ensino',
#  'Área de Formação',
#  'Setor',
#  'Número de Funcionários',
#  'Cargo Atual',
#  'Nível',
#  'Faixa salarial',
#  'Experiência na área de dados',
#  'Experiência prévia em TI/Engenharia de Software',
#  'Satisfação com a empresa atual',
#  'Maturidade em tecnologia e dados',
#  'Qualidade dos gestores e líderes',
#  'Reputação da empresa no mercado',
#  'Forma de trabalho atual',
#  'Forma de trabalho ideal',
#  'Atitude em caso de modelo 100% presencial']

# %% [markdown]
# #<font color ="cyan">DATAFRAME 2022 (XLSX)</font>

# %% [markdown]
# ##MOSTRANDO AS INFORMAÇÕES DO DATAFRAME DE 2022 - BRUTO
# → [URL da fonte de dados de 2022](https://www.kaggle.com/datasets/datahackers/state-of-data-2022)

# %%
df_2022
# Out:
#                           ('P0', 'id')  ('P1_a ', 'Idade')  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96               39.00
# 1     zzls2oftfn9law393oezzls2ofhvfpzd               32.00
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi               53.00
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl               27.00
# 4     zzaf1m95yan929rb94wzzaf1mekhvhpg               46.00
# ...                                ...                 ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp               26.00
# 4267  01dyfxam4u4bi29fem01dyfxaq9akvqp               30.00
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3               29.00
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de                 NaN
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7               24.00
#
#      ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                         35-39           Masculino
# 1                         30-34           Masculino
# 2                         50-54           Masculino
# 3                         25-29           Masculino
# 4                         45-49            Feminino
# ...                         ...                 ...
# 4266                      25-29           Masculino
# 4267                      30-34            Feminino
# 4268                      25-29           Masculino
# 4269                      17-21           Masculino
# 4270                      22-24           Masculino
#
#      ('P1_c ', 'Cor/raca/etnia') ('P1_d ', 'PCD')  \
# 0                          Parda              Não
# 1                          Parda              Não
# 2                         Branca              Não
# 3                         Branca              Não
# 4                         Branca              Não
# ...                          ...              ...
# 4266                      Branca              Não
# 4267                      Branca              Não
# 4268                      Branca              Não
# 4269                      Branca              Não
# 4270                      Branca              Não
#
#       ('P1_e ', 'experiencia_profissional_prejudicada')  \
# 0     Não acredito que minha experiência profissiona...
# 1     Sim, acredito que a minha a experiência profis...
# 2                                                   NaN
# 3                                                   NaN
# 4     Não acredito que minha experiência profissiona...
# ...                                                 ...
# 4266                                                NaN
# 4267  Não acredito que minha experiência profissiona...
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#                 ('P1_f ', 'aspectos_prejudicados')  \
# 0                                              NaN
# 1     Aprovação em processos seletivos/entrevistas
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 4266                                           NaN
# 4267                                           NaN
# 4268                                           NaN
# 4269                                           NaN
# 4270                                           NaN
#
#       ('P1_g ', 'vive_no_brasil') ('P1_i ', 'Estado onde mora')  \
# 0                            True         Distrito Federal (DF)
# 1                            True                     Pará (PA)
# 2                            True         Distrito Federal (DF)
# 3                            True             Minas Gerais (MG)
# 4                            True                     Pará (PA)
# ...                           ...                           ...
# 4266                         True                São Paulo (SP)
# 4267                         True             Minas Gerais (MG)
# 4268                         True                São Paulo (SP)
# 4269                         True                São Paulo (SP)
# 4270                         True                    Goiás (GO)
#
#      ('P1_i_1 ', 'uf onde mora') ('P1_i_2 ', 'Regiao onde mora')  \
# 0                             DF                    Centro-oeste
# 1                             PA                           Norte
# 2                             DF                    Centro-oeste
# 3                             MG                         Sudeste
# 4                             PA                           Norte
# ...                          ...                             ...
# 4266                          SP                         Sudeste
# 4267                          MG                         Sudeste
# 4268                          SP                         Sudeste
# 4269                          SP                         Sudeste
# 4270                          GO                    Centro-oeste
#
#      ('P1_j ', 'Mudou de Estado?') ('P1_k ', 'Regiao de origem')  \
# 0                            False                       Sudeste
# 1                             True                           NaN
# 2                            False                           Sul
# 3                             True                           NaN
# 4                             True                           NaN
# ...                            ...                           ...
# 4266                          True                           NaN
# 4267                          True                           NaN
# 4268                         False                      Nordeste
# 4269                          True                           NaN
# 4270                         False                      Nordeste
#
#      ('P1_l ', 'Nivel de Ensino')  \
# 0                   Pós-graduação
# 1           Graduação/Bacharelado
# 2                   Pós-graduação
# 3                Doutorado ou Phd
# 4                   Pós-graduação
# ...                           ...
# 4266        Graduação/Bacharelado
# 4267                     Mestrado
# 4268                     Mestrado
# 4269   Não tenho graduação formal
# 4270        Graduação/Bacharelado
#
#                           ('P1_m ', 'Área de Formação')  \
# 0     Computação / Engenharia de Software / Sistemas...
# 1                                    Outras Engenharias
# 2     Computação / Engenharia de Software / Sistemas...
# 3     Estatística/ Matemática / Matemática Computaci...
# 4     Computação / Engenharia de Software / Sistemas...
# ...                                                 ...
# 4266  Computação / Engenharia de Software / Sistemas...
# 4267                                 Outras Engenharias
# 4268                                 Outras Engenharias
# 4269                                                NaN
# 4270  Computação / Engenharia de Software / Sistemas...
#
#      ('P2_a ', 'Qual sua situação atual de trabalho?')  \
# 0                                     Servidor Público
# 1                                      Empregado (CLT)
# 2                                      Empregado (CLT)
# 3                                      Empregado (CLT)
# 4                                     Servidor Público
# ...                                                ...
# 4266                                   Empregado (CLT)
# 4267                                   Empregado (CLT)
# 4268                  Empreendedor ou Empregado (CNPJ)
# 4269                                        Estagiário
# 4270                                   Empregado (CLT)
#
#                        ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 0                           Setor Público                      Acima de 3.000
# 1                             Outra Opção                      Acima de 3.000
# 2                      Finanças ou Bancos                      Acima de 3.000
# 3                        Setor Automotivo                      Acima de 3.000
# 4                           Setor Público                        de 101 a 500
# ...                                   ...                                 ...
# 4266       Tecnologia/Fábrica de Software                      Acima de 3.000
# 4267                  Área de Consultoria                         de 51 a 100
# 4268  Setor Imobiliário/ Construção Civil                        de 101 a 500
# 4269                            Indústria                    de 1.001 a 3.000
# 4270                         Agronegócios                      de 501 a 1.000
#
#      ('P2_d ', 'Gestor?') ('P2_e ', 'Cargo como Gestor')  \
# 0                   False                            NaN
# 1                    True         Supervisor/Coordenador
# 2                   False                            NaN
# 3                   False                            NaN
# 4                   False                            NaN
# ...                   ...                            ...
# 4266                False                            NaN
# 4267                False                            NaN
# 4268                 True                   Gerente/Head
# 4269                False                            NaN
# 4270                False                            NaN
#
#                                ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 0                   DBA/Administrador de Banco de Dados             Júnior
# 1                                                   NaN                NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...              Pleno
# 3                     Cientista de Dados/Data Scientist             Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...              Pleno
# ...                                                 ...                ...
# 4266                     Analista de Dados/Data Analyst              Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...              Pleno
# 4268                                                NaN                NaN
# 4269                                        Outra Opção             Júnior
# 4270                     Analista de Dados/Data Analyst             Júnior
#
#            ('P2_h ', 'Faixa salarial')  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# ...                                ...
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 4                Não tenho experiência na área de dados
# ...                                                 ...
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#      ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 0                                                  True
# 1                                                 False
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 4266                                               True
# 4267                                               True
# 4268                                               True
# 4269                                               True
# 4270                                              False
#
#      ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')  \
# 0                                                   NaN
# 1     Falta de oportunidade de crescimento no empreg...
# 2     Falta de oportunidade de crescimento no empreg...
# 3                                                   NaN
# 4     Falta de oportunidade de crescimento no empreg...
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270  Salário atual não corresponde ao mercado, Falt...
#
#       ('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')  \
# 0                                                   NaN
# 1                                                  1.00
# 2                                                  1.00
# 3                                                   NaN
# 4                                                  1.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               1.00
#
#       ('P2_l_2 ', 'Salário atual não corresponde ao mercado')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  0.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               1.00
#
#       ('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  0.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               0.00
#
#       ('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  0.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               1.00
#
#       ('P2_l_5 ', 'Gostaria de receber mais benefícios')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  0.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               0.00
#
#       ('P2_l_6 ', 'O clima de trabalho/ambiente não é bom')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  1.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               0.00
#
#       ('P2_l_7 ', 'Falta de maturidade analítica na empresa')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                  0.00
# 3                                                   NaN
# 4                                                  1.00
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                               0.00
#
#      ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')  \
# 0     Não participei de entrevistas de emprego/proce...
# 1             Sim, fiz entrevistas mas não fui aprovado
# 2     Não participei de entrevistas de emprego/proce...
# 3                  Sim, fui aprovado e mudei de emprego
# 4     Não participei de entrevistas de emprego/proce...
# ...                                                 ...
# 4266               Sim, fui aprovado e mudei de emprego
# 4267  Não participei de entrevistas de emprego/proce...
# 4268  Sim, fui aprovado mas decidi não mudar de emprego
# 4269  Não participei de entrevistas de emprego/proce...
# 4270          Sim, fiz entrevistas mas não fui aprovado
#
#      ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')  \
# 0     Não estou buscando e não pretendo mudar de emp...
# 1     Estou em busca de oportunidades dentro ou fora...
# 2     Não estou buscando, mas me considero aberto a ...
# 3     Não estou buscando, mas me considero aberto a ...
# 4     Não estou buscando, mas me considero aberto a ...
# ...                                                 ...
# 4266  Não estou buscando e não pretendo mudar de emp...
# 4267  Não estou buscando e não pretendo mudar de emp...
# 4268  Não estou buscando, mas me considero aberto a ...
# 4269  Estou em busca de oportunidades dentro ou fora...
# 4270  Estou em busca de oportunidades dentro ou fora...
#
#      ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')  \
# 0                                            Benefícios
# 1     Remuneração/Salário, Plano de carreira e oport...
# 2     Remuneração/Salário, Flexibilidade de trabalho...
# 3     Remuneração/Salário, Flexibilidade de trabalho...
# 4     Remuneração/Salário, Oportunidade de aprendiza...
# ...                                                 ...
# 4266  Remuneração/Salário, Benefícios, Flexibilidade...
# 4267  Ambiente e clima de trabalho, Plano de carreir...
# 4268  Remuneração/Salário, Ambiente e clima de traba...
# 4269  Oportunidade de aprendizado e trabalhar com re...
# 4270  Remuneração/Salário, Oportunidade de aprendiza...
#
#       ('P2_o_1 ', 'Remuneração/Salário')  ('P2_o_2 ', 'Benefícios')  \
# 0                                   0.00                       1.00
# 1                                   1.00                       0.00
# 2                                   1.00                       0.00
# 3                                   1.00                       0.00
# 4                                   1.00                       0.00
# ...                                  ...                        ...
# 4266                                1.00                       1.00
# 4267                                0.00                       0.00
# 4268                                1.00                       0.00
# 4269                                1.00                       0.00
# 4270                                1.00                       0.00
#
#       ('P2_o_3 ', 'Propósito do trabalho e da empresa')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               1.00
# 4269                                               0.00
# 4270                                               0.00
#
#       ('P2_o_4 ', 'Flexibilidade de trabalho remoto')  \
# 0                                                0.00
# 1                                                0.00
# 2                                                1.00
# 3                                                1.00
# 4                                                0.00
# ...                                               ...
# 4266                                             1.00
# 4267                                             0.00
# 4268                                             0.00
# 4269                                             0.00
# 4270                                             0.00
#
#       ('P2_o_5 ', 'Ambiente e clima de trabalho')  \
# 0                                            0.00
# 1                                            0.00
# 2                                            0.00
# 3                                            0.00
# 4                                            0.00
# ...                                           ...
# 4266                                         0.00
# 4267                                         1.00
# 4268                                         1.00
# 4269                                         0.00
# 4270                                         0.00
#
#       ('P2_o_6 ', 'Oportunidade de aprendizado e trabalhar com referências na área')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  1.00
# 4                                                  1.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               0.00
# 4269                                               1.00
# 4270                                               1.00
#
#       ('P2_o_7 ', 'Plano de carreira e oportunidades de crescimento profissional')  \
# 0                                                  0.00
# 1                                                  1.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  1.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               1.00
# 4268                                               0.00
# 4269                                               0.00
# 4270                                               0.00
#
#       ('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               0.00
# 4269                                               0.00
# 4270                                               0.00
#
#       ('P2_o_9 ', 'Qualidade dos gestores e líderes')  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 4266                                             0.00
# 4267                                             0.00
# 4268                                             0.00
# 4269                                             0.00
# 4270                                             0.00
#
#       ('P2_o_10 ', 'Reputação que a empresa tem no mercado')  \
# 0                                                  0.00
# 1                                                  1.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               0.00
# 4269                                               1.00
# 4270                                               1.00
#
#      ('P2_p ', 'Atualmente qual a sua forma de trabalho?')  \
# 0                                Modelo 100% presencial
# 1                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4268  Modelo híbrido com dias fixos de trabalho pres...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#      ('P2_q ', 'Qual a forma de trabalho ideal para você?')  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4268  Modelo híbrido flexível (o funcionário tem lib...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#      ('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')  \
# 0      Vou aceitar e retornar ao modelo 100% presencial
# 1      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4      Vou aceitar e retornar ao modelo 100% presencial
# ...                                                 ...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4268  Vou procurar outra oportunidade no modelo híbr...
# 4269   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
#      ('P2_s ', 'Sua empresa passu por Layoff em 2022?')  \
# 0     Não ocorreram layoffs/demissões em massa na em...
# 1     Não ocorreram layoffs/demissões em massa na em...
# 2     Não ocorreram layoffs/demissões em massa na em...
# 3     Não ocorreram layoffs/demissões em massa na em...
# 4     Não ocorreram layoffs/demissões em massa na em...
# ...                                                 ...
# 4266  Não ocorreram layoffs/demissões em massa na em...
# 4267  Não ocorreram layoffs/demissões em massa na em...
# 4268  Sim, ocorreram layoffs/demissões em massa na e...
# 4269  Não ocorreram layoffs/demissões em massa na em...
# 4270  Não ocorreram layoffs/demissões em massa na em...
#
#      ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')  \
# 0                                                   NaN
# 1                                                 1 - 3
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                             4 - 10
# 4269                                                NaN
# 4270                                                NaN
#
#      ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')  \
# 0                                                   NaN
# 1                     Engenharia de Dados/Data Engineer
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268  Engenharia de Dados/Data Engineer, Cientista d...
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P3_b_1 ', 'Analytics Engineer')  \
# 0                                   NaN
# 1                                  0.00
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 4266                                NaN
# 4267                                NaN
# 4268                               0.00
# 4269                                NaN
# 4270                                NaN
#
#       ('P3_b_2 ', 'Engenharia de Dados/Data Engineer')  \
# 0                                                  NaN
# 1                                                 1.00
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 4266                                               NaN
# 4267                                               NaN
# 4268                                              1.00
# 4269                                               NaN
# 4270                                               NaN
#
#       ('P3_b_3 ', 'Analista de Dados/Data Analyst')  \
# 0                                               NaN
# 1                                              0.00
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 4266                                            NaN
# 4267                                            NaN
# 4268                                           1.00
# 4269                                            NaN
# 4270                                            NaN
#
#       ('P3_b_4 ', 'Cientista de Dados/Data Scientist')  \
# 0                                                  NaN
# 1                                                 0.00
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 4266                                               NaN
# 4267                                               NaN
# 4268                                              1.00
# 4269                                               NaN
# 4270                                               NaN
#
#       ('P3_b_5 ', 'Database Administrator/DBA')  \
# 0                                           NaN
# 1                                          0.00
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 4266                                        NaN
# 4267                                        NaN
# 4268                                       0.00
# 4269                                        NaN
# 4270                                        NaN
#
#       ('P3_b_6 ', 'Analista de Business Intelligence/BI')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                               0.00
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P3_b_7 ', 'Arquiteto de Dados/Data Architect')  \
# 0                                                  NaN
# 1                                                 0.00
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 4266                                               NaN
# 4267                                               NaN
# 4268                                              0.00
# 4269                                               NaN
# 4270                                               NaN
#
#       ('P3_b_8 ', 'Data Product Manager/DPM')  \
# 0                                         NaN
# 1                                        0.00
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 4266                                      NaN
# 4267                                      NaN
# 4268                                     0.00
# 4269                                      NaN
# 4270                                      NaN
#
#       ('P3_b_9 ', 'Business Analyst')  \
# 0                                 NaN
# 1                                0.00
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 4266                              NaN
# 4267                              NaN
# 4268                             0.00
# 4269                              NaN
# 4270                              NaN
#
#      ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')  \
# 0                                                   NaN
# 1     Sou gestor da equipe responsável pela entrega ...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268  Pensar na visão de longo prazo de dados da emp...
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P3_c_1 ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                               1.00
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P3_c_2 ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')  \
# 0                                                   NaN
# 1                                                  0.00
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                               1.00
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P3_c_3 ', 'Atração, seleção e contratação de talentos para o time de dados.')  \
# 0                                                   NaN
# 1                                                  0.00
# ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  1.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  1.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_6 ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_8 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_9 ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_10 ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
#       ('P8_d_11 ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')
# 0                                                   NaN
# 1                                                   NaN
# 2                                                  0.00
# 3                                                  0.00
# 4                                                   NaN
# ...                                                 ...
# 4266                                                NaN
# 4267                                                NaN
# 4268                                                NaN
# 4269                                                NaN
# 4270                                                NaN
#
# [4271 rows x 353 columns]

# %% [markdown]
# ##LISTA COM O TOTAL DE COLUNAS DO DATAFRAME 2022

# %%
df_2022.columns.tolist()
# Out:
# ["('P0', 'id')",
#  "('P1_a ', 'Idade')",
#  "('P1_a_1 ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_c ', 'Cor/raca/etnia')",
#  "('P1_d ', 'PCD')",
#  "('P1_e ', 'experiencia_profissional_prejudicada')",
#  "('P1_f ', 'aspectos_prejudicados')",
#  "('P1_g ', 'vive_no_brasil')",
#  "('P1_i ', 'Estado onde mora')",
#  "('P1_i_1 ', 'uf onde mora')",
#  "('P1_i_2 ', 'Regiao onde mora')",
#  "('P1_j ', 'Mudou de Estado?')",
#  "('P1_k ', 'Regiao de origem')",
#  "('P1_l ', 'Nivel de Ensino')",
#  "('P1_m ', 'Área de Formação')",
#  "('P2_a ', 'Qual sua situação atual de trabalho?')",
#  "('P2_b ', 'Setor')",
#  "('P2_c ', 'Numero de Funcionarios')",
#  "('P2_d ', 'Gestor?')",
#  "('P2_e ', 'Cargo como Gestor')",
#  "('P2_f ', 'Cargo Atual')",
#  "('P2_g ', 'Nivel')",
#  "('P2_h ', 'Faixa salarial')",
#  "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#  "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#  "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
#  "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
#  "('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')",
#  "('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
#  "('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')",
#  "('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')",
#  "('P2_l_5 ', 'Gostaria de receber mais benefícios')",
#  "('P2_l_6 ', 'O clima de trabalho/ambiente não é bom')",
#  "('P2_l_7 ', 'Falta de maturidade analítica na empresa')",
#  "('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
#  "('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')",
#  "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
#  "('P2_o_1 ', 'Remuneração/Salário')",
#  "('P2_o_2 ', 'Benefícios')",
#  "('P2_o_3 ', 'Propósito do trabalho e da empresa')",
#  "('P2_o_4 ', 'Flexibilidade de trabalho remoto')",
#  "('P2_o_5 ', 'Ambiente e clima de trabalho')",
#  "('P2_o_6 ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
#  "('P2_o_7 ', 'Plano de carreira e oportunidades de crescimento profissional')",
#  "('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')",
#  "('P2_o_9 ', 'Qualidade dos gestores e líderes')",
#  "('P2_o_10 ', 'Reputação que a empresa tem no mercado')",
#  "('P2_p ', 'Atualmente qual a sua forma de trabalho?')",
#  "('P2_q ', 'Qual a forma de trabalho ideal para você?')",
#  "('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')",
#  "('P2_s ', 'Sua empresa passu por Layoff em 2022?')",
#  "('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')",
#  "('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')",
#  "('P3_b_1 ', 'Analytics Engineer')",
#  "('P3_b_2 ', 'Engenharia de Dados/Data Engineer')",
#  "('P3_b_3 ', 'Analista de Dados/Data Analyst')",
#  "('P3_b_4 ', 'Cientista de Dados/Data Scientist')",
#  "('P3_b_5 ', 'Database Administrator/DBA')",
#  "('P3_b_6 ', 'Analista de Business Intelligence/BI')",
#  "('P3_b_7 ', 'Arquiteto de Dados/Data Architect')",
#  "('P3_b_8 ', 'Data Product Manager/DPM')",
#  "('P3_b_9 ', 'Business Analyst')",
#  "('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')",
#  "('P3_c_1 ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')",
#  "('P3_c_2 ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')",
#  "('P3_c_3 ', 'Atração, seleção e contratação de talentos para o time de dados.')",
#  "('P3_c_4 ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')",
#  "('P3_c_5 ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')",
#  "('P3_c_6 ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')",
#  "('P3_c_7 ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')",
#  "('P3_c_8 ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')",
#  "('P3_c_9 ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')",
#  "('P3_c_10 ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')",
#  "('P3_c_11 ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')",
#  "('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')",
#  "('P3_d_1 ', 'a Contratar novos talentos.')",
#  "('P3_d_2 ', 'b Reter talentos.')",
#  "('P3_d_3 ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')",
#  "('P3_d_4 ', 'd Gestão de equipes no ambiente remoto.')",
#  "('P3_d_5 ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')",
#  "('P3_d_6 ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')",
#  "('P3_d_7 ', 'g Conseguir processar e armazenar um alto volume de dados.')",
#  "('P3_d_8 ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')",
#  "('P3_d_9 ', 'i Desenvolver e manter modelos Machine Learning em produção.')",
#  "('P3_d_10 ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')",
#  "('P3_d_11 ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')",
#  "('P3_d_12 ', 'Conseguir levar inovação para a empresa através dos dados.')",
#  "('P3_d_13 ', 'Garantir retorno do investimento (ROI) em projetos de dados.')",
#  "('P3_d_14 ', 'Dividir o tempo entre entregas técnicas e gestão.')",
#  "('P4_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')",
#  "('P4_a_1 ', 'Atuacao')",
#  "('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')",
#  "('P4_b_1 ', 'Dados relacionais (estruturados em bancos SQL)')",
#  "('P4_b_2 ', 'Dados armazenados em bancos NoSQL')",
#  "('P4_b_3 ', 'Imagens')",
#  "('P4_b_4 ', 'Textos/Documentos')",
#  "('P4_b_5 ', 'Vídeos')",
#  "('P4_b_6 ', 'Áudios')",
#  "('P4_b_7 ', 'Planilhas')",
#  "('P4_b_8 ', 'Dados georeferenciados')",
#  "('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')",
#  "('P4_c_1 ', 'Dados relacionais (estruturados em bancos SQL)')",
#  "('P4_c_2 ', 'Dados armazenados em bancos NoSQL')",
#  "('P4_c_3 ', 'Imagens')",
#  "('P4_c_4 ', 'Textos/Documentos')",
#  "('P4_c_5 ', 'Vídeos')",
#  "('P4_c_6 ', 'Áudios')",
#  "('P4_c_7 ', 'Planilhas')",
#  "('P4_c_8 ', 'Dados georeferenciados')",
#  "('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')",
#  "('P4_d_1 ', 'SQL')",
#  "('P4_d_2 ', 'R ')",
#  "('P4_d_3 ', 'Python')",
#  "('P4_d_4 ', 'C/C++/C#')",
#  "('P4_d_5 ', '.NET')",
#  "('P4_d_6 ', 'Java')",
#  "('P4_d_7 ', 'Julia')",
#  "('P4_d_8 ', 'SAS/Stata')",
#  "('P4_d_9 ', 'Visual Basic/VBA')",
#  "('P4_d_10 ', 'Scala')",
#  "('P4_d_11 ', 'Matlab')",
#  "('P4_d_12 ', 'PHP')",
#  "('P4_d_13 ', 'Javascript')",
#  "('P4_d_14 ', 'Não utilizo nenhuma linguagem')",
#  "('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')",
#  "('P4_f ', 'Entre as linguagens listadas abaixo, qual é a sua preferida?')",
#  "('P4_g ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')",
#  "('P4_g_1 ', 'MySQL')",
#  "('P4_g_2 ', 'Oracle')",
#  "('P4_g_3 ', 'SQL SERVER')",
#  "('P4_f_4 ', 'Amazon Aurora ou RDS')",
#  "('P4_f_5 ', 'DynamoDB')",
#  "('P4_f_6 ', 'CoachDB')",
#  "('P4_f_7 ', 'Cassandra')",
#  "('P4_f_8 ', 'MongoDB')",
#  "('P4_f_9 ', 'MariaDB')",
#  "('P4_f_10 ', 'Datomic')",
#  "('P4_f_11 ', 'S3')",
#  "('P4_f_12 ', 'PostgreSQL')",
#  "('P4_f_13 ', 'ElasticSearch')",
#  "('P4_f_14 ', 'DB2')",
#  "('P4_f_15 ', 'Microsoft Access')",
#  "('P4_f_16 ', 'SQLite')",
#  "('P4_f_17 ', 'Sybase')",
#  "('P4_f_18 ', 'Firebase')",
#  "('P4_f_19 ', 'Vertica')",
#  "('P4_f_20 ', 'Redis')",
#  "('P4_f_21 ', 'Neo4J')",
#  "('P4_f_22 ', 'Google BigQuery')",
#  "('P4_f_23 ', 'Google Firestore')",
#  "('P4_f_24 ', 'Amazon Redshift')",
#  "('P4_f_25 ', 'Amazon Athena')",
#  "('P4_f_26 ', 'Snowflake')",
#  "('P4_f_27 ', 'Databricks')",
#  "('P4_f_28 ', 'HBase')",
#  "('P4_f_29 ', 'Presto')",
#  "('P4_f_30 ', 'Splunk')",
#  "('P4_f_31 ', 'SAP HANA')",
#  "('P4_f_32 ', 'Hive')",
#  "('P4_f_33 ', 'Firebird')",
#  "('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')",
#  "('P4_h ', 'Dentre as opções listadas, qual sua Cloud preferida?')",
#  "('P4_h_1 ', 'Azure (Microsoft)')",
#  "('P4_h_2 ', 'Amazon Web Services (AWS)')",
#  "('P4_h_3 ', 'Google Cloud (GCP)')",
#  "('P4_i ', 'Microsoft PowerBI')",
#  "('P4_i_1 ', 'Microsoft PowerBI')",
#  "('P4_i_2 ', 'Qlik View/Qlik Sense')",
#  "('P4_i_3 ', 'Tableau')",
#  "('P4_i_4 ', 'Metabase')",
#  "('P4_i_5 ', 'Superset')",
#  "('P4_i_6 ', 'Redash')",
#  "('P4_i_7 ', 'MicroStrategy')",
#  "('P4_i_8 ', 'IBM Analytics/Cognos')",
#  "('P4_i_9 ', 'SAP Business Objects')",
#  "('P4_i_10 ', 'Oracle Business Intelligence')",
#  "('P4_i_11 ', 'Amazon QuickSight')",
#  "('P4_i_12 ', 'Salesforce/Einstein Analytics')",
#  "('P4_i_13 ', 'Mode')",
#  "('P4_i_14 ', 'Alteryx')",
#  "('P4_i_15 ', 'Birst')",
#  "('P4_i_16 ', 'Looker')",
#  "('P4_i_17 ', 'Google Data Studio')",
#  "('P4_i_18 ', 'SAS Visual Analytics')",
#  "('P4_i_19 ', 'Grafana')",
#  "('P4_i_20 ', 'TIBCO Spotfire')",
#  "('P4_i_21 ', 'Pentaho')",
#  "('P4_i_22 ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')",
#  "('P4_i_23 ', 'Não utilizo nenhuma ferramenta de BI no trabalho')",
#  "('P5_a ', 'Qual seu objetivo na área de dados?')",
#  "('P5_b ', 'Qual oportunidade você está buscando?')",
#  "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
#  "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
#  "('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')",
#  "('P6_a_1 ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
#  "('P6_a_2 ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
#  "('P6_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P6_a_4 ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
#  "('P6_a_5 ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
#  "('P6_a_6 ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
#  "('P6_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
#  "('P6_a_8 ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')",
#  "('P6_a_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
#  "('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')",
#  "('P6_b_1 ', 'Scripts Python')",
#  "('P6_b_2 ', 'SQL & Stored Procedures')",
#  "('P6_b_3 ', 'Apache Airflow')",
#  "('P6_b_4 ', 'Luigi')",
#  "('P6_b_5 ', 'AWS Glue')",
#  "('P6_b_6 ', 'Talend')",
#  "('P6_b_7 ', 'Pentaho')",
#  "('P6_b_8 ', 'Alteryx')",
#  "('P6_b_9 ', 'Stitch')",
#  "('P6_b_10 ', 'Fivetran')",
#  "('P6_b_11 ', 'Google Dataflow')",
#  "('P6_b_12 ', 'Oracle Data Integrator')",
#  "('P6_b_13 ', 'IBM DataStage')",
#  "('P6_b_14 ', 'SAP BW ETL')",
#  "('P6_b_15 ', 'SQL Server Integration Services (SSIS)')",
#  "('P6_b_16 ', 'SAS Data Integration')",
#  "('P6_b_17 ', 'Qlik Sense')",
#  "('P6_b_18 ', 'Knime')",
#  "('P6_b_19 ', 'Databricks')",
#  "('P6_b_19 ', 'Não utilizo ferramentas de ETL')",
#  "('P6_c ', 'Sua organização possui um Data Lake?')",
#  "('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')",
#  "('P6_e ', 'Sua organização possui um Data Warehouse?')",
#  "('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')",
#  "('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')",
#  "('P6_g_1 ', 'great_expectations')",
#  "('P6_g_2 ', 'dbt')",
#  "('P6_g_3 ', 'AWS Deequ')",
#  "('P6_g_4 ', 'Apache Griffin')",
#  "('P6_g_5 ', 'Datafold')",
#  "('P6_g_6 ', 'Amundsen')",
#  "('P6_g_7 ', 'Monte Carlo')",
#  "('P6_g_8 ', 'SODA')",
#  "('P6_g_9 ', 'Big Eye')",
#  "('P6_g_10 ', 'Data Band')",
#  "('P6_g_11 ', 'Anomalo')",
#  "('P6_g_l ', 'Metaplane')",
#  "('P6_g_m ', 'Acceldata')",
#  "('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')",
#  "('P6_h_1 ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
#  "('P6_h_2 ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
#  "('P6_h_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P6_h_4 ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
#  "('P6_h_5 ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
#  "('P6_h_6 ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
#  "('P6_h_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
#  "('P6_h_8 ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')",
#  "('P6_h_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
#  "('P7_1 ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')",
#  "('P7_a_1 ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')",
#  "('P7_a_2 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
#  "('P7_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P7_a_4 ', 'Utilizo API's para extrair dados e complementar minhas análises.')",
#  "('P7_a_5 ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
#  "('P7_a_6 ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
#  "('P7_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
#  "('P7_a_8 ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')",
#  "('P7_a_9 ', 'Utilizo ferramentas avançadas de estatística como SAS')",
#  "('P7_a_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
#  "('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')",
#  "('P7_b_1 ', 'Scripts Python')",
#  "('P7_b_2 ', 'SQL & Stored Procedures')",
#  "('P7_b_3 ', 'Apache Airflow')",
#  "('P7_b_4 ', 'Luigi')",
#  "('P7_b_5 ', 'AWS Glue')",
#  "('P7_b_6 ', 'Talend')",
#  "('P7_b_7 ', 'Pentaho')",
#  "('P7_b_8 ', 'Alteryx')",
#  "('P7_b_9 ', 'Stitch')",
#  "('P7_b_10 ', 'Fivetran')",
#  "('P7_b_11 ', 'Google Dataflow')",
#  "('P7_b_12 ', 'Oracle Data Integrator')",
#  "('P7_b_13 ', 'IBM DataStage')",
#  "('P7_b_14 ', 'SAP BW ETL')",
#  "('P7_b_15 ', 'SQL Server Integration Services (SSIS)')",
#  "('P7_b_16 ', 'SAS Data Integration')",
#  "('P7_b_17 ', 'Qlik Sense')",
#  "('P7_b_18 ', 'Knime')",
#  "('P7_b_19 ', 'Databricks')",
#  "('P7_b_20 ', 'Não utilizo ferramentas de ETL')",
#  "('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')",
#  "('P7_c_1 ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')",
#  '(\'P7_c_2 \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')',
#  "('P7_c_3 ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')",
#  "('P7_c_4 ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')",
#  "('P7_c_5 ', 'Minha empresa não utiliza essas ferramentas.')",
#  "('P7_c_6 ', 'Não sei informar.')",
#  "('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')",
#  "('P7_d_1 ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')",
#  "('P7_d_2 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
#  "('P7_d_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
#  "('P7_d_4 ', 'Utilizando API's para extrair dados e complementar minhas análises.')",
#  "('P7_d_5 ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
#  "('P7_d_6 ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
#  "('P7_d_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
#  "('P7_d_8 ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')",
#  "('P7_d_9 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
#  "('P7_d_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
#  "('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')",
#  "('P8_a_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
#  "('P8_a_2 ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')",
#  "('P8_a_3 ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
#  "('P8_a_4 ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
#  "('P8_a_5 ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')",
#  "('P8_a_6 ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
#  "('P8_a_7 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')",
#  "('P8_a_8 ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
#  "('P8_a_9 ', 'Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
#  "('P8_a_10 ', 'Crio e gerencio soluções de Feature Store e cultura de MLOps.')",
#  "('P8_a_11 ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
#  "('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')",
#  "('P8_b_1 ', 'Utilizo modelos de regressão (linear, logística, GLM)')",
#  "('P8_b_2 ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')",
#  "('P8_b_3 ', 'Desenvolvo sistemas de recomendação (RecSys)')",
#  "('P8_b_4 ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')",
#  "('P8_b_5 ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')",
#  "('P8_b_6 ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')",
#  "('P8_b_7 ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')",
#  "('P8_b_8 ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')",
#  "('P8_b_9 ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')",
#  "('P8_b_10 ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')",
#  "('P8_b_11 ', 'Utilizo modelos de Machine Learning para detecção de fraude')",
#  "('P8_b_l ', 'Utilizo métodos de Visão Computacional')",
#  "('P8_b_m ', 'Utilizo modelos de Detecção de Churn')",
#  "('P8_3 ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')",
#  "('P8_c_1 ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')",
#  "('P8_c_2 ', 'Planilhas (Excel, Google Sheets etc)')",
#  "('P8_c_3 ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')",
#  "('P8_c_4 ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')",
#  "('P8_c_5 ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')",
#  "('P8_c_6 ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')",
#  "('P8_c_7 ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')",
#  "('P8_c_8 ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')",
#  "('P8_c_9 ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')",
#  "('P8_c_10 ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')",
#  "('P8_c_11 ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')",
#  "('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')",
#  "('P8_d_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
#  "('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')",
#  "('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
#  "('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
#  "('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')",
#  "('P8_d_6 ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
#  "('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')",
#  "('P8_d_8 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
#  "('P8_d_9 ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')",
#  "('P8_d_10 ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')",
#  "('P8_d_11 ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')"]

# %% [markdown]
# ##SEGREGANDO A TAREFA DE ANÁLISE DAS COLUNAS DO DATAFRAME 2022
#
# ####<font color ="red">⚠️ INFORMAÇÃO IMPORTANTE!!! ⚠️</font>
# A Segregação dos dados em 8 partes foi realizada, entretando, sobrou uma quantidade de linhas onde foi criada uma "parte 9" podendo ser organizado entre o time para trabalharmos nisso.
#
# Neste arquivo, sobrou apenas 1 linha.

# %%
# Original list of lines
lines = ["('P0', 'id')",
 "('P1_a ', 'Idade')",
 "('P1_a_1 ', 'Faixa idade')",
 "('P1_b ', 'Genero')",
 "('P1_c ', 'Cor/raca/etnia')",
 "('P1_d ', 'PCD')",
 "('P1_e ', 'experiencia_profissional_prejudicada')",
 "('P1_f ', 'aspectos_prejudicados')",
 "('P1_g ', 'vive_no_brasil')",
 "('P1_i ', 'Estado onde mora')",
 "('P1_i_1 ', 'uf onde mora')",
 "('P1_i_2 ', 'Regiao onde mora')",
 "('P1_j ', 'Mudou de Estado?')",
 "('P1_k ', 'Regiao de origem')",
 "('P1_l ', 'Nivel de Ensino')",
 "('P1_m ', 'Área de Formação')",
 "('P2_a ', 'Qual sua situação atual de trabalho?')",
 "('P2_b ', 'Setor')",
 "('P2_c ', 'Numero de Funcionarios')",
 "('P2_d ', 'Gestor?')",
 "('P2_e ', 'Cargo como Gestor')",
 "('P2_f ', 'Cargo Atual')",
 "('P2_g ', 'Nivel')",
 "('P2_h ', 'Faixa salarial')",
 "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
 "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
 "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
 "('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')",
 "('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')",
 "('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
 "('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')",
 "('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')",
 "('P2_l_5 ', 'Gostaria de receber mais benefícios')",
 "('P2_l_6 ', 'O clima de trabalho/ambiente não é bom')",
 "('P2_l_7 ', 'Falta de maturidade analítica na empresa')",
 "('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')",
 "('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')",
 "('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')",
 "('P2_o_1 ', 'Remuneração/Salário')",
 "('P2_o_2 ', 'Benefícios')",
 "('P2_o_3 ', 'Propósito do trabalho e da empresa')",
 "('P2_o_4 ', 'Flexibilidade de trabalho remoto')",
 "('P2_o_5 ', 'Ambiente e clima de trabalho')",
 "('P2_o_6 ', 'Oportunidade de aprendizado e trabalhar com referências na área')",
 "('P2_o_7 ', 'Plano de carreira e oportunidades de crescimento profissional')",
 "('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')",
 "('P2_o_9 ', 'Qualidade dos gestores e líderes')",
 "('P2_o_10 ', 'Reputação que a empresa tem no mercado')",
 "('P2_p ', 'Atualmente qual a sua forma de trabalho?')",
 "('P2_q ', 'Qual a forma de trabalho ideal para você?')",
 "('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')",
 "('P2_s ', 'Sua empresa passu por Layoff em 2022?')",
 "('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')",
 "('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')",
 "('P3_b_1 ', 'Analytics Engineer')",
 "('P3_b_2 ', 'Engenharia de Dados/Data Engineer')",
 "('P3_b_3 ', 'Analista de Dados/Data Analyst')",
 "('P3_b_4 ', 'Cientista de Dados/Data Scientist')",
 "('P3_b_5 ', 'Database Administrator/DBA')",
 "('P3_b_6 ', 'Analista de Business Intelligence/BI')",
 "('P3_b_7 ', 'Arquiteto de Dados/Data Architect')",
 "('P3_b_8 ', 'Data Product Manager/DPM')",
 "('P3_b_9 ', 'Business Analyst')",
 "('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')",
 "('P3_c_1 ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')",
 "('P3_c_2 ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')",
 "('P3_c_3 ', 'Atração, seleção e contratação de talentos para o time de dados.')",
 "('P3_c_4 ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')",
 "('P3_c_5 ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')",
 "('P3_c_6 ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')",
 "('P3_c_7 ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')",
 "('P3_c_8 ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')",
 "('P3_c_9 ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')",
 "('P3_c_10 ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')",
 "('P3_c_11 ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')",
 "('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')",
 "('P3_d_1 ', 'a Contratar novos talentos.')",
 "('P3_d_2 ', 'b Reter talentos.')",
 "('P3_d_3 ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')",
 "('P3_d_4 ', 'd Gestão de equipes no ambiente remoto.')",
 "('P3_d_5 ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')",
 "('P3_d_6 ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')",
 "('P3_d_7 ', 'g Conseguir processar e armazenar um alto volume de dados.')",
 "('P3_d_8 ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')",
 "('P3_d_9 ', 'i Desenvolver e manter modelos Machine Learning em produção.')",
 "('P3_d_10 ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')",
 "('P3_d_11 ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')",
 "('P3_d_12 ', 'Conseguir levar inovação para a empresa através dos dados.')",
 "('P3_d_13 ', 'Garantir retorno do investimento (ROI) em projetos de dados.')",
 "('P3_d_14 ', 'Dividir o tempo entre entregas técnicas e gestão.')",
 "('P4_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')",
 "('P4_a_1 ', 'Atuacao')",
 "('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')",
 "('P4_b_1 ', 'Dados relacionais (estruturados em bancos SQL)')",
 "('P4_b_2 ', 'Dados armazenados em bancos NoSQL')",
 "('P4_b_3 ', 'Imagens')",
 "('P4_b_4 ', 'Textos/Documentos')",
 "('P4_b_5 ', 'Vídeos')",
 "('P4_b_6 ', 'Áudios')",
 "('P4_b_7 ', 'Planilhas')",
 "('P4_b_8 ', 'Dados georeferenciados')",
 "('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')",
 "('P4_c_1 ', 'Dados relacionais (estruturados em bancos SQL)')",
 "('P4_c_2 ', 'Dados armazenados em bancos NoSQL')",
 "('P4_c_3 ', 'Imagens')",
 "('P4_c_4 ', 'Textos/Documentos')",
 "('P4_c_5 ', 'Vídeos')",
 "('P4_c_6 ', 'Áudios')",
 "('P4_c_7 ', 'Planilhas')",
 "('P4_c_8 ', 'Dados georeferenciados')",
 "('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')",
 "('P4_d_1 ', 'SQL')",
 "('P4_d_2 ', 'R ')",
 "('P4_d_3 ', 'Python')",
 "('P4_d_4 ', 'C/C++/C#')",
 "('P4_d_5 ', '.NET')",
 "('P4_d_6 ', 'Java')",
 "('P4_d_7 ', 'Julia')",
 "('P4_d_8 ', 'SAS/Stata')",
 "('P4_d_9 ', 'Visual Basic/VBA')",
 "('P4_d_10 ', 'Scala')",
 "('P4_d_11 ', 'Matlab')",
 "('P4_d_12 ', 'PHP')",
 "('P4_d_13 ', 'Javascript')",
 "('P4_d_14 ', 'Não utilizo nenhuma linguagem')",
 "('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')",
 "('P4_f ', 'Entre as linguagens listadas abaixo, qual é a sua preferida?')",
 "('P4_g ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')",
 "('P4_g_1 ', 'MySQL')",
 "('P4_g_2 ', 'Oracle')",
 "('P4_g_3 ', 'SQL SERVER')",
 "('P4_f_4 ', 'Amazon Aurora ou RDS')",
 "('P4_f_5 ', 'DynamoDB')",
 "('P4_f_6 ', 'CoachDB')",
 "('P4_f_7 ', 'Cassandra')",
 "('P4_f_8 ', 'MongoDB')",
 "('P4_f_9 ', 'MariaDB')",
 "('P4_f_10 ', 'Datomic')",
 "('P4_f_11 ', 'S3')",
 "('P4_f_12 ', 'PostgreSQL')",
 "('P4_f_13 ', 'ElasticSearch')",
 "('P4_f_14 ', 'DB2')",
 "('P4_f_15 ', 'Microsoft Access')",
 "('P4_f_16 ', 'SQLite')",
 "('P4_f_17 ', 'Sybase')",
 "('P4_f_18 ', 'Firebase')",
 "('P4_f_19 ', 'Vertica')",
 "('P4_f_20 ', 'Redis')",
 "('P4_f_21 ', 'Neo4J')",
 "('P4_f_22 ', 'Google BigQuery')",
 "('P4_f_23 ', 'Google Firestore')",
 "('P4_f_24 ', 'Amazon Redshift')",
 "('P4_f_25 ', 'Amazon Athena')",
 "('P4_f_26 ', 'Snowflake')",
 "('P4_f_27 ', 'Databricks')",
 "('P4_f_28 ', 'HBase')",
 "('P4_f_29 ', 'Presto')",
 "('P4_f_30 ', 'Splunk')",
 "('P4_f_31 ', 'SAP HANA')",
 "('P4_f_32 ', 'Hive')",
 "('P4_f_33 ', 'Firebird')",
 "('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')",
 "('P4_h ', 'Dentre as opções listadas, qual sua Cloud preferida?')",
 "('P4_h_1 ', 'Azure (Microsoft)')",
 "('P4_h_2 ', 'Amazon Web Services (AWS)')",
 "('P4_h_3 ', 'Google Cloud (GCP)')",
 "('P4_i ', 'Microsoft PowerBI')",
 "('P4_i_1 ', 'Microsoft PowerBI')",
 "('P4_i_2 ', 'Qlik View/Qlik Sense')",
 "('P4_i_3 ', 'Tableau')",
 "('P4_i_4 ', 'Metabase')",
 "('P4_i_5 ', 'Superset')",
 "('P4_i_6 ', 'Redash')",
 "('P4_i_7 ', 'MicroStrategy')",
 "('P4_i_8 ', 'IBM Analytics/Cognos')",
 "('P4_i_9 ', 'SAP Business Objects')",
 "('P4_i_10 ', 'Oracle Business Intelligence')",
 "('P4_i_11 ', 'Amazon QuickSight')",
 "('P4_i_12 ', 'Salesforce/Einstein Analytics')",
 "('P4_i_13 ', 'Mode')",
 "('P4_i_14 ', 'Alteryx')",
 "('P4_i_15 ', 'Birst')",
 "('P4_i_16 ', 'Looker')",
 "('P4_i_17 ', 'Google Data Studio')",
 "('P4_i_18 ', 'SAS Visual Analytics')",
 "('P4_i_19 ', 'Grafana')",
 "('P4_i_20 ', 'TIBCO Spotfire')",
 "('P4_i_21 ', 'Pentaho')",
 "('P4_i_22 ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')",
 "('P4_i_23 ', 'Não utilizo nenhuma ferramenta de BI no trabalho')",
 "('P5_a ', 'Qual seu objetivo na área de dados?')",
 "('P5_b ', 'Qual oportunidade você está buscando?')",
 "('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')",
 "('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')",
 "('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')",
 "('P6_a_1 ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
 "('P6_a_2 ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
 "('P6_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P6_a_4 ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
 "('P6_a_5 ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
 "('P6_a_6 ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
 "('P6_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
 "('P6_a_8 ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')",
 "('P6_a_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
 "('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')",
 "('P6_b_1 ', 'Scripts Python')",
 "('P6_b_2 ', 'SQL & Stored Procedures')",
 "('P6_b_3 ', 'Apache Airflow')",
 "('P6_b_4 ', 'Luigi')",
 "('P6_b_5 ', 'AWS Glue')",
 "('P6_b_6 ', 'Talend')",
 "('P6_b_7 ', 'Pentaho')",
 "('P6_b_8 ', 'Alteryx')",
 "('P6_b_9 ', 'Stitch')",
 "('P6_b_10 ', 'Fivetran')",
 "('P6_b_11 ', 'Google Dataflow')",
 "('P6_b_12 ', 'Oracle Data Integrator')",
 "('P6_b_13 ', 'IBM DataStage')",
 "('P6_b_14 ', 'SAP BW ETL')",
 "('P6_b_15 ', 'SQL Server Integration Services (SSIS)')",
 "('P6_b_16 ', 'SAS Data Integration')",
 "('P6_b_17 ', 'Qlik Sense')",
 "('P6_b_18 ', 'Knime')",
 "('P6_b_19 ', 'Databricks')",
 "('P6_b_19 ', 'Não utilizo ferramentas de ETL')",
 "('P6_c ', 'Sua organização possui um Data Lake?')",
 "('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')",
 "('P6_e ', 'Sua organização possui um Data Warehouse?')",
 "('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')",
 "('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')",
 "('P6_g_1 ', 'great_expectations')",
 "('P6_g_2 ', 'dbt')",
 "('P6_g_3 ', 'AWS Deequ')",
 "('P6_g_4 ', 'Apache Griffin')",
 "('P6_g_5 ', 'Datafold')",
 "('P6_g_6 ', 'Amundsen')",
 "('P6_g_7 ', 'Monte Carlo')",
 "('P6_g_8 ', 'SODA')",
 "('P6_g_9 ', 'Big Eye')",
 "('P6_g_10 ', 'Data Band')",
 "('P6_g_11 ', 'Anomalo')",
 "('P6_g_l ', 'Metaplane')",
 "('P6_g_m ', 'Acceldata')",
 "('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')",
 "('P6_h_1 ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')",
 "('P6_h_2 ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')",
 "('P6_h_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P6_h_4 ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')",
 "('P6_h_5 ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')",
 "('P6_h_6 ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')",
 "('P6_h_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')",
 "('P6_h_8 ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')",
 "('P6_h_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
 "('P7_1 ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')",
 "('P7_a_1 ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')",
 "('P7_a_2 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
 "('P7_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P7_a_4 ', 'Utilizo API's para extrair dados e complementar minhas análises.')",
 "('P7_a_5 ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
 "('P7_a_6 ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
 "('P7_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
 "('P7_a_8 ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')",
 "('P7_a_9 ', 'Utilizo ferramentas avançadas de estatística como SAS')",
 "('P7_a_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
 "('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')",
 "('P7_b_1 ', 'Scripts Python')",
 "('P7_b_2 ', 'SQL & Stored Procedures')",
 "('P7_b_3 ', 'Apache Airflow')",
 "('P7_b_4 ', 'Luigi')",
 "('P7_b_5 ', 'AWS Glue')",
 "('P7_b_6 ', 'Talend')",
 "('P7_b_7 ', 'Pentaho')",
 "('P7_b_8 ', 'Alteryx')",
 "('P7_b_9 ', 'Stitch')",
 "('P7_b_10 ', 'Fivetran')",
 "('P7_b_11 ', 'Google Dataflow')",
 "('P7_b_12 ', 'Oracle Data Integrator')",
 "('P7_b_13 ', 'IBM DataStage')",
 "('P7_b_14 ', 'SAP BW ETL')",
 "('P7_b_15 ', 'SQL Server Integration Services (SSIS)')",
 "('P7_b_16 ', 'SAS Data Integration')",
 "('P7_b_17 ', 'Qlik Sense')",
 "('P7_b_18 ', 'Knime')",
 "('P7_b_19 ', 'Databricks')",
 "('P7_b_20 ', 'Não utilizo ferramentas de ETL')",
 "('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')",
 "('P7_c_1 ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')",
 '(\'P7_c_2 \', \'""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.\')',
 "('P7_c_3 ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')",
 "('P7_c_4 ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')",
 "('P7_c_5 ', 'Minha empresa não utiliza essas ferramentas.')",
 "('P7_c_6 ', 'Não sei informar.')",
 "('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')",
 "('P7_d_1 ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')",
 "('P7_d_2 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')",
 "('P7_d_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')",
 "('P7_d_4 ', 'Utilizando API's para extrair dados e complementar minhas análises.')",
 "('P7_d_5 ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')",
 "('P7_d_6 ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')",
 "('P7_d_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')",
 "('P7_d_8 ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')",
 "('P7_d_9 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
 "('P7_d_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')",
 "('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')",
 "('P8_a_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
 "('P8_a_2 ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')",
 "('P8_a_3 ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
 "('P8_a_4 ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
 "('P8_a_5 ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')",
 "('P8_a_6 ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
 "('P8_a_7 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')",
 "('P8_a_8 ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
 "('P8_a_9 ', 'Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')",
 "('P8_a_10 ', 'Crio e gerencio soluções de Feature Store e cultura de MLOps.')",
 "('P8_a_11 ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')",
 "('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')",
 "('P8_b_1 ', 'Utilizo modelos de regressão (linear, logística, GLM)')",
 "('P8_b_2 ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')",
 "('P8_b_3 ', 'Desenvolvo sistemas de recomendação (RecSys)')",
 "('P8_b_4 ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')",
 "('P8_b_5 ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')",
 "('P8_b_6 ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')",
 "('P8_b_7 ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')",
 "('P8_b_8 ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')",
 "('P8_b_9 ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')",
 "('P8_b_10 ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')",
 "('P8_b_11 ', 'Utilizo modelos de Machine Learning para detecção de fraude')",
 "('P8_b_l ', 'Utilizo métodos de Visão Computacional')",
 "('P8_b_m ', 'Utilizo modelos de Detecção de Churn')",
 "('P8_3 ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')",
 "('P8_c_1 ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')",
 "('P8_c_2 ', 'Planilhas (Excel, Google Sheets etc)')",
 "('P8_c_3 ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')",
 "('P8_c_4 ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')",
 "('P8_c_5 ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')",
 "('P8_c_6 ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')",
 "('P8_c_7 ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')",
 "('P8_c_8 ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')",
 "('P8_c_9 ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')",
 "('P8_c_10 ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')",
 "('P8_c_11 ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')",
 "('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')",
 "('P8_d_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')",
 "('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')",
 "('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')",
 "('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')",
 "('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')",
 "('P8_d_6 ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')",
 "('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')",
 "('P8_d_8 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')",
 "('P8_d_9 ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')",
 "('P8_d_10 ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')",
 "('P8_d_11 ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')"]

#Calculando o número de linhas por
total_lines = len(lines)
lines_per_part = total_lines // 8

#Dividindo a lista em 8 partes
parts = [lines[i:i + lines_per_part] for i in range(0, total_lines, lines_per_part)]

#Printando cada parte
for i, part in enumerate(parts):
    print(f"Part {i + 1}:")
    for line in part:
        print(line)
    print()
# Out:
# Part 1:
# ('P0', 'id')
# ('P1_a ', 'Idade')
# ('P1_a_1 ', 'Faixa idade')
# ('P1_b ', 'Genero')
# ('P1_c ', 'Cor/raca/etnia')
# ('P1_d ', 'PCD')
# ('P1_e ', 'experiencia_profissional_prejudicada')
# ('P1_f ', 'aspectos_prejudicados')
# ('P1_g ', 'vive_no_brasil')
# ('P1_i ', 'Estado onde mora')
# ('P1_i_1 ', 'uf onde mora')
# ('P1_i_2 ', 'Regiao onde mora')
# ('P1_j ', 'Mudou de Estado?')
# ('P1_k ', 'Regiao de origem')
# ('P1_l ', 'Nivel de Ensino')
# ('P1_m ', 'Área de Formação')
# ('P2_a ', 'Qual sua situação atual de trabalho?')
# ('P2_b ', 'Setor')
# ('P2_c ', 'Numero de Funcionarios')
# ('P2_d ', 'Gestor?')
# ('P2_e ', 'Cargo como Gestor')
# ('P2_f ', 'Cargo Atual')
# ('P2_g ', 'Nivel')
# ('P2_h ', 'Faixa salarial')
# ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')
# ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')
# ('P2_k ', 'Você está satisfeito na sua empresa atual?')
# ('P2_l ', 'Qual o principal motivo da sua insatisfação com a empresa atual?')
# ('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')
# ('P2_l_2 ', 'Salário atual não corresponde ao mercado')
# ('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')
# ('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')
# ('P2_l_5 ', 'Gostaria de receber mais benefícios')
# ('P2_l_6 ', 'O clima de trabalho/ambiente não é bom')
# ('P2_l_7 ', 'Falta de maturidade analítica na empresa')
# ('P2_m ', 'Você participou de entrevistas de emprego nos últimos 6 meses?')
# ('P2_n ', 'Você pretende mudar de emprego nos próximos 6 meses?')
# ('P2_o ', 'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?')
# ('P2_o_1 ', 'Remuneração/Salário')
# ('P2_o_2 ', 'Benefícios')
# ('P2_o_3 ', 'Propósito do trabalho e da empresa')
# ('P2_o_4 ', 'Flexibilidade de trabalho remoto')
# ('P2_o_5 ', 'Ambiente e clima de trabalho')
# ('P2_o_6 ', 'Oportunidade de aprendizado e trabalhar com referências na área')
#
# Part 2:
# ('P2_o_7 ', 'Plano de carreira e oportunidades de crescimento profissional')
# ('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')
# ('P2_o_9 ', 'Qualidade dos gestores e líderes')
# ('P2_o_10 ', 'Reputação que a empresa tem no mercado')
# ('P2_p ', 'Atualmente qual a sua forma de trabalho?')
# ('P2_q ', 'Qual a forma de trabalho ideal para você?')
# ('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')
# ('P2_s ', 'Sua empresa passu por Layoff em 2022?')
# ('P3_a ', 'Qual o número aproximado de pessoas que atuam com dados na sua empresa hoje?')
# ('P3_b ', 'Quais desses papéis/cargos fazem parte do time (ou chapter) de dados da sua empresa?')
# ('P3_b_1 ', 'Analytics Engineer')
# ('P3_b_2 ', 'Engenharia de Dados/Data Engineer')
# ('P3_b_3 ', 'Analista de Dados/Data Analyst')
# ('P3_b_4 ', 'Cientista de Dados/Data Scientist')
# ('P3_b_5 ', 'Database Administrator/DBA')
# ('P3_b_6 ', 'Analista de Business Intelligence/BI')
# ('P3_b_7 ', 'Arquiteto de Dados/Data Architect')
# ('P3_b_8 ', 'Data Product Manager/DPM')
# ('P3_b_9 ', 'Business Analyst')
# ('P3_c ', 'Quais dessas responsabilidades fazem parte da sua rotina atual de trabalho como gestor?')
# ('P3_c_1 ', 'Pensar na visão de longo prazo de dados da empresa e fortalecimento da cultura analítica da companhia.')
# ('P3_c_2 ', 'Organização de treinamentos e iniciativas com o objetivo de aumentar a maturidade analítica das áreas de negócios.')
# ('P3_c_3 ', 'Atração, seleção e contratação de talentos para o time de dados.')
# ('P3_c_4 ', 'Decisão sobre contratação de ferramentas e tecnologias relacionadas a dados.')
# ('P3_c_5 ', 'Sou gestor da equipe responsável pela engenharia de dados e por manter o Data Lake da empresa como fonte única dos dados, garantindo a qualidade e confiabilidade da informação.')
# ('P3_c_6 ', 'Sou gestor da equipe responsável pela entrega de dados, estudos, relatórios e dashboards para as áreas de negócio da empresa.')
# ('P3_c_7 ', 'Sou gestor da equipe responsável por iniciativas e projetos envolvendo Inteligência Artificial e Machine Learning.')
# ('P3_c_8 ', 'Apesar de ser gestor ainda atuo na parte técnica, construindo soluções/análises/modelos etc.')
# ('P3_c_9 ', 'Gestão de projetos de dados, cuidando das etapas, equipes envolvidas, atingimento dos objetivos etc.')
# ('P3_c_10 ', 'Gestão de produtos de dados, cuidando da visão dos produtos, backlog, feedback de usuários etc.')
# ('P3_c_11 ', 'Gestão de pessoas, apoio no desenvolvimento das pessoas, evolução de carreira')
# ('P3_d ', 'Quais são os 3 maiores desafios que você tem como gestor no atual momento?')
# ('P3_d_1 ', 'a Contratar novos talentos.')
# ('P3_d_2 ', 'b Reter talentos.')
# ('P3_d_3 ', 'c Convencer a empresa a aumentar os investimentos na área de dados.')
# ('P3_d_4 ', 'd Gestão de equipes no ambiente remoto.')
# ('P3_d_5 ', 'e Gestão de projetos envolvendo áreas multidisciplinares da empresa.')
# ('P3_d_6 ', 'f Organizar as informações e garantir a qualidade e confiabilidade.')
# ('P3_d_7 ', 'g Conseguir processar e armazenar um alto volume de dados.')
# ('P3_d_8 ', 'h Conseguir gerar valor para as áreas de negócios através de estudos e experimentos.')
# ('P3_d_9 ', 'i Desenvolver e manter modelos Machine Learning em produção.')
# ('P3_d_10 ', 'j Gerenciar a expectativa das áreas de negócio em relação as entregas das equipes de dados.')
# ('P3_d_11 ', 'k Garantir a manutenção dos projetos e modelos em produção, em meio ao crescimento da empresa.')
# ('P3_d_12 ', 'Conseguir levar inovação para a empresa através dos dados.')
#
# Part 3:
# ('P3_d_13 ', 'Garantir retorno do investimento (ROI) em projetos de dados.')
# ('P3_d_14 ', 'Dividir o tempo entre entregas técnicas e gestão.')
# ('P4_a ', 'Mesmo que esse não seja seu cargo formal, você considera que sua atuação no dia a dia, reflete alguma das opções listadas abaixo?')
# ('P4_a_1 ', 'Atuacao')
# ('P4_b ', 'Quais das fontes de dados listadas você já analisou ou processou no trabalho?')
# ('P4_b_1 ', 'Dados relacionais (estruturados em bancos SQL)')
# ('P4_b_2 ', 'Dados armazenados em bancos NoSQL')
# ('P4_b_3 ', 'Imagens')
# ('P4_b_4 ', 'Textos/Documentos')
# ('P4_b_5 ', 'Vídeos')
# ('P4_b_6 ', 'Áudios')
# ('P4_b_7 ', 'Planilhas')
# ('P4_b_8 ', 'Dados georeferenciados')
# ('P4_c ', 'Entre as fontes de dados listadas, quais você utiliza na maior parte do tempo?')
# ('P4_c_1 ', 'Dados relacionais (estruturados em bancos SQL)')
# ('P4_c_2 ', 'Dados armazenados em bancos NoSQL')
# ('P4_c_3 ', 'Imagens')
# ('P4_c_4 ', 'Textos/Documentos')
# ('P4_c_5 ', 'Vídeos')
# ('P4_c_6 ', 'Áudios')
# ('P4_c_7 ', 'Planilhas')
# ('P4_c_8 ', 'Dados georeferenciados')
# ('P4_d ', 'Quais das linguagens listadas abaixo você utiliza no trabalho?')
# ('P4_d_1 ', 'SQL')
# ('P4_d_2 ', 'R ')
# ('P4_d_3 ', 'Python')
# ('P4_d_4 ', 'C/C++/C#')
# ('P4_d_5 ', '.NET')
# ('P4_d_6 ', 'Java')
# ('P4_d_7 ', 'Julia')
# ('P4_d_8 ', 'SAS/Stata')
# ('P4_d_9 ', 'Visual Basic/VBA')
# ('P4_d_10 ', 'Scala')
# ('P4_d_11 ', 'Matlab')
# ('P4_d_12 ', 'PHP')
# ('P4_d_13 ', 'Javascript')
# ('P4_d_14 ', 'Não utilizo nenhuma linguagem')
# ('P4_e ', 'Entre as linguagens listadas abaixo, qual é a que você mais utiliza no trabalho?')
# ('P4_f ', 'Entre as linguagens listadas abaixo, qual é a sua preferida?')
# ('P4_g ', 'Quais dos bancos de dados/fontes de dados listados abaixo você utiliza no trabalho?')
# ('P4_g_1 ', 'MySQL')
# ('P4_g_2 ', 'Oracle')
# ('P4_g_3 ', 'SQL SERVER')
# ('P4_f_4 ', 'Amazon Aurora ou RDS')
#
# Part 4:
# ('P4_f_5 ', 'DynamoDB')
# ('P4_f_6 ', 'CoachDB')
# ('P4_f_7 ', 'Cassandra')
# ('P4_f_8 ', 'MongoDB')
# ('P4_f_9 ', 'MariaDB')
# ('P4_f_10 ', 'Datomic')
# ('P4_f_11 ', 'S3')
# ('P4_f_12 ', 'PostgreSQL')
# ('P4_f_13 ', 'ElasticSearch')
# ('P4_f_14 ', 'DB2')
# ('P4_f_15 ', 'Microsoft Access')
# ('P4_f_16 ', 'SQLite')
# ('P4_f_17 ', 'Sybase')
# ('P4_f_18 ', 'Firebase')
# ('P4_f_19 ', 'Vertica')
# ('P4_f_20 ', 'Redis')
# ('P4_f_21 ', 'Neo4J')
# ('P4_f_22 ', 'Google BigQuery')
# ('P4_f_23 ', 'Google Firestore')
# ('P4_f_24 ', 'Amazon Redshift')
# ('P4_f_25 ', 'Amazon Athena')
# ('P4_f_26 ', 'Snowflake')
# ('P4_f_27 ', 'Databricks')
# ('P4_f_28 ', 'HBase')
# ('P4_f_29 ', 'Presto')
# ('P4_f_30 ', 'Splunk')
# ('P4_f_31 ', 'SAP HANA')
# ('P4_f_32 ', 'Hive')
# ('P4_f_33 ', 'Firebird')
# ('P4_g ', 'Quais das opções de Cloud listadas abaixo você utiliza no trabalho?')
# ('P4_h ', 'Dentre as opções listadas, qual sua Cloud preferida?')
# ('P4_h_1 ', 'Azure (Microsoft)')
# ('P4_h_2 ', 'Amazon Web Services (AWS)')
# ('P4_h_3 ', 'Google Cloud (GCP)')
# ('P4_i ', 'Microsoft PowerBI')
# ('P4_i_1 ', 'Microsoft PowerBI')
# ('P4_i_2 ', 'Qlik View/Qlik Sense')
# ('P4_i_3 ', 'Tableau')
# ('P4_i_4 ', 'Metabase')
# ('P4_i_5 ', 'Superset')
# ('P4_i_6 ', 'Redash')
# ('P4_i_7 ', 'MicroStrategy')
# ('P4_i_8 ', 'IBM Analytics/Cognos')
# ('P4_i_9 ', 'SAP Business Objects')
#
# Part 5:
# ('P4_i_10 ', 'Oracle Business Intelligence')
# ('P4_i_11 ', 'Amazon QuickSight')
# ('P4_i_12 ', 'Salesforce/Einstein Analytics')
# ('P4_i_13 ', 'Mode')
# ('P4_i_14 ', 'Alteryx')
# ('P4_i_15 ', 'Birst')
# ('P4_i_16 ', 'Looker')
# ('P4_i_17 ', 'Google Data Studio')
# ('P4_i_18 ', 'SAS Visual Analytics')
# ('P4_i_19 ', 'Grafana')
# ('P4_i_20 ', 'TIBCO Spotfire')
# ('P4_i_21 ', 'Pentaho')
# ('P4_i_22 ', 'Fazemos todas as análises utilizando apenas Excel ou planilhas do google')
# ('P4_i_23 ', 'Não utilizo nenhuma ferramenta de BI no trabalho')
# ('P5_a ', 'Qual seu objetivo na área de dados?')
# ('P5_b ', 'Qual oportunidade você está buscando?')
# ('P5_c ', 'Há quanto tempo você busca uma oportunidade na área de dados?')
# ('P5_d ', 'Como tem sido a busca por um emprego na área de dados?')
# ('P6_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual como engenheiro de dados?')
# ('P6_a_1 ', 'Desenvolvo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')
# ('P6_a_2 ', 'Realizo construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')
# ('P6_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P6_a_4 ', 'Atuo na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')
# ('P6_a_5 ', 'Modelo soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')
# ('P6_a_6 ', 'Desenvolvo/cuido da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')
# ('P6_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')
# ('P6_a_8 ', 'Cuido da qualidade dos dados, metadados e dicionário de dados.')
# ('P6_a_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')
# ('P6_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Engineer?')
# ('P6_b_1 ', 'Scripts Python')
# ('P6_b_2 ', 'SQL & Stored Procedures')
# ('P6_b_3 ', 'Apache Airflow')
# ('P6_b_4 ', 'Luigi')
# ('P6_b_5 ', 'AWS Glue')
# ('P6_b_6 ', 'Talend')
# ('P6_b_7 ', 'Pentaho')
# ('P6_b_8 ', 'Alteryx')
# ('P6_b_9 ', 'Stitch')
# ('P6_b_10 ', 'Fivetran')
# ('P6_b_11 ', 'Google Dataflow')
# ('P6_b_12 ', 'Oracle Data Integrator')
# ('P6_b_13 ', 'IBM DataStage')
# ('P6_b_14 ', 'SAP BW ETL')
# ('P6_b_15 ', 'SQL Server Integration Services (SSIS)')
#
# Part 6:
# ('P6_b_16 ', 'SAS Data Integration')
# ('P6_b_17 ', 'Qlik Sense')
# ('P6_b_18 ', 'Knime')
# ('P6_b_19 ', 'Databricks')
# ('P6_b_19 ', 'Não utilizo ferramentas de ETL')
# ('P6_c ', 'Sua organização possui um Data Lake?')
# ('P6_d ', 'Qual tecnologia utilizada como plataforma do Data Lake?')
# ('P6_e ', 'Sua organização possui um Data Warehouse?')
# ('P6_f ', 'Qual tecnologia utilizada como plataforma do Data Warehouse?')
# ('P6_g ', 'Quais as ferramentas de gestão de Qualidade de dados, Metadados e catálogo de dados você utiliza no trabalho?')
# ('P6_g_1 ', 'great_expectations')
# ('P6_g_2 ', 'dbt')
# ('P6_g_3 ', 'AWS Deequ')
# ('P6_g_4 ', 'Apache Griffin')
# ('P6_g_5 ', 'Datafold')
# ('P6_g_6 ', 'Amundsen')
# ('P6_g_7 ', 'Monte Carlo')
# ('P6_g_8 ', 'SODA')
# ('P6_g_9 ', 'Big Eye')
# ('P6_g_10 ', 'Data Band')
# ('P6_g_11 ', 'Anomalo')
# ('P6_g_l ', 'Metaplane')
# ('P6_g_m ', 'Acceldata')
# ('P6_h ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo?')
# ('P6_h_1 ', 'Desenvolvendo pipelines de dados utilizando linguagens de programação como Python, Scala, Java etc.')
# ('P6_h_2 ', 'Realizando construções de ETL's em ferramentas como Pentaho, Talend, Dataflow etc.')
# ('P6_h_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P6_h_4 ', 'Atuando na integração de diferentes fontes de dados através de plataformas proprietárias como Stitch Data, Fivetran etc.')
# ('P6_h_5 ', 'Modelando soluções de arquitetura de dados, criando componentes de ingestão de dados, transformação e recuperação da informação.')
# ('P6_h_6 ', 'Desenvolvendo/cuidando da manutenção de repositórios de dados baseados em streaming de eventos como Data Lakes e Data Lakehouses.')
# ('P6_h_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados como Data Warehouses, Data Marts etc.')
# ('P6_h_8 ', 'Cuidando da qualidade dos dados, metadados e dicionário de dados.')
# ('P6_h_9 ', 'Nenhuma das opções listadas refletem meu dia a dia.')
# ('P7_1 ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com análise de dados?')
# ('P7_a_1 ', 'Processo e analiso dados utilizando linguagens de programação como Python, R etc.')
# ('P7_a_2 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')
# ('P7_a_3 ', 'Crio consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P7_a_4 ', 'Utilizo API's para extrair dados e complementar minhas análises.')
# ('P7_a_5 ', 'Realizo experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')
# ('P7_a_6 ', 'Desenvolvo/cuido da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')
# ('P7_a_7 ', 'Atuo na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')
# ('P7_a_8 ', 'Desenvolvo/cuido da manutenção de planilhas para atender as áreas de negócio.')
# ('P7_a_9 ', 'Utilizo ferramentas avançadas de estatística como SAS')
# ('P7_a_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')
#
# Part 7:
# ('P7_b ', 'Quais as ferramentas/tecnologias de ETL que você utiliza no trabalho como Data Analyst?')
# ('P7_b_1 ', 'Scripts Python')
# ('P7_b_2 ', 'SQL & Stored Procedures')
# ('P7_b_3 ', 'Apache Airflow')
# ('P7_b_4 ', 'Luigi')
# ('P7_b_5 ', 'AWS Glue')
# ('P7_b_6 ', 'Talend')
# ('P7_b_7 ', 'Pentaho')
# ('P7_b_8 ', 'Alteryx')
# ('P7_b_9 ', 'Stitch')
# ('P7_b_10 ', 'Fivetran')
# ('P7_b_11 ', 'Google Dataflow')
# ('P7_b_12 ', 'Oracle Data Integrator')
# ('P7_b_13 ', 'IBM DataStage')
# ('P7_b_14 ', 'SAP BW ETL')
# ('P7_b_15 ', 'SQL Server Integration Services (SSIS)')
# ('P7_b_16 ', 'SAS Data Integration')
# ('P7_b_17 ', 'Qlik Sense')
# ('P7_b_18 ', 'Knime')
# ('P7_b_19 ', 'Databricks')
# ('P7_b_20 ', 'Não utilizo ferramentas de ETL')
# ('P7_c ', 'Sua empresa utiliza alguma das ferramentas listadas para dar mais autonomia em análise de dados para as áreas de negócio?')
# ('P7_c_1 ', 'Ferramentas de AutoML como H2O.ai, Data Robot, BigML etc.')
# ('P7_c_2 ', '""Point and Click"" Analytics como Alteryx, Knime, Rapidminer etc.')
# ('P7_c_3 ', 'Product metricts & Insights como Mixpanel, Amplitude, Adobe Analytics.')
# ('P7_c_4 ', 'Ferramentas de análise dentro de ferramentas de CRM como Salesforce Einstein Anaytics ou Zendesk dashboards.')
# ('P7_c_5 ', 'Minha empresa não utiliza essas ferramentas.')
# ('P7_c_6 ', 'Não sei informar.')
# ('P7_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo de trabalho?')
# ('P7_d_1 ', 'Processando e analisando dados utilizando linguagens de programação como Python, R etc.')
# ('P7_d_2 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik etc.')
# ('P7_d_3 ', 'Criando consultas através da linguagem SQL para exportar informações e compartilhar com as áreas de negócio.')
# ('P7_d_4 ', 'Utilizando API's para extrair dados e complementar minhas análises.')
# ('P7_d_5 ', 'Realizando experimentos e estudos utilizando metodologias estatísticas como teste de hipótese, modelos de regressão etc.')
# ('P7_d_6 ', 'Desenvolvendo/cuidando da manutenção de ETL's utilizando tecnologias como Talend, Pentaho, Airflow, Dataflow etc.')
# ('P7_d_7 ', 'Atuando na modelagem dos dados, com o objetivo de criar conjuntos de dados, Data Warehouses, Data Marts etc.')
# ('P7_d_8 ', 'Desenvolvendo/cuidando da manutenção de planilhas do Excel ou Google Sheets para atender as áreas de negócio.')
# ('P7_d_9 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')
# ('P7_d_10 ', 'Nenhuma das opções listadas refletem meu dia a dia.')
# ('P8_a ', 'Quais das opções abaixo fazem parte da sua rotina no trabalho atual com ciência de dados?')
# ('P8_a_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')
# ('P8_a_2 ', 'Sou responsável pela coleta e limpeza dos dados que uso para análise e modelagem.')
# ('P8_a_3 ', 'Sou responsável por entrar em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')
# ('P8_a_4 ', 'Desenvolvo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')
#
# Part 8:
# ('P8_a_5 ', 'Sou responsável por colocar modelos em produção, criar os pipelines de dados, APIs de consumo e monitoramento.')
# ('P8_a_6 ', 'Cuido da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')
# ('P8_a_7 ', 'Realizo construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc')
# ('P8_a_8 ', 'Utilizo ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises estatísticas e ajustar modelos.Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')
# ('P8_a_9 ', 'Crio e dou manutenção em ETLs, DAGs e automações de pipelines de dados.')
# ('P8_a_10 ', 'Crio e gerencio soluções de Feature Store e cultura de MLOps.')
# ('P8_a_11 ', 'Sou responsável por criar e manter a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')
# ('P8_b ', 'Quais as técnicas e métodos listados abaixo você costuma utilizar no trabalho?')
# ('P8_b_1 ', 'Utilizo modelos de regressão (linear, logística, GLM)')
# ('P8_b_2 ', 'Utilizo redes neurais ou modelos baseados em árvore para criar modelos de classificação')
# ('P8_b_3 ', 'Desenvolvo sistemas de recomendação (RecSys)')
# ('P8_b_4 ', 'Utilizo métodos estatísticos Bayesianos para analisar dados')
# ('P8_b_5 ', 'Utilizo técnicas de NLP (Natural Language Processing) para análisar dados não-estruturados')
# ('P8_b_6 ', 'Utilizo métodos estatísticos clássicos (Testes de hipótese, análise multivariada, sobrevivência, dados longitudinais, inferência estatistica) para analisar dados')
# ('P8_b_7 ', 'Utilizo cadeias de Markov ou HMM's para realizar análises de dados')
# ('P8_b_8 ', 'Desenvolvo técnicas de Clusterização (K-means, Spectral, DBScan etc)')
# ('P8_b_9 ', 'Realizo previsões através de modelos de Séries Temporais (Time Series)')
# ('P8_b_10 ', 'Utilizo modelos de Reinforcement Learning (aprendizado por reforço)')
# ('P8_b_11 ', 'Utilizo modelos de Machine Learning para detecção de fraude')
# ('P8_b_l ', 'Utilizo métodos de Visão Computacional')
# ('P8_b_m ', 'Utilizo modelos de Detecção de Churn')
# ('P8_3 ', 'Quais dessas tecnologias fazem parte do seu dia a dia como cientista de dados?')
# ('P8_c_1 ', 'Ferramentas de BI (PowerBI, Looker, Tableau, Qlik etc)')
# ('P8_c_2 ', 'Planilhas (Excel, Google Sheets etc)')
# ('P8_c_3 ', 'Ambientes de desenvolvimento local (R-studio, JupyterLab, Anaconda)')
# ('P8_c_4 ', 'Ambientes de desenvolvimento na nuvem (Google Colab, AWS Sagemaker, Kaggle Notebooks etc)')
# ('P8_c_5 ', 'Ferramentas de AutoML (Datarobot, H2O, Auto-Keras etc)')
# ('P8_c_6 ', 'Ferramentas de ETL (Apache Airflow, NiFi, Stitch, Fivetran, Pentaho etc)')
# ('P8_c_7 ', 'Plataformas de Machine Learning (TensorFlow, Azure Machine Learning, Kubeflow etc)')
# ('P8_c_8 ', 'Feature Store (Feast, Hopsworks, AWS Feature Store, Databricks Feature Store etc)')
# ('P8_c_9 ', 'Sistemas de controle de versão (Github, DVC, Neptune, Gitlab etc)')
# ('P8_c_10 ', 'Plataformas de Data Apps (Streamlit, Shiny, Plotly Dash etc)')
# ('P8_c_11 ', 'Ferramentas de estatística avançada como SPSS, SAS, etc.')
# ('P8_d ', 'Em qual das opções abaixo você gasta a maior parte do seu tempo no trabalho?')
# ('P8_d_1 ', 'Estudos Ad-hoc com o objetivo de confirmar hipóteses, realizar modelos preditivos, forecasts, análise de cluster para resolver problemas pontuais e responder perguntas das áreas de negócio.')
# ('P8_d_2 ', 'Coletando e limpando os dados que uso para análise e modelagem.')
# ('P8_d_3 ', 'Entrando em contato com os times de negócio para definição do problema, identificar a solução e apresentação de resultados.')
# ('P8_d_4 ', 'Desenvolvendo modelos de Machine Learning com o objetivo de colocar em produção em sistemas (produtos de dados).')
# ('P8_d_5 ', 'Colocando modelos em produção, criando os pipelines de dados, APIs de consumo e monitoramento.')
# ('P8_d_6 ', 'Cuidando da manutenção de modelos de Machine Learning já em produção, atuando no monitoramento, ajustes e refatoração quando necessário.')
# ('P8_d_7 ', 'Realizando construções de dashboards em ferramentas de BI como PowerBI, Tableau, Looker, Qlik, etc.')
# ('P8_d_8 ', 'Utilizando ferramentas avançadas de estatística como SAS, SPSS, Stata etc, para realizar análises.')
# ('P8_d_9 ', 'Criando e dando manutenção em ETLs, DAGs e automações de pipelines de dados.')
# ('P8_d_10 ', 'Criando e gerenciando soluções de Feature Store e cultura de MLOps.')
#
# Part 9:
# ('P8_d_11 ', 'Criando e mantendo a infra que meus modelos e soluções rodam (clusters, servidores, API, containers, etc.)')

# %% [markdown]
# ##REMOÇÃO DAS COLUNAS DESNECESSÁRIAS PARA O NOSSO PROJETO.

# %%
df_2022 = df_2022.drop(df_2022.columns[52:], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[0], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[-1], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[3:8], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[10], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[12], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[19], axis=1)

# %%
df_2022 = df_2022.drop(df_2022.columns[26:36], axis=1)

# %%
# Colunas a serem removidas
colunas_eliminar2 = [
    "('P1_i_2 ', 'Regiao onde mora')",
    "('P1_k ', 'Regiao de origem')",
    "('P2_e ', 'Cargo como Gestor')",
    "('P2_l_1 ', 'Falta de oportunidade de crescimento no emprego atual')",
    "('P2_l_2 ', 'Salário atual não corresponde ao mercado')",
    "('P2_l_3 ', 'Não tenho uma boa relação com meu líder/gestor')",
    "('P2_l_4 ', 'Gostaria de trabalhar em em outra área de atuação')",
    "('P2_l_5 ', 'Gostaria de receber mais benefícios')",
    "('P2_l_6 ', 'O clima de trabalho/ambiente não é bom')",
    "('P2_l_7 ', 'Falta de maturidade analítica na empresa')"
]

# Remover as colunas especificadas
df_2022 = df_2022.drop(columns=colunas_eliminar2, axis=1)

# %% [markdown]
# ##RESULTADO DATAFRAME 2022 - DROP REALIZADO

# %%
df_2022
# Out:
#       ('P1_a ', 'Idade') ('P1_a_1 ', 'Faixa idade') ('P1_b ', 'Genero')  \
# 0                  39.00                      35-39           Masculino
# 1                  32.00                      30-34           Masculino
# 2                  53.00                      50-54           Masculino
# 3                  27.00                      25-29           Masculino
# 4                  46.00                      45-49            Feminino
# ...                  ...                        ...                 ...
# 4266               26.00                      25-29           Masculino
# 4267               30.00                      30-34            Feminino
# 4268               29.00                      25-29           Masculino
# 4269                 NaN                      17-21           Masculino
# 4270               24.00                      22-24           Masculino
#
#      ('P1_i ', 'Estado onde mora') ('P1_i_1 ', 'uf onde mora')  \
# 0            Distrito Federal (DF)                          DF
# 1                        Pará (PA)                          PA
# 2            Distrito Federal (DF)                          DF
# 3                Minas Gerais (MG)                          MG
# 4                        Pará (PA)                          PA
# ...                            ...                         ...
# 4266                São Paulo (SP)                          SP
# 4267             Minas Gerais (MG)                          MG
# 4268                São Paulo (SP)                          SP
# 4269                São Paulo (SP)                          SP
# 4270                    Goiás (GO)                          GO
#
#      ('P1_j ', 'Mudou de Estado?') ('P1_l ', 'Nivel de Ensino')  \
# 0                            False                Pós-graduação
# 1                             True        Graduação/Bacharelado
# 2                            False                Pós-graduação
# 3                             True             Doutorado ou Phd
# 4                             True                Pós-graduação
# ...                            ...                          ...
# 4266                          True        Graduação/Bacharelado
# 4267                          True                     Mestrado
# 4268                         False                     Mestrado
# 4269                          True   Não tenho graduação formal
# 4270                         False        Graduação/Bacharelado
#
#                           ('P1_m ', 'Área de Formação')  \
# 0     Computação / Engenharia de Software / Sistemas...
# 1                                    Outras Engenharias
# 2     Computação / Engenharia de Software / Sistemas...
# 3     Estatística/ Matemática / Matemática Computaci...
# 4     Computação / Engenharia de Software / Sistemas...
# ...                                                 ...
# 4266  Computação / Engenharia de Software / Sistemas...
# 4267                                 Outras Engenharias
# 4268                                 Outras Engenharias
# 4269                                                NaN
# 4270  Computação / Engenharia de Software / Sistemas...
#
#                        ('P2_b ', 'Setor') ('P2_c ', 'Numero de Funcionarios')  \
# 0                           Setor Público                      Acima de 3.000
# 1                             Outra Opção                      Acima de 3.000
# 2                      Finanças ou Bancos                      Acima de 3.000
# 3                        Setor Automotivo                      Acima de 3.000
# 4                           Setor Público                        de 101 a 500
# ...                                   ...                                 ...
# 4266       Tecnologia/Fábrica de Software                      Acima de 3.000
# 4267                  Área de Consultoria                         de 51 a 100
# 4268  Setor Imobiliário/ Construção Civil                        de 101 a 500
# 4269                            Indústria                    de 1.001 a 3.000
# 4270                         Agronegócios                      de 501 a 1.000
#
#                                ('P2_f ', 'Cargo Atual') ('P2_g ', 'Nivel')  \
# 0                   DBA/Administrador de Banco de Dados             Júnior
# 1                                                   NaN                NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...              Pleno
# 3                     Cientista de Dados/Data Scientist             Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...              Pleno
# ...                                                 ...                ...
# 4266                     Analista de Dados/Data Analyst              Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...              Pleno
# 4268                                                NaN                NaN
# 4269                                        Outra Opção             Júnior
# 4270                     Analista de Dados/Data Analyst             Júnior
#
#            ('P2_h ', 'Faixa salarial')  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# ...                                ...
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#      ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')  \
# 0                                         de 1 a 2 anos
# 1                                         de 3 a 4 anos
# 2                                         de 3 a 4 anos
# 3                                         de 4 a 6 anos
# 4                Não tenho experiência na área de dados
# ...                                                 ...
# 4266                                      de 3 a 4 anos
# 4267                                      de 1 a 2 anos
# 4268                                      de 4 a 6 anos
# 4269                                     Menos de 1 ano
# 4270                                      de 1 a 2 anos
#
#      ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#      ('P2_k ', 'Você está satisfeito na sua empresa atual?')  \
# 0                                                  True
# 1                                                 False
# 2                                                 False
# 3                                                  True
# 4                                                 False
# ...                                                 ...
# 4266                                               True
# 4267                                               True
# 4268                                               True
# 4269                                               True
# 4270                                              False
#
#       ('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')  \
# 0                                                  0.00
# 1                                                  0.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               0.00
# 4269                                               0.00
# 4270                                               0.00
#
#       ('P2_o_9 ', 'Qualidade dos gestores e líderes')  \
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# ...                                               ...
# 4266                                             0.00
# 4267                                             0.00
# 4268                                             0.00
# 4269                                             0.00
# 4270                                             0.00
#
#       ('P2_o_10 ', 'Reputação que a empresa tem no mercado')  \
# 0                                                  0.00
# 1                                                  1.00
# 2                                                  0.00
# 3                                                  0.00
# 4                                                  0.00
# ...                                                 ...
# 4266                                               0.00
# 4267                                               0.00
# 4268                                               0.00
# 4269                                               1.00
# 4270                                               1.00
#
#      ('P2_p ', 'Atualmente qual a sua forma de trabalho?')  \
# 0                                Modelo 100% presencial
# 1                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4268  Modelo híbrido com dias fixos de trabalho pres...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#      ('P2_q ', 'Qual a forma de trabalho ideal para você?')  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4268  Modelo híbrido flexível (o funcionário tem lib...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#      ('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')
# 0      Vou aceitar e retornar ao modelo 100% presencial
# 1      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4      Vou aceitar e retornar ao modelo 100% presencial
# ...                                                 ...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4268  Vou procurar outra oportunidade no modelo híbr...
# 4269   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
# [4271 rows x 22 columns]

# %% [markdown]
# ##RESULTADO DATAFRAME 2022 EM LISTA - DROP REALIZADO

# %%
df_2022.columns.tolist()
# Out:
# ["('P1_a ', 'Idade')",
#  "('P1_a_1 ', 'Faixa idade')",
#  "('P1_b ', 'Genero')",
#  "('P1_i ', 'Estado onde mora')",
#  "('P1_i_1 ', 'uf onde mora')",
#  "('P1_j ', 'Mudou de Estado?')",
#  "('P1_l ', 'Nivel de Ensino')",
#  "('P1_m ', 'Área de Formação')",
#  "('P2_b ', 'Setor')",
#  "('P2_c ', 'Numero de Funcionarios')",
#  "('P2_f ', 'Cargo Atual')",
#  "('P2_g ', 'Nivel')",
#  "('P2_h ', 'Faixa salarial')",
#  "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')",
#  "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')",
#  "('P2_k ', 'Você está satisfeito na sua empresa atual?')",
#  "('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')",
#  "('P2_o_9 ', 'Qualidade dos gestores e líderes')",
#  "('P2_o_10 ', 'Reputação que a empresa tem no mercado')",
#  "('P2_p ', 'Atualmente qual a sua forma de trabalho?')",
#  "('P2_q ', 'Qual a forma de trabalho ideal para você?')",
#  "('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')"]

# %% [markdown]
# ##CÁLCULO

# %%
# Calcular a porcentagem de valores nulos em cada coluna
porcentagem_nulos = (df_2022.isnull().sum() / len(df_2022)) * 100

# %%
# Exibir a porcentagem de valores nulos em cada coluna
print(round(porcentagem_nulos,1))
# Out:
# ('P1_a ', 'Idade')                                                                                                                        1.70
# ('P1_a_1 ', 'Faixa idade')                                                                                                                0.00
# ('P1_b ', 'Genero')                                                                                                                       0.20
# ('P1_i ', 'Estado onde mora')                                                                                                             2.70
# ('P1_i_1 ', 'uf onde mora')                                                                                                               2.70
# ('P1_j ', 'Mudou de Estado?')                                                                                                             2.30
# ('P1_l ', 'Nivel de Ensino')                                                                                                              0.00
# ('P1_m ', 'Área de Formação')                                                                                                             2.90
# ('P2_b ', 'Setor')                                                                                                                       13.50
# ('P2_c ', 'Numero de Funcionarios')                                                                                                      13.50
# ('P2_f ', 'Cargo Atual')                                                                                                                 30.20
# ('P2_g ', 'Nivel')                                                                                                                       30.20
# ('P2_h ', 'Faixa salarial')                                                                                                              13.50
# ('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')                                                                      13.50
# ('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')   13.50
# ('P2_k ', 'Você está satisfeito na sua empresa atual?')                                                                                  13.50
# ('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')                                                                     13.50
# ('P2_o_9 ', 'Qualidade dos gestores e líderes')                                                                                          13.50
# ('P2_o_10 ', 'Reputação que a empresa tem no mercado')                                                                                   13.50
# ('P2_p ', 'Atualmente qual a sua forma de trabalho?')                                                                                    13.50
# ('P2_q ', 'Qual a forma de trabalho ideal para você?')                                                                                   13.50
# ('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')                                                  13.50
# dtype: float64

# %% [markdown]
# ##RENOMEANDO AS COLUNAS DO DATAFRAME 2022

# %%
# Define o mapeamento das colunas

column_mapping2022 = {
    "('P1_a ', 'Idade')": "Idade",
    "('P1_a_1 ', 'Faixa idade')": "Faixa idade",
    "('P1_b ', 'Genero')": "Genero",
    "('P1_i ', 'Estado onde mora')": "Estado onde mora",
    "('P1_i_1 ', 'uf onde mora')": "UF onde mora",
    "('P1_j ', 'Mudou de Estado?')": "Mudou de Estado?",
    "('P1_l ', 'Nivel de Ensino')": "Nivel de Ensino",
    "('P1_m ', 'Área de Formação')": "Área de Formação",
    "('P2_b ', 'Setor')": "Setor",
    "('P2_c ', 'Numero de Funcionarios')": "Número de Funcionários",
    "('P2_f ', 'Cargo Atual')": "Cargo Atual",
    "('P2_g ', 'Nivel')": "Nível",
    "('P2_h ', 'Faixa salarial')": "Faixa salarial",
    "('P2_i ', 'Quanto tempo de experiência na área de dados você tem?')": "Experiência na área de dados",
    "('P2_j ', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?')": "Experiência prévia em TI/Engenharia de Software",
    "('P2_k ', 'Você está satisfeito na sua empresa atual?')": "Satisfação com a empresa atual",
    "('P2_o_8 ', 'Maturidade da empresa em termos de tecnologia e dados')": "Maturidade em tecnologia e dados",
    "('P2_o_9 ', 'Qualidade dos gestores e líderes')": "Qualidade dos gestores e líderes",
    "('P2_o_10 ', 'Reputação que a empresa tem no mercado')": "Reputação da empresa no mercado",
    "('P2_p ', 'Atualmente qual a sua forma de trabalho?')": "Forma de trabalho atual",
    "('P2_q ', 'Qual a forma de trabalho ideal para você?')": "Forma de trabalho ideal",
    "('P2_r ', 'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?')": "Atitude em caso de modelo 100% presencial"
}

# Renomeia as colunas
df_2022.rename(columns=column_mapping2022, inplace=True)

# Imprime o DataFrame para verificar as alterações
print(df_2022)
# Out:
#       Idade Faixa idade     Genero       Estado onde mora UF onde mora  \
# 0     39.00       35-39  Masculino  Distrito Federal (DF)           DF
# 1     32.00       30-34  Masculino              Pará (PA)           PA
# 2     53.00       50-54  Masculino  Distrito Federal (DF)           DF
# 3     27.00       25-29  Masculino      Minas Gerais (MG)           MG
# 4     46.00       45-49   Feminino              Pará (PA)           PA
# ...     ...         ...        ...                    ...          ...
# 4266  26.00       25-29  Masculino         São Paulo (SP)           SP
# 4267  30.00       30-34   Feminino      Minas Gerais (MG)           MG
# 4268  29.00       25-29  Masculino         São Paulo (SP)           SP
# 4269    NaN       17-21  Masculino         São Paulo (SP)           SP
# 4270  24.00       22-24  Masculino             Goiás (GO)           GO
#
#      Mudou de Estado?             Nivel de Ensino  \
# 0               False               Pós-graduação
# 1                True       Graduação/Bacharelado
# 2               False               Pós-graduação
# 3                True            Doutorado ou Phd
# 4                True               Pós-graduação
# ...               ...                         ...
# 4266             True       Graduação/Bacharelado
# 4267             True                    Mestrado
# 4268            False                    Mestrado
# 4269             True  Não tenho graduação formal
# 4270            False       Graduação/Bacharelado
#
#                                        Área de Formação  \
# 0     Computação / Engenharia de Software / Sistemas...
# 1                                    Outras Engenharias
# 2     Computação / Engenharia de Software / Sistemas...
# 3     Estatística/ Matemática / Matemática Computaci...
# 4     Computação / Engenharia de Software / Sistemas...
# ...                                                 ...
# 4266  Computação / Engenharia de Software / Sistemas...
# 4267                                 Outras Engenharias
# 4268                                 Outras Engenharias
# 4269                                                NaN
# 4270  Computação / Engenharia de Software / Sistemas...
#
#                                     Setor Número de Funcionários  \
# 0                           Setor Público         Acima de 3.000
# 1                             Outra Opção         Acima de 3.000
# 2                      Finanças ou Bancos         Acima de 3.000
# 3                        Setor Automotivo         Acima de 3.000
# 4                           Setor Público           de 101 a 500
# ...                                   ...                    ...
# 4266       Tecnologia/Fábrica de Software         Acima de 3.000
# 4267                  Área de Consultoria            de 51 a 100
# 4268  Setor Imobiliário/ Construção Civil           de 101 a 500
# 4269                            Indústria       de 1.001 a 3.000
# 4270                         Agronegócios         de 501 a 1.000
#
#                                             Cargo Atual   Nível  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 1                                                   NaN     NaN
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 3                     Cientista de Dados/Data Scientist  Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# ...                                                 ...     ...
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4268                                                NaN     NaN
# 4269                                        Outra Opção  Júnior
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#                         Faixa salarial  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 1       de R$ 4.001/mês a R$ 6.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# ...                                ...
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4268  de R$ 16.001/mês a R$ 20.000/mês
# 4269             Menos de R$ 1.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#                 Experiência na área de dados  \
# 0                              de 1 a 2 anos
# 1                              de 3 a 4 anos
# 2                              de 3 a 4 anos
# 3                              de 4 a 6 anos
# 4     Não tenho experiência na área de dados
# ...                                      ...
# 4266                           de 3 a 4 anos
# 4267                           de 1 a 2 anos
# 4268                           de 4 a 6 anos
# 4269                          Menos de 1 ano
# 4270                           de 1 a 2 anos
#
#         Experiência prévia em TI/Engenharia de Software  \
# 0                                        de 7 a 10 anos
# 1                                        Menos de 1 ano
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# ...                                                 ...
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4268  Não tive experiência na área de TI/Engenharia ...
# 4269  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#      Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 0                              True                              0.00
# 1                             False                              0.00
# 2                             False                              0.00
# 3                              True                              0.00
# 4                             False                              0.00
# ...                             ...                               ...
# 4266                           True                              0.00
# 4267                           True                              0.00
# 4268                           True                              0.00
# 4269                           True                              0.00
# 4270                          False                              0.00
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 0                                 0.00                             0.00
# 1                                 0.00                             1.00
# 2                                 0.00                             0.00
# 3                                 0.00                             0.00
# 4                                 0.00                             0.00
# ...                                ...                              ...
# 4266                              0.00                             0.00
# 4267                              0.00                             0.00
# 4268                              0.00                             0.00
# 4269                              0.00                             1.00
# 4270                              0.00                             1.00
#
#                                 Forma de trabalho atual  \
# 0                                Modelo 100% presencial
# 1                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4268  Modelo híbrido com dias fixos de trabalho pres...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#                                 Forma de trabalho ideal  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 1     Modelo híbrido flexível (o funcionário tem lib...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# ...                                                 ...
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4268  Modelo híbrido flexível (o funcionário tem lib...
# 4269                             Modelo 100% presencial
# 4270                                 Modelo 100% remoto
#
#               Atitude em caso de modelo 100% presencial
# 0      Vou aceitar e retornar ao modelo 100% presencial
# 1      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4      Vou aceitar e retornar ao modelo 100% presencial
# ...                                                 ...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4268  Vou procurar outra oportunidade no modelo híbr...
# 4269   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
# [4271 rows x 22 columns]

# %% [markdown]
# ##CHECAGEM DO TIPO DOS DADOS DO DATAFRAME 2022

# %%
# Comando usado neste momento para verificar o balanceamento do dataframe
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 22 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Idade                                            4197 non-null   float64
#  1   Faixa idade                                      4271 non-null   object
#  2   Genero                                           4262 non-null   object
#  3   Estado onde mora                                 4156 non-null   object
#  4   UF onde mora                                     4156 non-null   object
#  5   Mudou de Estado?                                 4171 non-null   object
#  6   Nivel de Ensino                                  4271 non-null   object
#  7   Área de Formação                                 4149 non-null   object
#  8   Setor                                            3694 non-null   object
#  9   Número de Funcionários                           3694 non-null   object
#  10  Cargo Atual                                      2981 non-null   object
#  11  Nível                                            2981 non-null   object
#  12  Faixa salarial                                   3694 non-null   object
#  13  Experiência na área de dados                     3694 non-null   object
#  14  Experiência prévia em TI/Engenharia de Software  3694 non-null   object
#  15  Satisfação com a empresa atual                   3694 non-null   object
#  16  Maturidade em tecnologia e dados                 3694 non-null   float64
#  17  Qualidade dos gestores e líderes                 3694 non-null   float64
#  18  Reputação da empresa no mercado                  3694 non-null   float64
#  19  Forma de trabalho atual                          3694 non-null   object
#  20  Forma de trabalho ideal                          3694 non-null   object
#  21  Atitude em caso de modelo 100% presencial        3694 non-null   object
# dtypes: float64(4), object(18)
# memory usage: 734.2+ KB

# %%
# Remover linhas com valores não finitos na coluna "Idade"
df_2022 = df_2022.dropna(subset=["Idade"])

# Converter a coluna para o tipo inteiro
df_2022["Idade"] = df_2022["Idade"].astype(int)

# Verificar os tipos de dados após a conversão
print(df_2022.dtypes)
# Out:
# Idade                                                int64
# Faixa idade                                         object
# Genero                                              object
# Estado onde mora                                    object
# UF onde mora                                        object
# Mudou de Estado?                                    object
# Nivel de Ensino                                     object
# Área de Formação                                    object
# Setor                                               object
# Número de Funcionários                              object
# Cargo Atual                                         object
# Nível                                               object
# Faixa salarial                                      object
# Experiência na área de dados                        object
# Experiência prévia em TI/Engenharia de Software     object
# Satisfação com a empresa atual                      object
# Maturidade em tecnologia e dados                   float64
# Qualidade dos gestores e líderes                   float64
# Reputação da empresa no mercado                    float64
# Forma de trabalho atual                             object
# Forma de trabalho ideal                             object
# Atitude em caso de modelo 100% presencial           object
# dtype: object
# <ipython-input-71-f59065d1af40>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022["Idade"] = df_2022["Idade"].astype(int)

# %% [markdown]
# ##DROPANDO AS LINHAS VAZIAS DATAFRAME 2022

# %%
df_2022.dropna(inplace=True)
# Out:
# <ipython-input-72-d354d92b4612>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.dropna(inplace=True)

# %%
df_2022
# Out:
#       Idade Faixa idade     Genero       Estado onde mora UF onde mora  \
# 0        39       35-39  Masculino  Distrito Federal (DF)           DF
# 2        53       50-54  Masculino  Distrito Federal (DF)           DF
# 3        27       25-29  Masculino      Minas Gerais (MG)           MG
# 4        46       45-49   Feminino              Pará (PA)           PA
# 5        32       30-34   Feminino             Ceará (CE)           CE
# ...     ...         ...        ...                    ...          ...
# 4263     26       25-29  Masculino    Rio de Janeiro (RJ)           RJ
# 4265     28       25-29  Masculino            Paraná (PR)           PR
# 4266     26       25-29  Masculino         São Paulo (SP)           SP
# 4267     30       30-34   Feminino      Minas Gerais (MG)           MG
# 4270     24       22-24  Masculino             Goiás (GO)           GO
#
#      Mudou de Estado?        Nivel de Ensino  \
# 0               False          Pós-graduação
# 2               False          Pós-graduação
# 3                True       Doutorado ou Phd
# 4                True          Pós-graduação
# 5                True          Pós-graduação
# ...               ...                    ...
# 4263             True  Graduação/Bacharelado
# 4265             True  Graduação/Bacharelado
# 4266             True  Graduação/Bacharelado
# 4267             True               Mestrado
# 4270            False  Graduação/Bacharelado
#
#                                        Área de Formação  \
# 0     Computação / Engenharia de Software / Sistemas...
# 2     Computação / Engenharia de Software / Sistemas...
# 3     Estatística/ Matemática / Matemática Computaci...
# 4     Computação / Engenharia de Software / Sistemas...
# 5     Ciências Biológicas/ Farmácia/ Medicina/ Área ...
# ...                                                 ...
# 4263                                 Outras Engenharias
# 4265  Computação / Engenharia de Software / Sistemas...
# 4266  Computação / Engenharia de Software / Sistemas...
# 4267                                 Outras Engenharias
# 4270  Computação / Engenharia de Software / Sistemas...
#
#                                Setor Número de Funcionários  \
# 0                      Setor Público         Acima de 3.000
# 2                 Finanças ou Bancos         Acima de 3.000
# 3                   Setor Automotivo         Acima de 3.000
# 4                      Setor Público           de 101 a 500
# 5                           Educação         Acima de 3.000
# ...                              ...                    ...
# 4263  Tecnologia/Fábrica de Software         de 501 a 1.000
# 4265                       Marketing               de 1 a 5
# 4266  Tecnologia/Fábrica de Software         Acima de 3.000
# 4267             Área de Consultoria            de 51 a 100
# 4270                    Agronegócios         de 501 a 1.000
#
#                                             Cargo Atual   Nível  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 3                     Cientista de Dados/Data Scientist  Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# ...                                                 ...     ...
# 4263  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
# 4265                              Analista de Marketing   Pleno
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#                         Faixa salarial  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# ...                                ...
# 4263    de R$ 6.001/mês a R$ 8.000/mês
# 4265    de R$ 2.001/mês a R$ 3.000/mês
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#                 Experiência na área de dados  \
# 0                              de 1 a 2 anos
# 2                              de 3 a 4 anos
# 3                              de 4 a 6 anos
# 4     Não tenho experiência na área de dados
# 5     Não tenho experiência na área de dados
# ...                                      ...
# 4263                           de 3 a 4 anos
# 4265                           de 3 a 4 anos
# 4266                           de 3 a 4 anos
# 4267                           de 1 a 2 anos
# 4270                           de 1 a 2 anos
#
#         Experiência prévia em TI/Engenharia de Software  \
# 0                                        de 7 a 10 anos
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4263  Não tive experiência na área de TI/Engenharia ...
# 4265                                      de 1 a 2 anos
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#      Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 0                              True                              0.00
# 2                             False                              0.00
# 3                              True                              0.00
# 4                             False                              0.00
# 5                             False                              0.00
# ...                             ...                               ...
# 4263                           True                              0.00
# 4265                          False                              0.00
# 4266                           True                              0.00
# 4267                           True                              0.00
# 4270                          False                              0.00
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 0                                 0.00                             0.00
# 2                                 0.00                             0.00
# 3                                 0.00                             0.00
# 4                                 0.00                             0.00
# 5                                 0.00                             0.00
# ...                                ...                              ...
# 4263                              0.00                             0.00
# 4265                              0.00                             1.00
# 4266                              0.00                             0.00
# 4267                              0.00                             0.00
# 4270                              0.00                             1.00
#
#                                 Forma de trabalho atual  \
# 0                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# 5                                Modelo 100% presencial
# ...                                                 ...
# 4263                                 Modelo 100% remoto
# 4265  Modelo híbrido com dias fixos de trabalho pres...
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4270                                 Modelo 100% remoto
#
#                                 Forma de trabalho ideal  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# 5     Modelo híbrido flexível (o funcionário tem lib...
# ...                                                 ...
# 4263  Modelo híbrido flexível (o funcionário tem lib...
# 4265                                 Modelo 100% remoto
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4270                                 Modelo 100% remoto
#
#               Atitude em caso de modelo 100% presencial
# 0      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4      Vou aceitar e retornar ao modelo 100% presencial
# 5      Vou aceitar e retornar ao modelo 100% presencial
# ...                                                 ...
# 4263  Vou procurar outra oportunidade no modelo híbr...
# 4265  Vou procurar outra oportunidade no modelo 100%...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
# [2802 rows x 22 columns]

# %%
df_2022 ["Satisfação com a empresa atual"] = df_2022 ["Satisfação com a empresa atual"].astype("bool")
df_2022 ["Maturidade em tecnologia e dados"] = df_2022 ["Maturidade em tecnologia e dados"].astype("int64")
df_2022 ["Qualidade dos gestores e líderes"] = df_2022 ["Qualidade dos gestores e líderes"].astype("float64")
df_2022 ["Reputação da empresa no mercado"] = df_2022 ["Reputação da empresa no mercado"].astype("float64")
df_2022 ["Mudou de Estado?"] = df_2022 ["Mudou de Estado?"].astype("bool")
# Out:
# <ipython-input-74-6610e175f14d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022 ["Satisfação com a empresa atual"] = df_2022 ["Satisfação com a empresa atual"].astype("bool")
# <ipython-input-74-6610e175f14d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022 ["Maturidade em tecnologia e dados"] = df_2022 ["Maturidade em tecnologia e dados"].astype("int64")
# <ipython-input-74-6610e175f14d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022 ["Qualidade dos gestores e líderes"] = df_2022 ["Qualidade dos gestores e líderes"].astype("float64")
# <ipython-input-74-6610e175f14d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022 ["Reputação da empresa no mercado"] = df_2022 ["Reputação da empresa no mercado"].astype("float64")
# <ipython-input-74-6610e175f14d>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022 ["Mudou de Estado?"] = df_2022 ["Mudou de Estado?"].astype("bool")

# %%
df_2022.isna().sum()
# Out:
# Idade                                              0
# Faixa idade                                        0
# Genero                                             0
# Estado onde mora                                   0
# UF onde mora                                       0
# Mudou de Estado?                                   0
# Nivel de Ensino                                    0
# Área de Formação                                   0
# Setor                                              0
# Número de Funcionários                             0
# Cargo Atual                                        0
# Nível                                              0
# Faixa salarial                                     0
# Experiência na área de dados                       0
# Experiência prévia em TI/Engenharia de Software    0
# Satisfação com a empresa atual                     0
# Maturidade em tecnologia e dados                   0
# Qualidade dos gestores e líderes                   0
# Reputação da empresa no mercado                    0
# Forma de trabalho atual                            0
# Forma de trabalho ideal                            0
# Atitude em caso de modelo 100% presencial          0
# dtype: int64

# %%
import pandera as pa

# Definição do esquema de validação
schema = pa.DataFrameSchema({
    'Idade': pa.Column(pa.Int64),
    'Faixa idade': pa.Column(pa.String),
    'Genero': pa.Column(pa.String),
    'Estado onde mora': pa.Column(pa.String),
    'UF onde mora': pa.Column(pa.String),
    'Mudou de Estado?': pa.Column(pa.Bool),
    'Nível': pa.Column(pa.String),  # Atualizei o nome da coluna para 'Nível'
    'Área de Formação': pa.Column(pa.String),
    'Setor': pa.Column(pa.String),
    'Número de Funcionários': pa.Column(pa.String),
    'Cargo Atual': pa.Column(pa.String),
    'Faixa salarial': pa.Column(pa.String),
    'Experiência na área de dados': pa.Column(pa.String),
    'Experiência prévia em TI/Engenharia de Software': pa.Column(pa.String),
    'Satisfação com a empresa atual': pa.Column(pa.Bool),
    'Maturidade em tecnologia e dados': pa.Column(pa.Int64),
    'Qualidade dos gestores e líderes': pa.Column(pa.Float64),
    'Reputação da empresa no mercado': pa.Column(pa.Float64),
    'Forma de trabalho atual': pa.Column(pa.String),
    'Forma de trabalho ideal': pa.Column(pa.String),
    'Atitude em caso de modelo 100% presencial': pa.Column(pa.String)
})

# Validar o DataFrame
schema.validate(df_2022)
# Out:
#       Idade Faixa idade     Genero       Estado onde mora UF onde mora  \
# 0        39       35-39  Masculino  Distrito Federal (DF)           DF
# 2        53       50-54  Masculino  Distrito Federal (DF)           DF
# 3        27       25-29  Masculino      Minas Gerais (MG)           MG
# 4        46       45-49   Feminino              Pará (PA)           PA
# 5        32       30-34   Feminino             Ceará (CE)           CE
# ...     ...         ...        ...                    ...          ...
# 4263     26       25-29  Masculino    Rio de Janeiro (RJ)           RJ
# 4265     28       25-29  Masculino            Paraná (PR)           PR
# 4266     26       25-29  Masculino         São Paulo (SP)           SP
# 4267     30       30-34   Feminino      Minas Gerais (MG)           MG
# 4270     24       22-24  Masculino             Goiás (GO)           GO
#
#       Mudou de Estado?        Nivel de Ensino  \
# 0                False          Pós-graduação
# 2                False          Pós-graduação
# 3                 True       Doutorado ou Phd
# 4                 True          Pós-graduação
# 5                 True          Pós-graduação
# ...                ...                    ...
# 4263              True  Graduação/Bacharelado
# 4265              True  Graduação/Bacharelado
# 4266              True  Graduação/Bacharelado
# 4267              True               Mestrado
# 4270             False  Graduação/Bacharelado
#
#                                        Área de Formação  \
# 0     Computação / Engenharia de Software / Sistemas...
# 2     Computação / Engenharia de Software / Sistemas...
# 3     Estatística/ Matemática / Matemática Computaci...
# 4     Computação / Engenharia de Software / Sistemas...
# 5     Ciências Biológicas/ Farmácia/ Medicina/ Área ...
# ...                                                 ...
# 4263                                 Outras Engenharias
# 4265  Computação / Engenharia de Software / Sistemas...
# 4266  Computação / Engenharia de Software / Sistemas...
# 4267                                 Outras Engenharias
# 4270  Computação / Engenharia de Software / Sistemas...
#
#                                Setor Número de Funcionários  \
# 0                      Setor Público         Acima de 3.000
# 2                 Finanças ou Bancos         Acima de 3.000
# 3                   Setor Automotivo         Acima de 3.000
# 4                      Setor Público           de 101 a 500
# 5                           Educação         Acima de 3.000
# ...                              ...                    ...
# 4263  Tecnologia/Fábrica de Software         de 501 a 1.000
# 4265                       Marketing               de 1 a 5
# 4266  Tecnologia/Fábrica de Software         Acima de 3.000
# 4267             Área de Consultoria            de 51 a 100
# 4270                    Agronegócios         de 501 a 1.000
#
#                                             Cargo Atual   Nível  \
# 0                   DBA/Administrador de Banco de Dados  Júnior
# 2     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 3                     Cientista de Dados/Data Scientist  Sênior
# 4     Desenvolvedor/ Engenheiro de Software/ Analist...   Pleno
# 5                                             Professor   Pleno
# ...                                                 ...     ...
# 4263  Engenheiro de Dados/Arquiteto de Dados/Data En...  Júnior
# 4265                              Analista de Marketing   Pleno
# 4266                     Analista de Dados/Data Analyst   Pleno
# 4267  Engenheiro de Dados/Arquiteto de Dados/Data En...   Pleno
# 4270                     Analista de Dados/Data Analyst  Júnior
#
#                         Faixa salarial  \
# 0      de R$ 8.001/mês a R$ 12.000/mês
# 2     de R$ 12.001/mês a R$ 16.000/mês
# 3     de R$ 12.001/mês a R$ 16.000/mês
# 4       de R$ 6.001/mês a R$ 8.000/mês
# 5       de R$ 2.001/mês a R$ 3.000/mês
# ...                                ...
# 4263    de R$ 6.001/mês a R$ 8.000/mês
# 4265    de R$ 2.001/mês a R$ 3.000/mês
# 4266    de R$ 4.001/mês a R$ 6.000/mês
# 4267    de R$ 3.001/mês a R$ 4.000/mês
# 4270    de R$ 3.001/mês a R$ 4.000/mês
#
#                 Experiência na área de dados  \
# 0                              de 1 a 2 anos
# 2                              de 3 a 4 anos
# 3                              de 4 a 6 anos
# 4     Não tenho experiência na área de dados
# 5     Não tenho experiência na área de dados
# ...                                      ...
# 4263                           de 3 a 4 anos
# 4265                           de 3 a 4 anos
# 4266                           de 3 a 4 anos
# 4267                           de 1 a 2 anos
# 4270                           de 1 a 2 anos
#
#         Experiência prévia em TI/Engenharia de Software  \
# 0                                        de 7 a 10 anos
# 2                                       Mais de 10 anos
# 3     Não tive experiência na área de TI/Engenharia ...
# 4                                       Mais de 10 anos
# 5     Não tive experiência na área de TI/Engenharia ...
# ...                                                 ...
# 4263  Não tive experiência na área de TI/Engenharia ...
# 4265                                      de 1 a 2 anos
# 4266                                     de 7 a 10 anos
# 4267  Não tive experiência na área de TI/Engenharia ...
# 4270  Não tive experiência na área de TI/Engenharia ...
#
#       Satisfação com a empresa atual  Maturidade em tecnologia e dados  \
# 0                               True                                 0
# 2                              False                                 0
# 3                               True                                 0
# 4                              False                                 0
# 5                              False                                 0
# ...                              ...                               ...
# 4263                            True                                 0
# 4265                           False                                 0
# 4266                            True                                 0
# 4267                            True                                 0
# 4270                           False                                 0
#
#       Qualidade dos gestores e líderes  Reputação da empresa no mercado  \
# 0                                 0.00                             0.00
# 2                                 0.00                             0.00
# 3                                 0.00                             0.00
# 4                                 0.00                             0.00
# 5                                 0.00                             0.00
# ...                                ...                              ...
# 4263                              0.00                             0.00
# 4265                              0.00                             1.00
# 4266                              0.00                             0.00
# 4267                              0.00                             0.00
# 4270                              0.00                             1.00
#
#                                 Forma de trabalho atual  \
# 0                                Modelo 100% presencial
# 2     Modelo híbrido com dias fixos de trabalho pres...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# 5                                Modelo 100% presencial
# ...                                                 ...
# 4263                                 Modelo 100% remoto
# 4265  Modelo híbrido com dias fixos de trabalho pres...
# 4266                                 Modelo 100% remoto
# 4267                                 Modelo 100% remoto
# 4270                                 Modelo 100% remoto
#
#                                 Forma de trabalho ideal  \
# 0     Modelo híbrido com dias fixos de trabalho pres...
# 2     Modelo híbrido flexível (o funcionário tem lib...
# 3     Modelo híbrido flexível (o funcionário tem lib...
# 4                                Modelo 100% presencial
# 5     Modelo híbrido flexível (o funcionário tem lib...
# ...                                                 ...
# 4263  Modelo híbrido flexível (o funcionário tem lib...
# 4265                                 Modelo 100% remoto
# 4266  Modelo híbrido flexível (o funcionário tem lib...
# 4267  Modelo híbrido flexível (o funcionário tem lib...
# 4270                                 Modelo 100% remoto
#
#               Atitude em caso de modelo 100% presencial
# 0      Vou aceitar e retornar ao modelo 100% presencial
# 2     Vou procurar outra oportunidade no modelo híbr...
# 3     Vou procurar outra oportunidade no modelo híbr...
# 4      Vou aceitar e retornar ao modelo 100% presencial
# 5      Vou aceitar e retornar ao modelo 100% presencial
# ...                                                 ...
# 4263  Vou procurar outra oportunidade no modelo híbr...
# 4265  Vou procurar outra oportunidade no modelo 100%...
# 4266  Vou procurar outra oportunidade no modelo híbr...
# 4267   Vou aceitar e retornar ao modelo 100% presencial
# 4270  Vou procurar outra oportunidade no modelo 100%...
#
# [2802 rows x 22 columns]

# %% [markdown]
# #<font color ="cyan">EXPORTANDO DATAFRAME 2022 - TRATADO (XLSX)</font>

# %%
# Exportação para google drive.
df_2022.to_excel('DF_2022_tratado.xlsx')

# %% [markdown]
# #<font color ="cyan">ANÁLISE EXPLORATÓRIA DO DATAFRAME 2022 (XLSX)</font>

# %%
# Qual é a média de salário por gênero?
df_2022.groupby('Genero')['Idade'].sum().sort_values(ascending=False).head(10).plot(kind='barh', color='orange')
plt.xlabel('Salário')
plt.ylabel('Genero')
plt.title('Média Salarial por Genero')
plt.show()

# %%
#Qual é a distribuição de salários por faixa etária?
df_2022.groupby('Faixa salarial')['Faixa idade'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
plt.xlabel('Salário / Idade')
plt.ylabel('Quantidade')
plt.title('Salário por Faixa Etária')
plt.show()

# %%
#Qual é a média de anos de experiência profissional por setor?
df_2022.groupby('Experiência na área de dados')['Setor'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Experiência na área de dados  Setor
# de 1 a 2 anos                 Tecnologia/Fábrica de Software    185
#                               Finanças ou Bancos                157
# de 3 a 4 anos                 Finanças ou Bancos                114
#                               Tecnologia/Fábrica de Software    112
# Menos de 1 ano                Tecnologia/Fábrica de Software    104
# de 1 a 2 anos                 Área de Consultoria                83
# Menos de 1 ano                Finanças ou Bancos                 69
# de 4 a 6 anos                 Finanças ou Bancos                 68
# de 1 a 2 anos                 Varejo                             67
# de 4 a 6 anos                 Tecnologia/Fábrica de Software     61
# Name: Setor, dtype: int64

# %%
#Como a média de salário varia entre diferentes níveis de educação?
df_2022.groupby('Faixa salarial')['Nivel de Ensino'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar', color='gray')
plt.xlabel('Salário x Educação')
plt.ylabel('Quantidade')
plt.title('Níveis de Educação')
plt.show()

# %% [markdown]
# #<font color ="cyan">GRÁFICOS USANDO MATPLOTLIB DATAFRAME 2022</font>

# %%
# Histograma de Idade
plt.hist(df_2022['Idade'], bins=20, color='orange', edgecolor='black')
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Distribuição da Idade dos Trabalhadores')
plt.show()

# %%
# Medidas de Tendência Central
media_idade = df_2022['Idade'].mean()
mediana_idade = df_2022['Idade'].median()
moda_idade = df_2022['Idade'].mode().values[0]

# %%
# Boxplot
plt.boxplot(df_2022['Idade'])
plt.ylabel('Idade')
plt.title('Distribuição da Idade dos Trabalhadores')
plt.show()

# %%
# Descrição Estatística
descricao_idade = df_2022['Idade'].describe()
print(descricao_idade)
# Out:
# count   2802.00
# mean      30.31
# std        6.49
# min       18.00
# 25%       26.00
# 50%       29.00
# 75%       34.00
# max       54.00
# Name: Idade, dtype: float64

# %%
print("Média de Idade:", media_idade)
print("Mediana de Idade:", mediana_idade)
print("Moda de Idade:", moda_idade)
# Out:
# Média de Idade: 30.30728051391863
# Mediana de Idade: 29.0
# Moda de Idade: 27

# %%
# Boxplot por Faixa Etária
plt.figure(figsize=(10, 6))
sns.boxplot(x='Faixa idade', y='Idade', data=df_2022, palette='viridis')
plt.xlabel('Faixa Etária')
plt.ylabel('Idade')
plt.title('Distribuição da Idade por Faixa Etária')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# <ipython-input-87-a1e66ced44b3>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Faixa idade', y='Idade', data=df_2022, palette='viridis')

# %%
# Análise Estatística Descritiva por Faixa Etária
descricao_por_faixa_etaria = df_2022.groupby('Faixa idade')['Idade'].describe()
print(descricao_por_faixa_etaria)
# Out:
#               count  mean  std   min   25%   50%   75%   max
# Faixa idade
# 17-21         95.00 20.34 0.94 18.00 20.00 21.00 21.00 21.00
# 22-24        347.00 23.20 0.80 22.00 23.00 23.00 24.00 24.00
# 25-29       1055.00 26.93 1.37 25.00 26.00 27.00 28.00 29.00
# 30-34        708.00 31.77 1.40 30.00 31.00 32.00 33.00 34.00
# 35-39        333.00 36.66 1.37 35.00 36.00 36.00 38.00 39.00
# 40-44        143.00 41.83 1.41 40.00 41.00 42.00 43.00 44.00
# 45-49         80.00 46.71 1.36 45.00 45.75 47.00 48.00 49.00
# 50-54         41.00 51.56 1.48 50.00 50.00 52.00 53.00 54.00

# %%
# Teste de ANOVA (Análise de Variância)
from scipy.stats import f_oneway

# %%
faixas_etarias = df_2022['Faixa idade'].unique()
grupos_por_faixa_etaria = [df_2022[df_2022['Faixa idade'] == faixa]['Idade'] for faixa in faixas_etarias]

# %%
resultado_anova = f_oneway(*grupos_por_faixa_etaria)
print("\nResultado do Teste de ANOVA:")
print("Valor-p:", resultado_anova.pvalue)
# Out:
# Resultado do Teste de ANOVA:
# Valor-p: 0.0

# %%
#Qual é a forma de trabalho ideal para os trabalhadores?

plt.figure(figsize=(6, 6))
plt.scatter(df_2022['Idade'], df_2022['Forma de trabalho ideal'])
plt.xlabel('Idade')
plt.ylabel('Forma de trabalho ideal')
plt.title('Relação entre Idade e Forma de trabalho ideal')
plt.show()

# %% [markdown]
# #<font color ="cyan">GRÁFICOS USANDO SEABORN DATAFRAME 2022</font>

# %%
# Calcula a matriz de correlação
correlation_matrix = df_2022.corr()

# Plota o gráfico de correlação usando seaborn
plt.figure(figsize=(8, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='PiYG', fmt=".2f", vmin=-1, vmax=1)
plt.title('Gráfico de Correlação')
plt.show()
# Out:
# <ipython-input-93-3cae2123ba78>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_2022.corr()

# %%
# Histograma
plt.figure(figsize=(10, 6))
sns.histplot(df_2022['Idade'], kde=True, color='blue', bins=10)
plt.xlabel('Idade')
plt.ylabel('Frequência')
plt.title('Histograma de Idade')
plt.grid(True)
plt.show()

# %%
for coluna in colunas_numericas:
    print(f"{coluna}: {df_2022[coluna].dtype}")
# Out:
# Idade: int64
# Maturidade em tecnologia e dados: int64
# Qualidade dos gestores e líderes: float64
# Reputação da empresa no mercado: float64

# %%
df_2022.columns.tolist()
# Out:
# ['Idade',
#  'Faixa idade',
#  'Genero',
#  'Estado onde mora',
#  'UF onde mora',
#  'Mudou de Estado?',
#  'Nivel de Ensino',
#  'Área de Formação',
#  'Setor',
#  'Número de Funcionários',
#  'Cargo Atual',
#  'Nível',
#  'Faixa salarial',
#  'Experiência na área de dados',
#  'Experiência prévia em TI/Engenharia de Software',
#  'Satisfação com a empresa atual',
#  'Maturidade em tecnologia e dados',
#  'Qualidade dos gestores e líderes',
#  'Reputação da empresa no mercado',
#  'Forma de trabalho atual',
#  'Forma de trabalho ideal',
#  'Atitude em caso de modelo 100% presencial']

# %% [markdown]
# #<font color ="cyan">CONFERINDO AS LINHAS EM COMUM NOS DOIS DATASETS (2021 E 2022)</font>

# %% [markdown]
# ##VERIFICANDO AS DIFERENÇAS

# %% [markdown]
# ####DROP1 =
#     "'Idade'",
#     "'Faixa idade'",
#     "'Genero'",
#     "'Estado onde mora'",
#     "'uf onde mora'",
#     "'Mudou de Estado?'",
#     "'Nivel de Ensino'",
#     "'Área de Formação'",
#     "'Qual sua situação atual de trabalho?'",
#     "'Setor'",
#     "'Numero de Funcionarios'",
#     "'Gestor?'",
#     "'Cargo Atual'",
#     "'Nivel'",
#     "'Faixa salarial'",
#     "'Quanto tempo de experiência na área de dados você tem?'",
#     "'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'",
#     "'Você está satisfeito na sua empresa atual?'",
#     "'Você participou de entrevistas de emprego nos últimos 6 meses?'",
#     "'Você pretende mudar de emprego nos próximos 6 meses?'",
#     "'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?'",
#     "'Remuneração/Salário'",
#     "'Benefícios'",
#     "'Propósito do trabalho e da empresa'",
#     "'Flexibilidade de trabalho remoto'",
#     "'Ambiente e clima de trabalho'",
#     "'Oportunidade de aprendizado e trabalhar com referências na área'",
#     "'Plano de carreira e oportunidades de crescimento profissional'",
#     "'Maturidade da empresa em termos de tecnologia e dados'",
#     "'Qualidade dos gestores e líderes'",
#     "'Reputação que a empresa tem no mercado'",
#     "'Atualmente qual a sua forma de trabalho?'",
#     "'Qual a forma de trabalho ideal para você?'",
#     "'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?'
# ####DROP 2 =
#     "'Idade'",
#     "'Faixa idade'",
#     "'Genero'",
#     "'Cor/raca/etnia'",
#     "'PCD'",
#     "'experiencia_profissional_prejudicada'",
#     "'aspectos_prejudicados'",
#     "'vive_no_brasil'",
#     "'Estado onde mora'",
#     "'uf onde mora'",
#     "'Regiao onde mora'",
#     "'Mudou de Estado?'",
#     "'Regiao de origem'",
#     "'Nivel de Ensino'",
#     "'Área de Formação'",
#     "'Qual sua situação atual de trabalho?'",
#     "'Setor'",
#     "'Numero de Funcionarios'",
#     "'Gestor?'",
#     "'Cargo como Gestor'",
#     "'Cargo Atual'",
#     "'Nivel'",
#     "'Faixa salarial'",
#     "'Quanto tempo de experiência na área de dados você tem?'",
#     "'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?'",
#     "'Você está satisfeito na sua empresa atual?'",
#     "'Qual o principal motivo da sua insatisfação com a empresa atual?'",
#     "'Falta de oportunidade de crescimento no emprego atual'",
#     "'Salário atual não corresponde ao mercado'",
#     "'Não tenho uma boa relação com meu líder/gestor'",
#     "'Gostaria de trabalhar em em outra área de atuação'",
#     "'Gostaria de receber mais benefícios'",
#     "'O clima de trabalho/ambiente não é bom'",
#     "'Falta de maturidade analítica na empresa'",
#     "'Você participou de entrevistas de emprego nos últimos 6 meses?'",
#     "'Você pretende mudar de emprego nos próximos 6 meses?'",
#     "'Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?'",
#     "'Remuneração/Salário'",
#     "'Benefícios'",
#     "'Propósito do trabalho e da empresa'",
#     "'Flexibilidade de trabalho remoto'",
#     "'Ambiente e clima de trabalho'",
#     "'Oportunidade de aprendizado e trabalhar com referências na área'",
#     "'Plano de carreira e oportunidades de crescimento profissional'",
#     "'Maturidade da empresa em termos de tecnologia e dados'",
#     "'Qualidade dos gestores e líderes'",
#     "'Reputação que a empresa tem no mercado'",
#     "'Atualmente qual a sua forma de trabalho?'",
#     "'Qual a forma de trabalho ideal para você?'",
#     "'Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?'"

# %% [markdown]
# ###LISTA FINAL PÓS COMPARAÇÃO

# %% [markdown]
# ###Colunas em comum =
#
# ```
# "Idade"
# "Faixa idade"
# "Genero"
# "Estado onde mora"
# "uf onde mora"
# "Mudou de Estado?"
# "Nivel de Ensino"
# "Área de Formação"
# "Qual sua situação atual de trabalho?"
# "Setor"
# "Numero de Funcionarios"
# "Gestor?"
# "Cargo Atual"
# "Nivel"
# "Faixa salarial"
# "Quanto tempo de experiência na área de dados você tem?"
# "Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?"
# "Você está satisfeito na sua empresa atual?"
# "Quais os principais critérios que você leva em consideração no momento de decidir onde trabalhar?"
# "Remuneração/Salário"
# "Benefícios"
# "Propósito do trabalho e da empresa"
# "Flexibilidade de trabalho remoto"
# "Ambiente e clima de trabalho"
# "Oportunidade de aprendizado e trabalhar com referências na área"
# "Plano de carreira e oportunidades de crescimento profissional"
# "Maturidade da empresa em termos de tecnologia e dados"
# "Qualidade dos gestores e líderes"
# "Reputação que a empresa tem no mercado"
# "Atualmente qual a sua forma de trabalho?"
# "Qual a forma de trabalho ideal para você?"
# "Caso sua empresa decida pelo modelo 100% presencial qual será sua atitude?"
# ```
